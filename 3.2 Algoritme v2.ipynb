# %% [markdown]
# ## Omloop nummer 1 met de hand

# %%
import pandas as pd
from datetime import timedelta

# Constante variabelen
ENERGIE_VERBRUIK_PER_KM = 1.2  # kWh per gereden kilometer
OPLAADKRACHT_PER_UUR = 450  # kWh per uur tot 90%
MAX_BATT_CAPA = 300  # kWh
SOC_START = 0.9  # factor
SOC_MIN = 0.1  # factor
BATTERIJ_SLIJTAGE = 0.9  # Factor
SOH = MAX_BATT_CAPA * BATTERIJ_SLIJTAGE

def load_data():
    """Functie om data in te laden."""
    df_omloopplanning = pd.read_excel('Onaangepast - omloopplanning.xlsx', engine='openpyxl')
    df_dienstregeling = pd.read_excel('Onaangepast - Connexxion data - 2024-2025.xlsx', engine='openpyxl')
    df_afstandsmatrix = pd.read_excel('Onaangepast - Connexxion data - 2024-2025.xlsx', engine='openpyxl', sheet_name='Afstandsmatrix')
    return df_omloopplanning, df_dienstregeling, df_afstandsmatrix

def create_parameters_df():
    """Functie om een parameters DataFrame te maken."""
    soc_ochtend = SOH * SOC_START
    soc_minimum = SOH * SOC_MIN
    data = {
        'Parameter': ['Max Batterij Capaciteit', 'SOC Start', 'SOC Minimum', 'Batterij Slijtage', 'SOH', 'SOC Ochtend', 'SOC Minimum', 'Batterijverbuik', 'Oplaadsnelheid'],
        'Waarde': [MAX_BATT_CAPA, SOC_START, SOC_MIN, BATTERIJ_SLIJTAGE, SOH, soc_ochtend, soc_minimum, ENERGIE_VERBRUIK_PER_KM, OPLAADKRACHT_PER_UUR],
        'Eenheid': ['kWh', 'Factor', 'Factor', 'Factor', 'kW (MBC * BS)', 'kW (SOH * SOC S)', 'kW (SOH * SOC M)', 'kWh/km', 'kWh/uur']
    }
    return pd.DataFrame(data)

def convert_to_datetime(time_str):
    """Functie om tijden naar datetime om te zetten."""
    if pd.isna(time_str):
        # Als de tijd ontbreekt, retourneer een NaT Timestamp
        return pd.NaT

    try:
        time_obj = pd.to_datetime(time_str, format='%H:%M').time()
    except TypeError:
        # Fallback als time_str geen geschikt formaat heeft
        return pd.NaT

    upper_boundary = pd.to_datetime('23:59', format='%H:%M').time()
    lower_boundary = pd.to_datetime('04:00', format='%H:%M').time()
    
    if lower_boundary <= time_obj <= upper_boundary:
        return pd.Timestamp('2024-08-29') + pd.Timedelta(hours=time_obj.hour, minutes=time_obj.minute)
    else:
        return pd.Timestamp('2024-08-30') + pd.Timedelta(hours=time_obj.hour, minutes=time_obj.minute)

def process_schedule_data(df_dienstregeling):
    """Functie om de nieuwe dienstregeling te verwerken."""
    df = df_dienstregeling.copy()
    
    # Vervang NaN door een standaardwaarde voordat je de conversie uitvoert
    df['buslijn'] = df['buslijn'].fillna(0).astype(int).astype(str)

    df['vertrek_datetime'] = df['vertrektijd'].apply(convert_to_datetime)
    df['Omloop'] = 0
    df_sorted = df.sort_values(by=['vertrek_datetime', 'buslijn'])
    df_sorted['code_omloop'] = df_sorted['startlocatie'].str.strip().str.lower() + '_' + \
                               df_sorted['eindlocatie'].str.strip().str.lower() + '_' + \
                               df_sorted['buslijn']
    return df_sorted

def process_distance_matrix(df_afstandsmatrix):
    """Functie om de afstandsmatrix te verwerken."""
    df = df_afstandsmatrix.copy()
    df['buslijn'] = df['buslijn'].fillna(0).astype(int).astype(str)
    df['code_afstand'] = df['startlocatie'].str.strip().str.lower() + '_' + \
                         df['eindlocatie'].str.strip().str.lower() + '_' + \
                         df['buslijn']
    return df

def setUpDataframes(df_nieuwe_dienstregelingv2, df_afstandsmatrix):
    """Kopieer en bereid dataframes voor gebruik voor de inplanting."""
    df = df_nieuwe_dienstregelingv2.copy()
    df['vertrek_datetime'] = pd.to_datetime(df['vertrek_datetime'])
    df['aankomst_datetime'] = pd.NaT
    df['Omloop'] = pd.NA
    return df

def vindt_reistijd(df_afstandsmatrix, startlocatie, eindlocatie):
    """Vind de reistijd tussen start- en eindlocatie."""
    rij = df_afstandsmatrix[
        (df_afstandsmatrix['startlocatie'] == startlocatie) &
        (df_afstandsmatrix['eindlocatie'] == eindlocatie)
    ]
    if not rij.empty:
        return int(rij['min reistijd in min'].values[0])
    return None

def inplannen_busritten(df_ritten, df_afstandsmatrix):
    """Functie om busritten in te plannen met een verplichte rusttijd na elke vijfde keer bij 'ehvbst'."""
    bus_nr = omloopnummer_voor_de_while_loop
    actuele_tijd = df_ritten.iloc[0]['vertrek_datetime'] - timedelta(minutes=4)  # Start bij de garage
    huidige_locatie = 'ehvgar'
    count_ehvbst = 0  # Tel hoe vaak de bus bij 'ehvbst' is aangekomen
    iteration_count = 0

    while True:
        iteration_count += 1
        print(f"Iteration {iteration_count}: Current time {actuele_tijd}, Current location {huidige_locatie}")

        mogelijk_ritten = df_ritten[
            (df_ritten['Omloop'].isna()) & 
            (df_ritten['vertrek_datetime'] >= actuele_tijd) & 
            (df_ritten['startlocatie'] == huidige_locatie)
        ]

        if not mogelijk_ritten.empty:
            row = mogelijk_ritten.iloc[0]  # Kies de eerst mogelijke rit
            print(f"Assigning ride at index {row.name} to bus {bus_nr}.")
            df_ritten.at[row.name, 'Omloop'] = bus_nr

            rit_duur = vindt_reistijd(df_afstandsmatrix, row['startlocatie'], row['eindlocatie'])
            if rit_duur is not None:
                aankomsttijd = row['vertrek_datetime'] + timedelta(minutes=rit_duur)
                df_ritten.at[row.name, 'aankomst_datetime'] = aankomsttijd
                print(f"Ride at index {row.name} arrives at: {aankomsttijd}")

                actuele_tijd = aankomsttijd
                huidige_locatie = row['eindlocatie']

                # Bijhouden hoe vaak 'ehvbst' bereikt is
                if huidige_locatie == 'ehvbst':
                    count_ehvbst += 1
                    print(f"Bus has now arrived at 'ehvbst' {count_ehvbst} times.")
                    
                    # Bij elke 5e keer een pauze van een uur incasseren
                    if count_ehvbst == 8:
                        print("Taking a break for 1 hour at 'ehvbst'.")
                        actuele_tijd += timedelta(hours=1)
                        count_ehvbst = 0  # Reset de teller
                
                print(f"Ride ends at {aankomsttijd}, new current location is {huidige_locatie}.")
            continue

        volgende_startlocaties = df_ritten[
            (df_ritten['Omloop'].isna()) &
            (df_ritten['vertrek_datetime'] > actuele_tijd)
        ]

        if volgende_startlocaties.empty:
            print("No more rides available, terminating loop.")
            break

        next_location_found = False
        for _, row in volgende_startlocaties.iterrows():
            reistijd = vindt_reistijd(df_afstandsmatrix, huidige_locatie, row['startlocatie'])
            if reistijd is not None and (actuele_tijd + timedelta(minutes=reistijd)) <= row['vertrek_datetime']:
                print(f"Moving to new start location {row['startlocatie']} with travel time {reistijd} minutes.")
                actuele_tijd += timedelta(minutes=reistijd)
                huidige_locatie = row['startlocatie']
                next_location_found = True
                break

        if not next_location_found:
            print("Unable to find a valid next location, terminating loop.")
            break

    return df_ritten

def filter_and_calculate(df_ritten, df_afstandsmatrix):
    """Filter de DataFrame en bereken afstand en batterijverbruik."""
    omloop_1_df = df_ritten[df_ritten['Omloop'] == omloopnummer_voor_de_while_loop].copy()

    # Voeg de 'afstand in meters' toe uit de afstandsmatrix
    omloop_1_df = omloop_1_df.merge(
        df_afstandsmatrix[['code_afstand', 'afstand in meters']],
        left_on='code_omloop',
        right_on='code_afstand',
        how='left'
    )

    # Kies de juiste kolom na de merge
    omloop_1_df['afstand in meters'] = omloop_1_df['afstand in meters_y'].fillna(0)

    # Verwijder onnodige suffixed kolommen
    kolommen_verwijderen = ['afstand in meters_x', 'afstand in meters_y', 'code_afstand_x', 'code_afstand_y']
    bestaande_kolommen = [kolom for kolom in kolommen_verwijderen if kolom in omloop_1_df.columns]
    omloop_1_df.drop(columns=bestaande_kolommen, inplace=True)

    # Bereken de afstand in kilometers
    omloop_1_df['afstand in km'] = omloop_1_df['afstand in meters'] / 1000

    # Bereken batterijgebruik voor actieve activiteit
    omloop_1_df['Batterijgebruik'] = omloop_1_df['afstand in km'] * ENERGIE_VERBRUIK_PER_KM

    # Stel batterijgebruik in op 0.01 als de activiteit 'idle' is
    omloop_1_df.loc[omloop_1_df['activiteit'] == 'idle', 'Batterijgebruik'] = 0.01

    return omloop_1_df

def add_activiteit_column(df):
    """Voegt een 'activiteit' kolom toe gebaseerd op de aanwezigheid van een omloopnummer."""
    df['activiteit'] = df['Omloop'].apply(lambda x: 'dienstrit' if pd.notna(x) else 'geen dienst')
    return df

def add_idle_activity(df):
    """Voegt 'idle' activiteiten toe waar nodig."""
    rows_to_add = []

    # Sorteer het DataFrame op basis van vertrektijd, zodat ritten op volgorde worden verwerkt.
    df = df.sort_values(by='vertrek_datetime').reset_index(drop=True)

    for i in range(1, len(df)):
        vorige_rit = df.iloc[i - 1]
        huidige_rit = df.iloc[i]

        # Controleer beide datetimes en zorg dat de times valid zijn voor het bepalen van idle tijd
        if pd.notna(vorige_rit['aankomst_datetime']) and vorige_rit['aankomst_datetime'] < huidige_rit['vertrek_datetime']:
            idle_start = vorige_rit['aankomst_datetime']
            # Idle activiteit eindigt bij de start van de volgende rit
            idle_end = huidige_rit['vertrek_datetime']

            # Voeg een rij toe voor de "idle" periode
            rows_to_add.append({
                'startlocatie': vorige_rit['eindlocatie'],
                'eindlocatie': vorige_rit['eindlocatie'],
                'vertrek_datetime': idle_start,
                'aankomst_datetime': idle_end,
                'buslijn': '',
                'Omloop': vorige_rit['Omloop'],
                'activiteit': 'idle',
                'afstand in meters': 0,
                'afstand in km': 0,
                'Batterijgebruik': 0.01,
                 'code_omloop': str(huidige_rit['startlocatie']) + '_' + \
                                str(huidige_rit['startlocatie']) + '_' + \
                                str('Idle')
            })
            # Debug print om te zien welke idle rij toegevoegd is
            print(f"Idle added from {idle_start} to {idle_end}.")

    # Voeg de 'idle' rijen toe aan de DataFrame als er rijen zijn
    if rows_to_add:
        idle_df = pd.DataFrame(rows_to_add)
        df = pd.concat([df, idle_df], ignore_index=True)

    # Herverdeel de DataFrame om ervoor te zorgen dat alles op volgorde staat
    df = df.sort_values(by='vertrek_datetime').reset_index(drop=True)
    return df

def calculate_soc(df, initial_soc=243):
    """Voegt SOC_start en SOC_eind kolommen toe aan de DataFrame."""
    # Sorteren is belangrijk om juiste volgorde te behouden
    df = df.sort_values(['Omloop', 'vertrek_datetime']).reset_index(drop=True)

    # Initialiseren van de SOC kolommen
    df['SOC_start'] = 0.0
    df['SOC_eind'] = 0.0
    
    for omloop in df['Omloop'].unique():
        omloop_data = df[df['Omloop'] == omloop]
        prev_soc_eind = initial_soc
        
        for index, row in omloop_data.iterrows():
            if index == omloop_data.index[0]:  # Eerste rit van Omloop
                soc_start = initial_soc
            else:
                soc_start = prev_soc_eind

            # Bereken de SOC_eind
            soc_eind = soc_start - row['Batterijgebruik']

            # Update DataFrame
            df.at[index, 'SOC_start'] = soc_start
            df.at[index, 'SOC_eind'] = soc_eind

            # Update previous SOC_eind for next iteration
            prev_soc_eind = soc_eind

    return df

def manage_battery_and_charging(df, target_soc=243, drive_time=timedelta(minutes=4), charge_duration=timedelta(minutes=45)):
    """Laad de bus op als er een uur idle tijd is tussen de aankomst en het vertrek van ritten."""
    df = df.sort_values(['Omloop', 'vertrek_datetime']).reset_index(drop=True)
    adjusted_rows = []
    prev_soc_eind = target_soc  # Begin met volle lading

    # Default structure for a row
    default_row = {
        'startlocatie': None,
        'eindlocatie': None,
        'vertrektijd': None,
        'buslijn': None,
        'vertrek_datetime': None,
        'aankomst_datetime': None,
        'Omloop': None,
        'code_omloop': None,
        'activiteit': None,
        'afstand in km': None,
        'Batterijgebruik': None,
        'code_afstand': None,
        'afstand in meters': None,
        'SOC_start': None,
        'SOC_eind': None,
    }

    for index, row in df.iterrows():
        soc_start = prev_soc_eind if index != 0 else target_soc
        soc_eind = soc_start - row['Batterijgebruik']

        # Voeg de huidige rit toe
        adjusted_rows.append({
            **default_row,
            **row.to_dict(),
            'SOC_start': soc_start,
            'SOC_eind': soc_eind,
        })
        prev_soc_eind = soc_eind

        # Check of er een uur idle tijd is na deze rit
        if index < len(df) - 1:
            next_row = df.iloc[index + 1]

            # Bereken de idle tijd tussen de huidige aankomst en de volgende vertrek
            idle_time = next_row['vertrek_datetime'] - row['aankomst_datetime']

            # Als er voldoende idle tijd is
            if idle_time >= timedelta(hours=1):
                # Voeg materiaalrit naar garage toe
                to_garage_end_time = row['aankomst_datetime'] + drive_time
                adjusted_rows.append({
                    **default_row,
                    'startlocatie': row['eindlocatie'],
                    'eindlocatie': 'ehvgarage',
                    'vertrek_datetime': row['aankomst_datetime'],
                    'aankomst_datetime': to_garage_end_time,
                    'activiteit': 'materiaalrit',
                    'Batterijgebruik': 0.2,
                    'SOC_start': soc_eind,
                    'SOC_eind': soc_eind - 0.2,
                    'Omloop': row['Omloop']
                })

                # Laad de bus op
                charge_time_start = to_garage_end_time
                soc_charged = target_soc  # Doel SOC

                charge_time_end = charge_time_start + charge_duration
                adjusted_rows.append({
                    **default_row,
                    'startlocatie': 'ehvgarage',
                    'eindlocatie': 'ehvgarage',
                    'vertrek_datetime': charge_time_start,
                    'aankomst_datetime': charge_time_end,
                    'activiteit': 'opladen',
                    'Batterijgebruik': (soc_eind - 0.2 - soc_charged),  # Negatief om opladen aan te geven
                    'SOC_start': soc_eind - 0.2,
                    'SOC_eind': soc_charged,
                    'Omloop': row['Omloop']
                })

                # Materiaal rit terug naar de oorspronkelijke eindlocatie
                return_time = charge_time_end + drive_time
                adjusted_rows.append({
                    **default_row,
                    'startlocatie': 'ehvgarage',
                    'eindlocatie': row['eindlocatie'],
                    'vertrek_datetime': charge_time_end,
                    'aankomst_datetime': return_time,
                    'activiteit': 'materiaalrit',
                    'Batterijgebruik': 0.2,
                    'SOC_start': soc_charged,
                    'SOC_eind': soc_charged - 0.2,
                    'Omloop': row['Omloop']
                })

                prev_soc_eind = soc_charged - 0.2

    adjusted_df = pd.DataFrame(adjusted_rows)
    adjusted_df = adjusted_df.sort_values(by='vertrek_datetime').reset_index(drop=True)
    return adjusted_df

# Inladen van data
df_omloopplanning, df_dienstregeling, df_afstandsmatrix = load_data()

# Maak de parameters DataFrame en laat deze zien
df_parameters = create_parameters_df()
display(df_parameters)


omloopnummer_voor_de_while_loop = 1

## hier begint de while loop
# Verwerk dienstregeling en afstandsmatrix data
df_nieuwe_dienstregelingv2 = process_schedule_data(df_dienstregeling)
df_afstandsmatrix = process_distance_matrix(df_afstandsmatrix)

# Setting up the dataframes
df_nieuwe_dienstregelingv1 = setUpDataframes(df_nieuwe_dienstregelingv2, df_afstandsmatrix)

# Plan de busritten
df_processed_ritten = inplannen_busritten(df_nieuwe_dienstregelingv1, df_afstandsmatrix)

# Voer de functie uit na het verwerken van ritten
df_processed_ritten = add_activiteit_column(df_processed_ritten)

# Voeg de idle activiteiten in de verwerkte ritten toe
# Voer een test uit en controleer op output
df_with_idle = add_idle_activity(df_processed_ritten[df_processed_ritten['Omloop'] == omloopnummer_voor_de_while_loop])
# display(df_with_idle[df_with_idle['activiteit'] == 'idle'])
# display(df_with_idle.head(50))

# Filter en bereken
omloop_df = filter_and_calculate(df_with_idle, df_afstandsmatrix)

# Toevoegen van SOC kolommen aan de DataFrame met ritten
df_with_soc = calculate_soc(omloop_df)

# Filter out rows with 'idle' activity and simulate battery charging and material trips
df_filtered = df_with_soc[df_with_soc['activiteit'] != 'idle']
# display(df_filtered.head(50))
df_adjusted = manage_battery_and_charging(df_filtered)

##### Naam maken
df_name = f"df_omloopnummer_{omloopnummer_voor_de_while_loop}"
omloopnummersdf_dict = {}
omloopnummersdf_dict[df_name] = df_adjusted.copy()

# Weergeven van het resultaat
# display(df_omloopnummer_1)

# display(df_dienstregeling)

def get_remaining_rows(df_dienstregeling, df_adjusted):
    # Vervang NaN waarden door een standaardwaarde, bijvoorbeeld 0
    df_dienstregeling['buslijn'] = df_dienstregeling['buslijn'].fillna(0).astype(int)
    df_adjusted['buslijn'] = df_adjusted['buslijn'].fillna(0).astype(int)

    # Converteer tijden naar een gemeenschappelijke representatie voor vergelijking
    df_dienstregeling['vertrektijd'] = pd.to_datetime(df_dienstregeling['vertrektijd'], format='%H:%M', errors='coerce').dt.time
    df_adjusted['vertrek_datetime'] = pd.to_datetime(df_adjusted['vertrek_datetime'], errors='coerce').dt.time

    # Maakt strings voor vergelijking
    df_dienstregeling['compare_key'] = df_dienstregeling.apply(
        lambda x: f"{x['startlocatie']}|{x['eindlocatie']}|{x['vertrektijd']}|{x['buslijn']}", axis=1
    )
    df_adjusted['compare_key'] = df_adjusted.apply(
        lambda x: f"{x['startlocatie']}|{x['eindlocatie']}|{x['vertrek_datetime']}|{x['buslijn']}", axis=1
    )

    # Haal de compare_keys op die uniek zijn voor df_dienstregeling
    unique_keys = set(df_dienstregeling['compare_key']) - set(df_adjusted['compare_key'])

    # Filter rijen in df_dienstregeling die uniek zijn
    remaining_df = df_dienstregeling[df_dienstregeling['compare_key'].isin(unique_keys)].drop(columns=['compare_key'])
    
    return remaining_df

# Gebruik de functie om de resterende regels te krijgen
df_remaining = get_remaining_rows(df_dienstregeling, df_adjusted)

# Print de resultaten
print(f"Aantal regels in df_dienstregeling: {df_dienstregeling.shape[0]}")
print(f"Aantal regels in df_adjusted: {df_adjusted.shape[0]}")
print(f"Aantal regels in df_remaining: {df_remaining.shape[0]}")
df_dienstregeling = df_remaining.copy()



display(df_dienstregeling)
# Out:
#                  Parameter  Waarde           Eenheid
# 0  Max Batterij Capaciteit   300.0               kWh
# 1                SOC Start     0.9            Factor
# 2              SOC Minimum     0.1            Factor
# 3        Batterij Slijtage     0.9            Factor
# 4                      SOH   270.0     kW (MBC * BS)
# 5              SOC Ochtend   243.0  kW (SOH * SOC S)
# 6              SOC Minimum    27.0  kW (SOH * SOC M)
# 7          Batterijverbuik     1.2            kWh/km
# 8           Oplaadsnelheid   450.0           kWh/uur
# Iteration 1: Current time 2024-08-29 05:03:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2024-08-29 05:07:00, Current location ehvbst
# Assigning ride at index 163 to bus 1.
# Ride at index 163 arrives at: 2024-08-29 05:28:00
# Ride ends at 2024-08-29 05:28:00, new current location is ehvapt.
# Iteration 3: Current time 2024-08-29 05:28:00, Current location ehvapt
# Assigning ride at index 0 to bus 1.
# Ride at index 0 arrives at: 2024-08-29 06:25:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 06:25:00, new current location is ehvbst.
# Iteration 4: Current time 2024-08-29 06:25:00, Current location ehvbst
# Assigning ride at index 166 to bus 1.
# Ride at index 166 arrives at: 2024-08-29 06:52:00
# Ride ends at 2024-08-29 06:52:00, new current location is ehvapt.
# Iteration 5: Current time 2024-08-29 06:52:00, Current location ehvapt
# Assigning ride at index 2 to bus 1.
# Ride at index 2 arrives at: 2024-08-29 07:17:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 07:17:00, new current location is ehvbst.
# Iteration 6: Current time 2024-08-29 07:17:00, Current location ehvbst
# Assigning ride at index 170 to bus 1.
# Ride at index 170 arrives at: 2024-08-29 07:40:00
# Ride ends at 2024-08-29 07:40:00, new current location is ehvapt.
# Iteration 7: Current time 2024-08-29 07:40:00, Current location ehvapt
# Assigning ride at index 6 to bus 1.
# Ride at index 6 arrives at: 2024-08-29 08:07:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 08:07:00, new current location is ehvbst.
# Iteration 8: Current time 2024-08-29 08:07:00, Current location ehvbst
# Assigning ride at index 175 to bus 1.
# Ride at index 175 arrives at: 2024-08-29 08:30:00
# Ride ends at 2024-08-29 08:30:00, new current location is ehvapt.
# Iteration 9: Current time 2024-08-29 08:30:00, Current location ehvapt
# Assigning ride at index 93 to bus 1.
# Ride at index 93 arrives at: 2024-08-29 08:55:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 08:55:00, new current location is ehvbst.
# Iteration 10: Current time 2024-08-29 08:55:00, Current location ehvbst
# Assigning ride at index 180 to bus 1.
# Ride at index 180 arrives at: 2024-08-29 09:20:00
# Ride ends at 2024-08-29 09:20:00, new current location is ehvapt.
# Iteration 11: Current time 2024-08-29 09:20:00, Current location ehvapt
# Assigning ride at index 16 to bus 1.
# Ride at index 16 arrives at: 2024-08-29 09:47:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2024-08-29 09:47:00, new current location is ehvbst.
# Iteration 12: Current time 2024-08-29 09:47:00, Current location ehvbst
# Assigning ride at index 185 to bus 1.
# Ride at index 185 arrives at: 2024-08-29 10:10:00
# Ride ends at 2024-08-29 10:10:00, new current location is ehvapt.
# Iteration 13: Current time 2024-08-29 10:10:00, Current location ehvapt
# Assigning ride at index 21 to bus 1.
# Ride at index 21 arrives at: 2024-08-29 10:37:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2024-08-29 10:37:00, new current location is ehvbst.
# Iteration 14: Current time 2024-08-29 10:37:00, Current location ehvbst
# Assigning ride at index 190 to bus 1.
# Ride at index 190 arrives at: 2024-08-29 11:00:00
# Ride ends at 2024-08-29 11:00:00, new current location is ehvapt.
# Iteration 15: Current time 2024-08-29 11:00:00, Current location ehvapt
# Assigning ride at index 108 to bus 1.
# Ride at index 108 arrives at: 2024-08-29 11:25:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2024-08-29 11:25:00, new current location is ehvbst.
# Iteration 16: Current time 2024-08-29 11:25:00, Current location ehvbst
# Assigning ride at index 195 to bus 1.
# Ride at index 195 arrives at: 2024-08-29 11:50:00
# Ride ends at 2024-08-29 11:50:00, new current location is ehvapt.
# Iteration 17: Current time 2024-08-29 11:50:00, Current location ehvapt
# Assigning ride at index 31 to bus 1.
# Ride at index 31 arrives at: 2024-08-29 12:17:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 12:17:00, new current location is ehvbst.
# Iteration 18: Current time 2024-08-29 13:17:00, Current location ehvbst
# Assigning ride at index 206 to bus 1.
# Ride at index 206 arrives at: 2024-08-29 13:40:00
# Ride ends at 2024-08-29 13:40:00, new current location is ehvapt.
# Iteration 19: Current time 2024-08-29 13:40:00, Current location ehvapt
# Assigning ride at index 42 to bus 1.
# Ride at index 42 arrives at: 2024-08-29 14:07:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 14:07:00, new current location is ehvbst.
# Iteration 20: Current time 2024-08-29 14:07:00, Current location ehvbst
# Assigning ride at index 211 to bus 1.
# Ride at index 211 arrives at: 2024-08-29 14:30:00
# Ride ends at 2024-08-29 14:30:00, new current location is ehvapt.
# Iteration 21: Current time 2024-08-29 14:30:00, Current location ehvapt
# Assigning ride at index 129 to bus 1.
# Ride at index 129 arrives at: 2024-08-29 14:55:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 14:55:00, new current location is ehvbst.
# Iteration 22: Current time 2024-08-29 14:55:00, Current location ehvbst
# Assigning ride at index 216 to bus 1.
# Ride at index 216 arrives at: 2024-08-29 15:20:00
# Ride ends at 2024-08-29 15:20:00, new current location is ehvapt.
# Iteration 23: Current time 2024-08-29 15:20:00, Current location ehvapt
# Assigning ride at index 52 to bus 1.
# Ride at index 52 arrives at: 2024-08-29 15:47:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 15:47:00, new current location is ehvbst.
# Iteration 24: Current time 2024-08-29 15:47:00, Current location ehvbst
# Assigning ride at index 221 to bus 1.
# Ride at index 221 arrives at: 2024-08-29 16:10:00
# Ride ends at 2024-08-29 16:10:00, new current location is ehvapt.
# Iteration 25: Current time 2024-08-29 16:10:00, Current location ehvapt
# Assigning ride at index 57 to bus 1.
# Ride at index 57 arrives at: 2024-08-29 16:37:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 16:37:00, new current location is ehvbst.
# Iteration 26: Current time 2024-08-29 16:37:00, Current location ehvbst
# Assigning ride at index 226 to bus 1.
# Ride at index 226 arrives at: 2024-08-29 17:00:00
# Ride ends at 2024-08-29 17:00:00, new current location is ehvapt.
# Iteration 27: Current time 2024-08-29 17:00:00, Current location ehvapt
# Assigning ride at index 144 to bus 1.
# Ride at index 144 arrives at: 2024-08-29 17:25:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2024-08-29 17:25:00, new current location is ehvbst.
# Iteration 28: Current time 2024-08-29 17:25:00, Current location ehvbst
# Assigning ride at index 231 to bus 1.
# Ride at index 231 arrives at: 2024-08-29 17:50:00
# Ride ends at 2024-08-29 17:50:00, new current location is ehvapt.
# Iteration 29: Current time 2024-08-29 17:50:00, Current location ehvapt
# Assigning ride at index 67 to bus 1.
# Ride at index 67 arrives at: 2024-08-29 18:17:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2024-08-29 18:17:00, new current location is ehvbst.
# Iteration 30: Current time 2024-08-29 18:17:00, Current location ehvbst
# Assigning ride at index 319 to bus 1.
# Ride at index 319 arrives at: 2024-08-29 18:43:00
# Ride ends at 2024-08-29 18:43:00, new current location is ehvapt.
# Iteration 31: Current time 2024-08-29 18:43:00, Current location ehvapt
# Assigning ride at index 154 to bus 1.
# Ride at index 154 arrives at: 2024-08-29 19:10:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2024-08-29 19:10:00, new current location is ehvbst.
# Iteration 32: Current time 2024-08-29 19:10:00, Current location ehvbst
# Assigning ride at index 239 to bus 1.
# Ride at index 239 arrives at: 2024-08-29 19:35:00
# Ride ends at 2024-08-29 19:35:00, new current location is ehvapt.
# Iteration 33: Current time 2024-08-29 19:35:00, Current location ehvapt
# Assigning ride at index 75 to bus 1.
# Ride at index 75 arrives at: 2024-08-29 20:02:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 20:02:00, new current location is ehvbst.
# Iteration 34: Current time 2024-08-29 21:02:00, Current location ehvbst
# Assigning ride at index 245 to bus 1.
# Ride at index 245 arrives at: 2024-08-29 21:28:00
# Ride ends at 2024-08-29 21:28:00, new current location is ehvapt.
# Iteration 35: Current time 2024-08-29 21:28:00, Current location ehvapt
# Assigning ride at index 80 to bus 1.
# Ride at index 80 arrives at: 2024-08-29 21:56:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 21:56:00, new current location is ehvbst.
# Iteration 36: Current time 2024-08-29 21:56:00, Current location ehvbst
# Assigning ride at index 247 to bus 1.
# Ride at index 247 arrives at: 2024-08-29 22:28:00
# Ride ends at 2024-08-29 22:28:00, new current location is ehvapt.
# Iteration 37: Current time 2024-08-29 22:28:00, Current location ehvapt
# Assigning ride at index 82 to bus 1.
# Ride at index 82 arrives at: 2024-08-29 22:56:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 22:56:00, new current location is ehvbst.
# Iteration 38: Current time 2024-08-29 22:56:00, Current location ehvbst
# Assigning ride at index 249 to bus 1.
# Ride at index 249 arrives at: 2024-08-29 23:28:00
# Ride ends at 2024-08-29 23:28:00, new current location is ehvapt.
# Iteration 39: Current time 2024-08-29 23:28:00, Current location ehvapt
# Assigning ride at index 84 to bus 1.
# Ride at index 84 arrives at: 2024-08-29 23:56:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 23:56:00, new current location is ehvbst.
# Iteration 40: Current time 2024-08-29 23:56:00, Current location ehvbst
# Assigning ride at index 251 to bus 1.
# Ride at index 251 arrives at: 2024-08-30 00:30:00
# Ride ends at 2024-08-30 00:30:00, new current location is ehvapt.
# Iteration 41: Current time 2024-08-30 00:30:00, Current location ehvapt
# Assigning ride at index 86 to bus 1.
# Ride at index 86 arrives at: 2024-08-30 00:52:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-30 00:52:00, new current location is ehvbst.
# Iteration 42: Current time 2024-08-30 00:52:00, Current location ehvbst
# No more rides available, terminating loop.
# Idle added from 2024-08-29 05:28:00 to 2024-08-29 06:04:00.
# Idle added from 2024-08-29 06:25:00 to 2024-08-29 06:31:00.
# Idle added from 2024-08-29 06:52:00 to 2024-08-29 06:56:00.
# Idle added from 2024-08-29 07:17:00 to 2024-08-29 07:19:00.
# Idle added from 2024-08-29 07:40:00 to 2024-08-29 07:46:00.
# Idle added from 2024-08-29 08:07:00 to 2024-08-29 08:09:00.
# Idle added from 2024-08-29 08:30:00 to 2024-08-29 08:34:00.
# Idle added from 2024-08-29 08:55:00 to 2024-08-29 08:59:00.
# Idle added from 2024-08-29 09:20:00 to 2024-08-29 09:26:00.
# Idle added from 2024-08-29 09:47:00 to 2024-08-29 09:49:00.
# Idle added from 2024-08-29 10:10:00 to 2024-08-29 10:16:00.
# Idle added from 2024-08-29 10:37:00 to 2024-08-29 10:39:00.
# Idle added from 2024-08-29 11:00:00 to 2024-08-29 11:04:00.
# Idle added from 2024-08-29 11:25:00 to 2024-08-29 11:29:00.
# Idle added from 2024-08-29 11:50:00 to 2024-08-29 11:56:00.
# Idle added from 2024-08-29 12:17:00 to 2024-08-29 13:19:00.
# Idle added from 2024-08-29 13:40:00 to 2024-08-29 13:46:00.
# Idle added from 2024-08-29 14:07:00 to 2024-08-29 14:09:00.
# Idle added from 2024-08-29 14:30:00 to 2024-08-29 14:34:00.
# Idle added from 2024-08-29 14:55:00 to 2024-08-29 14:59:00.
# Idle added from 2024-08-29 15:20:00 to 2024-08-29 15:26:00.
# Idle added from 2024-08-29 15:47:00 to 2024-08-29 15:49:00.
# Idle added from 2024-08-29 16:10:00 to 2024-08-29 16:16:00.
# Idle added from 2024-08-29 16:37:00 to 2024-08-29 16:39:00.
# Idle added from 2024-08-29 17:00:00 to 2024-08-29 17:04:00.
# Idle added from 2024-08-29 17:25:00 to 2024-08-29 17:29:00.
# Idle added from 2024-08-29 17:50:00 to 2024-08-29 17:56:00.
# Idle added from 2024-08-29 18:17:00 to 2024-08-29 18:22:00.
# Idle added from 2024-08-29 18:43:00 to 2024-08-29 18:49:00.
# Idle added from 2024-08-29 19:10:00 to 2024-08-29 19:14:00.
# Idle added from 2024-08-29 19:35:00 to 2024-08-29 19:41:00.
# Idle added from 2024-08-29 20:02:00 to 2024-08-29 21:07:00.
# Idle added from 2024-08-29 21:28:00 to 2024-08-29 21:35:00.
# Idle added from 2024-08-29 21:56:00 to 2024-08-29 22:07:00.
# Idle added from 2024-08-29 22:28:00 to 2024-08-29 22:35:00.
# Idle added from 2024-08-29 22:56:00 to 2024-08-29 23:07:00.
# Idle added from 2024-08-29 23:28:00 to 2024-08-29 23:35:00.
# Idle added from 2024-08-29 23:56:00 to 2024-08-30 00:09:00.
# Idle added from 2024-08-30 00:30:00 to 2024-08-30 00:31:00.
# Aantal regels in df_dienstregeling: 327
# Aantal regels in df_adjusted: 46
# Aantal regels in df_remaining: 287
#     startlocatie vertrektijd eindlocatie  buslijn
# 1         ehvapt    06:34:00      ehvbst      401
# 3         ehvapt    07:11:00      ehvbst      401
# 4         ehvapt    07:26:00      ehvbst      401
# 5         ehvapt    07:36:00      ehvbst      401
# 7         ehvapt    07:56:00      ehvbst      401
# ..           ...         ...         ...      ...
# 322       ehvbst    18:52:00      ehvapt      400
# 323       ehvbst    18:54:00      ehvapt      400
# 324       ehvbst    19:07:00      ehvapt      400
# 325       ehvbst    19:22:00      ehvapt      400
# 326       ehvbst    19:37:00      ehvapt      400
#
# [287 rows x 4 columns]

# %% [markdown]
# ## Omloopnummer 2 met aangepaste functies

# %%
def process_schedule_data(df_dienstregeling):
    """Functie om de nieuwe dienstregeling te verwerken."""
    df = df_dienstregeling.copy()
    
    # Vervang NaN door een standaardwaarde voordat je de conversie uitvoert
    df['buslijn'] = df['buslijn'].fillna(0).astype(int).astype(str)

    # Converteer de 'vertrektijd' kolom naar string en behandel eventuele NaT/Nan
    df['vertrektijd'] = df['vertrektijd'].fillna('').astype(str)

    # Controleer of er extra whitespace of tekens zijn die moeten worden gestript
    df['vertrektijd'] = df['vertrektijd'].str.strip().str.replace(r':\d{2}$', '', regex=True)

    df['vertrek_datetime'] = df['vertrektijd'].apply(convert_to_datetime)  # Zorg dat deze functie goed omgaat met niet-conforme tijden
    df['Omloop'] = 0
    df_sorted = df.sort_values(by=['vertrek_datetime', 'buslijn'])
    df_sorted['code_omloop'] = df_sorted['startlocatie'].str.strip().str.lower() + '_' + \
                               df_sorted['eindlocatie'].str.strip().str.lower() + '_' + \
                               df_sorted['buslijn']
    return df_sorted

def convert_to_datetime(time_str):
    try:
        return pd.to_datetime(time_str, format='%H:%M', errors='coerce').time()
    except ValueError:
        print(f"Could not parse time: {time_str}")
        return None
    
def setUpDataframes(df_nieuwe_dienstregelingv2, df_afstandsmatrix):
    """Kopieer en bereid dataframes voor gebruik voor de inplanting."""
    df = df_nieuwe_dienstregelingv2.copy()

    # Zet een vaste referentiedatum, bijvoorbeeld 1 januari 2023
    referentie_datum = pd.Timestamp('2023-01-01')

    # Combineer de referentiedatum met de vertrektijd om een volledige datetime te krijgen
    df['vertrek_datetime'] = df['vertrek_datetime'].apply(lambda x: pd.Timestamp.combine(referentie_datum.date(), x) if pd.notnull(x) else pd.NaT)

    df['aankomst_datetime'] = pd.NaT
    df['Omloop'] = pd.NA
    return df

def get_verschillende_rij(df_dienstregeling, df_aangepast):
    # Verwijder rijen met missende waarden en maak een kopie
    df_dienstregeling = df_dienstregeling.dropna(subset=['startlocatie', 'eindlocatie', 'vertrektijd', 'buslijn']).copy()
    df_aangepast = df_aangepast.dropna(subset=['startlocatie', 'eindlocatie', 'vertrek_datetime', 'buslijn']).copy()

    # Zorgvuldig typecasting met debug printen
    df_dienstregeling['buslijn'] = df_dienstregeling['buslijn'].fillna(0).astype(int)
    df_aangepast['buslijn'] = df_aangepast['buslijn'].fillna(0).astype(int)

    # Converteer tijden: met gecontroleerde tijd parsering
    df_dienstregeling['vertrektijd'] = pd.to_datetime(
        df_dienstregeling['vertrektijd'], format='%H:%M:%S', errors='coerce'
    ).dt.time

    df_aangepast['vertrek_datetime'] = pd.to_datetime(
        df_aangepast['vertrek_datetime'], errors='coerce'
    ).dt.time

    # Strip strings en creëer vergelijkingssleutels
    df_dienstregeling['vergelijk_sleutel'] = df_dienstregeling.apply(
        lambda x: f"{x['startlocatie'].strip()}|{x['eindlocatie'].strip()}|{x['vertrektijd']}|{x['buslijn']}", axis=1
    )
    df_aangepast['vergelijk_sleutel'] = df_aangepast.apply(
        lambda x: f"{x['startlocatie'].strip()}|{x['eindlocatie'].strip()}|{x['vertrek_datetime']}|{x['buslijn']}", axis=1
    )

    # Print aantal unieke sleutels voor debugging
    print(f"Unieke vergelijkingssleutels in df_dienstregeling: {len(df_dienstregeling['vergelijk_sleutel'].unique())}")
    print(f"Unieke vergelijkingssleutels in df_aangepast: {len(df_aangepast['vergelijk_sleutel'].unique())}")

    # Vind unieke vergelijkingssleutels voor df_dienstregeling
    unieke_sleutels = set(df_dienstregeling['vergelijk_sleutel']) - set(df_aangepast['vergelijk_sleutel'])

    # Filteren en teruggeven van de overgebleven datarijen
    overgebleven_df = df_dienstregeling[df_dienstregeling['vergelijk_sleutel'].isin(unieke_sleutels)].drop(columns=['vergelijk_sleutel'])
    
    return overgebleven_df

omloopnummer_voor_de_while_loop = 2
count_ehvbst = 0

## hier begint de while loop
# Verwerk dienstregeling en afstandsmatrix data
df_nieuwe_dienstregelingv2 = process_schedule_data(df_dienstregeling)
df_afstandsmatrix = process_distance_matrix(df_afstandsmatrix)

# Setting up the dataframes
df_nieuwe_dienstregelingv1 = setUpDataframes(df_nieuwe_dienstregelingv2, df_afstandsmatrix)

# Plan de busritten
df_processed_ritten = inplannen_busritten(df_nieuwe_dienstregelingv1, df_afstandsmatrix)

# Voer de functie uit na het verwerken van ritten
df_processed_ritten = add_activiteit_column(df_processed_ritten)

# Voeg de idle activiteiten in de verwerkte ritten toe
# Voer een test uit en controleer op output
df_with_idle = add_idle_activity(df_processed_ritten[df_processed_ritten['Omloop'] == omloopnummer_voor_de_while_loop])
# display(df_with_idle[df_with_idle['activiteit'] == 'idle'])
# display(df_with_idle.head(50))

# Filter en bereken
omloop_df = filter_and_calculate(df_with_idle, df_afstandsmatrix)

# Toevoegen van SOC kolommen aan de DataFrame met ritten
df_with_soc = calculate_soc(omloop_df)

# Filter out rows with 'idle' activity and simulate battery charging and material trips
df_filtered = df_with_soc[df_with_soc['activiteit'] != 'idle']
# display(df_filtered.head(50))
df_adjusted = manage_battery_and_charging(df_filtered)

##### Naam maken
df_name = f"df_omloopnummer_{omloopnummer_voor_de_while_loop}"
omloopnummersdf_dict[df_name] = df_adjusted.copy()
# display(df_adjusted)

# Gebruik de functie voor de resterende regels
df_overgebleven = get_verschillende_rij(df_dienstregeling, df_adjusted)

# Print resultaten
print(f"Aantal regels in df_dienstregeling: {df_dienstregeling.shape[0]}")
print(f"Aantal regels in df_aangepast: {df_adjusted.shape[0]}")
print(f"Aantal regels in df_overgebleven: {df_overgebleven.shape[0]}")

display(df_overgebleven)

omloopnummer_voor_de_while_loop = 3
# Out:
# Iteration 1: Current time 2022-12-31 23:57:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2023-01-01 00:01:00, Current location ehvbst
# Assigning ride at index 164 to bus 2.
# Ride at index 164 arrives at: 2023-01-01 05:58:00
# Ride ends at 2023-01-01 05:58:00, new current location is ehvapt.
# Iteration 3: Current time 2023-01-01 05:58:00, Current location ehvapt
# Assigning ride at index 1 to bus 2.
# Ride at index 1 arrives at: 2023-01-01 06:55:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 06:55:00, new current location is ehvbst.
# Iteration 4: Current time 2023-01-01 06:55:00, Current location ehvbst
# Assigning ride at index 168 to bus 2.
# Ride at index 168 arrives at: 2023-01-01 07:20:00
# Ride ends at 2023-01-01 07:20:00, new current location is ehvapt.
# Iteration 5: Current time 2023-01-01 07:20:00, Current location ehvapt
# Assigning ride at index 4 to bus 2.
# Ride at index 4 arrives at: 2023-01-01 07:47:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 07:47:00, new current location is ehvbst.
# Iteration 6: Current time 2023-01-01 07:47:00, Current location ehvbst
# Assigning ride at index 173 to bus 2.
# Ride at index 173 arrives at: 2023-01-01 08:10:00
# Ride ends at 2023-01-01 08:10:00, new current location is ehvapt.
# Iteration 7: Current time 2023-01-01 08:10:00, Current location ehvapt
# Assigning ride at index 9 to bus 2.
# Ride at index 9 arrives at: 2023-01-01 08:37:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 08:37:00, new current location is ehvbst.
# Iteration 8: Current time 2023-01-01 08:37:00, Current location ehvbst
# Assigning ride at index 178 to bus 2.
# Ride at index 178 arrives at: 2023-01-01 09:00:00
# Ride ends at 2023-01-01 09:00:00, new current location is ehvapt.
# Iteration 9: Current time 2023-01-01 09:00:00, Current location ehvapt
# Assigning ride at index 96 to bus 2.
# Ride at index 96 arrives at: 2023-01-01 09:25:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 09:25:00, new current location is ehvbst.
# Iteration 10: Current time 2023-01-01 09:25:00, Current location ehvbst
# Assigning ride at index 183 to bus 2.
# Ride at index 183 arrives at: 2023-01-01 09:50:00
# Ride ends at 2023-01-01 09:50:00, new current location is ehvapt.
# Iteration 11: Current time 2023-01-01 09:50:00, Current location ehvapt
# Assigning ride at index 19 to bus 2.
# Ride at index 19 arrives at: 2023-01-01 10:17:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 10:17:00, new current location is ehvbst.
# Iteration 12: Current time 2023-01-01 10:17:00, Current location ehvbst
# Assigning ride at index 188 to bus 2.
# Ride at index 188 arrives at: 2023-01-01 10:40:00
# Ride ends at 2023-01-01 10:40:00, new current location is ehvapt.
# Iteration 13: Current time 2023-01-01 10:40:00, Current location ehvapt
# Assigning ride at index 24 to bus 2.
# Ride at index 24 arrives at: 2023-01-01 11:07:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2023-01-01 11:07:00, new current location is ehvbst.
# Iteration 14: Current time 2023-01-01 11:07:00, Current location ehvbst
# Assigning ride at index 193 to bus 2.
# Ride at index 193 arrives at: 2023-01-01 11:30:00
# Ride ends at 2023-01-01 11:30:00, new current location is ehvapt.
# Iteration 15: Current time 2023-01-01 11:30:00, Current location ehvapt
# Assigning ride at index 111 to bus 2.
# Ride at index 111 arrives at: 2023-01-01 11:55:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2023-01-01 11:55:00, new current location is ehvbst.
# Iteration 16: Current time 2023-01-01 11:55:00, Current location ehvbst
# Assigning ride at index 198 to bus 2.
# Ride at index 198 arrives at: 2023-01-01 12:20:00
# Ride ends at 2023-01-01 12:20:00, new current location is ehvapt.
# Iteration 17: Current time 2023-01-01 12:20:00, Current location ehvapt
# Assigning ride at index 34 to bus 2.
# Ride at index 34 arrives at: 2023-01-01 12:47:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2023-01-01 12:47:00, new current location is ehvbst.
# Iteration 18: Current time 2023-01-01 13:47:00, Current location ehvbst
# Assigning ride at index 209 to bus 2.
# Ride at index 209 arrives at: 2023-01-01 14:10:00
# Ride ends at 2023-01-01 14:10:00, new current location is ehvapt.
# Iteration 19: Current time 2023-01-01 14:10:00, Current location ehvapt
# Assigning ride at index 45 to bus 2.
# Ride at index 45 arrives at: 2023-01-01 14:37:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 14:37:00, new current location is ehvbst.
# Iteration 20: Current time 2023-01-01 14:37:00, Current location ehvbst
# Assigning ride at index 214 to bus 2.
# Ride at index 214 arrives at: 2023-01-01 15:00:00
# Ride ends at 2023-01-01 15:00:00, new current location is ehvapt.
# Iteration 21: Current time 2023-01-01 15:00:00, Current location ehvapt
# Assigning ride at index 132 to bus 2.
# Ride at index 132 arrives at: 2023-01-01 15:25:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 15:25:00, new current location is ehvbst.
# Iteration 22: Current time 2023-01-01 15:25:00, Current location ehvbst
# Assigning ride at index 219 to bus 2.
# Ride at index 219 arrives at: 2023-01-01 15:50:00
# Ride ends at 2023-01-01 15:50:00, new current location is ehvapt.
# Iteration 23: Current time 2023-01-01 15:50:00, Current location ehvapt
# Assigning ride at index 55 to bus 2.
# Ride at index 55 arrives at: 2023-01-01 16:17:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 16:17:00, new current location is ehvbst.
# Iteration 24: Current time 2023-01-01 16:17:00, Current location ehvbst
# Assigning ride at index 224 to bus 2.
# Ride at index 224 arrives at: 2023-01-01 16:40:00
# Ride ends at 2023-01-01 16:40:00, new current location is ehvapt.
# Iteration 25: Current time 2023-01-01 16:40:00, Current location ehvapt
# Assigning ride at index 60 to bus 2.
# Ride at index 60 arrives at: 2023-01-01 17:07:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 17:07:00, new current location is ehvbst.
# Iteration 26: Current time 2023-01-01 17:07:00, Current location ehvbst
# Assigning ride at index 229 to bus 2.
# Ride at index 229 arrives at: 2023-01-01 17:30:00
# Ride ends at 2023-01-01 17:30:00, new current location is ehvapt.
# Iteration 27: Current time 2023-01-01 17:30:00, Current location ehvapt
# Assigning ride at index 147 to bus 2.
# Ride at index 147 arrives at: 2023-01-01 17:55:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 17:55:00, new current location is ehvbst.
# Iteration 28: Current time 2023-01-01 17:55:00, Current location ehvbst
# Assigning ride at index 234 to bus 2.
# Ride at index 234 arrives at: 2023-01-01 18:20:00
# Ride ends at 2023-01-01 18:20:00, new current location is ehvapt.
# Iteration 29: Current time 2023-01-01 18:20:00, Current location ehvapt
# Assigning ride at index 70 to bus 2.
# Ride at index 70 arrives at: 2023-01-01 18:47:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2023-01-01 18:47:00, new current location is ehvbst.
# Iteration 30: Current time 2023-01-01 18:47:00, Current location ehvbst
# Assigning ride at index 322 to bus 2.
# Ride at index 322 arrives at: 2023-01-01 19:13:00
# Ride ends at 2023-01-01 19:13:00, new current location is ehvapt.
# Iteration 31: Current time 2023-01-01 19:13:00, Current location ehvapt
# Assigning ride at index 157 to bus 2.
# Ride at index 157 arrives at: 2023-01-01 19:40:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2023-01-01 19:40:00, new current location is ehvbst.
# Iteration 32: Current time 2023-01-01 19:40:00, Current location ehvbst
# Assigning ride at index 241 to bus 2.
# Ride at index 241 arrives at: 2023-01-01 20:05:00
# Ride ends at 2023-01-01 20:05:00, new current location is ehvapt.
# Iteration 33: Current time 2023-01-01 20:05:00, Current location ehvapt
# Assigning ride at index 77 to bus 2.
# Ride at index 77 arrives at: 2023-01-01 20:32:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2023-01-01 20:32:00, new current location is ehvbst.
# Iteration 34: Current time 2023-01-01 21:32:00, Current location ehvbst
# Assigning ride at index 246 to bus 2.
# Ride at index 246 arrives at: 2023-01-01 21:58:00
# Ride ends at 2023-01-01 21:58:00, new current location is ehvapt.
# Iteration 35: Current time 2023-01-01 21:58:00, Current location ehvapt
# Assigning ride at index 81 to bus 2.
# Ride at index 81 arrives at: 2023-01-01 22:26:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 22:26:00, new current location is ehvbst.
# Iteration 36: Current time 2023-01-01 22:26:00, Current location ehvbst
# Assigning ride at index 248 to bus 2.
# Ride at index 248 arrives at: 2023-01-01 22:58:00
# Ride ends at 2023-01-01 22:58:00, new current location is ehvapt.
# Iteration 37: Current time 2023-01-01 22:58:00, Current location ehvapt
# Assigning ride at index 83 to bus 2.
# Ride at index 83 arrives at: 2023-01-01 23:26:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 23:26:00, new current location is ehvbst.
# Iteration 38: Current time 2023-01-01 23:26:00, Current location ehvbst
# Assigning ride at index 250 to bus 2.
# Ride at index 250 arrives at: 2023-01-01 23:58:00
# Ride ends at 2023-01-01 23:58:00, new current location is ehvapt.
# Iteration 39: Current time 2023-01-01 23:58:00, Current location ehvapt
# No more rides available, terminating loop.
# Idle added from 2023-01-01 05:58:00 to 2023-01-01 06:34:00.
# Idle added from 2023-01-01 06:55:00 to 2023-01-01 06:59:00.
# Idle added from 2023-01-01 07:20:00 to 2023-01-01 07:26:00.
# Idle added from 2023-01-01 07:47:00 to 2023-01-01 07:49:00.
# Idle added from 2023-01-01 08:10:00 to 2023-01-01 08:16:00.
# Idle added from 2023-01-01 08:37:00 to 2023-01-01 08:39:00.
# Idle added from 2023-01-01 09:00:00 to 2023-01-01 09:04:00.
# Idle added from 2023-01-01 09:25:00 to 2023-01-01 09:29:00.
# Idle added from 2023-01-01 09:50:00 to 2023-01-01 09:56:00.
# Idle added from 2023-01-01 10:17:00 to 2023-01-01 10:19:00.
# Idle added from 2023-01-01 10:40:00 to 2023-01-01 10:46:00.
# Idle added from 2023-01-01 11:07:00 to 2023-01-01 11:09:00.
# Idle added from 2023-01-01 11:30:00 to 2023-01-01 11:34:00.
# Idle added from 2023-01-01 11:55:00 to 2023-01-01 11:59:00.
# Idle added from 2023-01-01 12:20:00 to 2023-01-01 12:26:00.
# Idle added from 2023-01-01 12:47:00 to 2023-01-01 13:49:00.
# Idle added from 2023-01-01 14:10:00 to 2023-01-01 14:16:00.
# Idle added from 2023-01-01 14:37:00 to 2023-01-01 14:39:00.
# Idle added from 2023-01-01 15:00:00 to 2023-01-01 15:04:00.
# Idle added from 2023-01-01 15:25:00 to 2023-01-01 15:29:00.
# Idle added from 2023-01-01 15:50:00 to 2023-01-01 15:56:00.
# Idle added from 2023-01-01 16:17:00 to 2023-01-01 16:19:00.
# Idle added from 2023-01-01 16:40:00 to 2023-01-01 16:46:00.
# Idle added from 2023-01-01 17:07:00 to 2023-01-01 17:09:00.
# Idle added from 2023-01-01 17:30:00 to 2023-01-01 17:34:00.
# Idle added from 2023-01-01 17:55:00 to 2023-01-01 17:59:00.
# Idle added from 2023-01-01 18:20:00 to 2023-01-01 18:26:00.
# Idle added from 2023-01-01 18:47:00 to 2023-01-01 18:52:00.
# Idle added from 2023-01-01 19:13:00 to 2023-01-01 19:19:00.
# Idle added from 2023-01-01 19:40:00 to 2023-01-01 19:44:00.
# Idle added from 2023-01-01 20:05:00 to 2023-01-01 20:11:00.
# Idle added from 2023-01-01 20:32:00 to 2023-01-01 21:37:00.
# Idle added from 2023-01-01 21:58:00 to 2023-01-01 22:05:00.
# Idle added from 2023-01-01 22:26:00 to 2023-01-01 22:37:00.
# Idle added from 2023-01-01 22:58:00 to 2023-01-01 23:05:00.
# Idle added from 2023-01-01 23:26:00 to 2023-01-01 23:37:00.
# Unieke vergelijkingssleutels in df_dienstregeling: 287
# Unieke vergelijkingssleutels in df_aangepast: 37
# Aantal regels in df_dienstregeling: 287
# Aantal regels in df_aangepast: 43
# Aantal regels in df_overgebleven: 250
#     startlocatie vertrektijd eindlocatie  buslijn
# 3         ehvapt    07:11:00      ehvbst      401
# 5         ehvapt    07:36:00      ehvbst      401
# 7         ehvapt    07:56:00      ehvbst      401
# 8         ehvapt    08:06:00      ehvbst      401
# 10        ehvapt    08:26:00      ehvbst      401
# ..           ...         ...         ...      ...
# 321       ehvbst    18:37:00      ehvapt      400
# 323       ehvbst    18:54:00      ehvapt      400
# 324       ehvbst    19:07:00      ehvapt      400
# 325       ehvbst    19:22:00      ehvapt      400
# 326       ehvbst    19:37:00      ehvapt      400
#
# [250 rows x 4 columns]

# %% [markdown]
# ## De rest van de omloopnummers met een while loop (geeft altijd error bij leeg df)

# %%
while not df_dienstregeling.empty or omloopnummer_voor_de_while_loop != 21:
    count_ehvbst = 0
    # Verwerk dienstregeling en afstandsmatrix data
    df_nieuwe_dienstregelingv2 = process_schedule_data(df_dienstregeling)
    df_afstandsmatrix = process_distance_matrix(df_afstandsmatrix)

    # Setting up the dataframes
    df_nieuwe_dienstregelingv1 = setUpDataframes(df_nieuwe_dienstregelingv2, df_afstandsmatrix)

    # Plan de busritten
    df_processed_ritten = inplannen_busritten(df_nieuwe_dienstregelingv1, df_afstandsmatrix)

    # Voer de functie uit na het verwerken van ritten
    df_processed_ritten = add_activiteit_column(df_processed_ritten)

    # Voeg de idle activiteiten in de verwerkte ritten toe
    df_with_idle = add_idle_activity(df_processed_ritten[df_processed_ritten['Omloop'] == omloopnummer_voor_de_while_loop])

    # Filter en bereken
    omloop_df = filter_and_calculate(df_with_idle, df_afstandsmatrix)

    # Toevoegen van SOC kolommen aan de DataFrame met ritten
    df_with_soc = calculate_soc(omloop_df)

    # Filter out rows with 'idle' activity and simulate battery charging and material trips
    df_filtered = df_with_soc[df_with_soc['activiteit'] != 'idle']
    df_adjusted = manage_battery_and_charging(df_filtered)

    # Naam maken voor de dictionary
    df_name = f"df_omloopnummer_{omloopnummer_voor_de_while_loop}"
    omloopnummersdf_dict[df_name] = df_adjusted.copy()

    # Gebruik de functie voor de resterende regels
    df_overgebleven = get_verschillende_rij(df_dienstregeling, df_adjusted)

    # Print resultaten
    print(f"Aantal regels in df_dienstregeling: {df_dienstregeling.shape[0]}")
    print(f"Aantal regels in df_aangepast: {df_adjusted.shape[0]}")
    print(f"Aantal regels in df_overgebleven: {df_overgebleven.shape[0]}")
    
    # Display results for inspection
    # display(df_overgebleven)

    # Update the loop variable and dataframe for the next iteration
    df_dienstregeling = df_overgebleven
    omloopnummer_voor_de_while_loop += 1

    # if len(omloopnummersdf_dict[df_name]) == 2:
    #     break
# Out:
# Iteration 1: Current time 2022-12-31 23:57:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2023-01-01 00:01:00, Current location ehvbst
# Assigning ride at index 164 to bus 3.
# Ride at index 164 arrives at: 2023-01-01 05:58:00
# Ride ends at 2023-01-01 05:58:00, new current location is ehvapt.
# Iteration 3: Current time 2023-01-01 05:58:00, Current location ehvapt
# Assigning ride at index 1 to bus 3.
# Ride at index 1 arrives at: 2023-01-01 06:55:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 06:55:00, new current location is ehvbst.
# Iteration 4: Current time 2023-01-01 06:55:00, Current location ehvbst
# Assigning ride at index 168 to bus 3.
# Ride at index 168 arrives at: 2023-01-01 07:20:00
# Ride ends at 2023-01-01 07:20:00, new current location is ehvapt.
# Iteration 5: Current time 2023-01-01 07:20:00, Current location ehvapt
# Assigning ride at index 4 to bus 3.
# Ride at index 4 arrives at: 2023-01-01 07:47:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 07:47:00, new current location is ehvbst.
# Iteration 6: Current time 2023-01-01 07:47:00, Current location ehvbst
# Assigning ride at index 173 to bus 3.
# Ride at index 173 arrives at: 2023-01-01 08:10:00
# Ride ends at 2023-01-01 08:10:00, new current location is ehvapt.
# Iteration 7: Current time 2023-01-01 08:10:00, Current location ehvapt
# Assigning ride at index 9 to bus 3.
# Ride at index 9 arrives at: 2023-01-01 08:37:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 08:37:00, new current location is ehvbst.
# Iteration 8: Current time 2023-01-01 08:37:00, Current location ehvbst
# Assigning ride at index 178 to bus 3.
# Ride at index 178 arrives at: 2023-01-01 09:00:00
# Ride ends at 2023-01-01 09:00:00, new current location is ehvapt.
# Iteration 9: Current time 2023-01-01 09:00:00, Current location ehvapt
# Assigning ride at index 96 to bus 3.
# Ride at index 96 arrives at: 2023-01-01 09:25:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 09:25:00, new current location is ehvbst.
# Iteration 10: Current time 2023-01-01 09:25:00, Current location ehvbst
# Assigning ride at index 183 to bus 3.
# Ride at index 183 arrives at: 2023-01-01 09:50:00
# Ride ends at 2023-01-01 09:50:00, new current location is ehvapt.
# Iteration 11: Current time 2023-01-01 09:50:00, Current location ehvapt
# Assigning ride at index 19 to bus 3.
# Ride at index 19 arrives at: 2023-01-01 10:17:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 10:17:00, new current location is ehvbst.
# Iteration 12: Current time 2023-01-01 10:17:00, Current location ehvbst
# Assigning ride at index 188 to bus 3.
# Ride at index 188 arrives at: 2023-01-01 10:40:00
# Ride ends at 2023-01-01 10:40:00, new current location is ehvapt.
# Iteration 13: Current time 2023-01-01 10:40:00, Current location ehvapt
# Assigning ride at index 24 to bus 3.
# Ride at index 24 arrives at: 2023-01-01 11:07:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2023-01-01 11:07:00, new current location is ehvbst.
# Iteration 14: Current time 2023-01-01 11:07:00, Current location ehvbst
# Assigning ride at index 193 to bus 3.
# Ride at index 193 arrives at: 2023-01-01 11:30:00
# Ride ends at 2023-01-01 11:30:00, new current location is ehvapt.
# Iteration 15: Current time 2023-01-01 11:30:00, Current location ehvapt
# Assigning ride at index 111 to bus 3.
# Ride at index 111 arrives at: 2023-01-01 11:55:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2023-01-01 11:55:00, new current location is ehvbst.
# Iteration 16: Current time 2023-01-01 11:55:00, Current location ehvbst
# Assigning ride at index 198 to bus 3.
# Ride at index 198 arrives at: 2023-01-01 12:20:00
# Ride ends at 2023-01-01 12:20:00, new current location is ehvapt.
# Iteration 17: Current time 2023-01-01 12:20:00, Current location ehvapt
# Assigning ride at index 34 to bus 3.
# Ride at index 34 arrives at: 2023-01-01 12:47:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2023-01-01 12:47:00, new current location is ehvbst.
# Iteration 18: Current time 2023-01-01 13:47:00, Current location ehvbst
# Assigning ride at index 209 to bus 3.
# Ride at index 209 arrives at: 2023-01-01 14:10:00
# Ride ends at 2023-01-01 14:10:00, new current location is ehvapt.
# Iteration 19: Current time 2023-01-01 14:10:00, Current location ehvapt
# Assigning ride at index 45 to bus 3.
# Ride at index 45 arrives at: 2023-01-01 14:37:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 14:37:00, new current location is ehvbst.
# Iteration 20: Current time 2023-01-01 14:37:00, Current location ehvbst
# Assigning ride at index 214 to bus 3.
# Ride at index 214 arrives at: 2023-01-01 15:00:00
# Ride ends at 2023-01-01 15:00:00, new current location is ehvapt.
# Iteration 21: Current time 2023-01-01 15:00:00, Current location ehvapt
# Assigning ride at index 132 to bus 3.
# Ride at index 132 arrives at: 2023-01-01 15:25:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 15:25:00, new current location is ehvbst.
# Iteration 22: Current time 2023-01-01 15:25:00, Current location ehvbst
# Assigning ride at index 219 to bus 3.
# Ride at index 219 arrives at: 2023-01-01 15:50:00
# Ride ends at 2023-01-01 15:50:00, new current location is ehvapt.
# Iteration 23: Current time 2023-01-01 15:50:00, Current location ehvapt
# Assigning ride at index 55 to bus 3.
# Ride at index 55 arrives at: 2023-01-01 16:17:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 16:17:00, new current location is ehvbst.
# Iteration 24: Current time 2023-01-01 16:17:00, Current location ehvbst
# Assigning ride at index 224 to bus 3.
# Ride at index 224 arrives at: 2023-01-01 16:40:00
# Ride ends at 2023-01-01 16:40:00, new current location is ehvapt.
# Iteration 25: Current time 2023-01-01 16:40:00, Current location ehvapt
# Assigning ride at index 60 to bus 3.
# Ride at index 60 arrives at: 2023-01-01 17:07:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 17:07:00, new current location is ehvbst.
# Iteration 26: Current time 2023-01-01 17:07:00, Current location ehvbst
# Assigning ride at index 229 to bus 3.
# Ride at index 229 arrives at: 2023-01-01 17:30:00
# Ride ends at 2023-01-01 17:30:00, new current location is ehvapt.
# Iteration 27: Current time 2023-01-01 17:30:00, Current location ehvapt
# Assigning ride at index 147 to bus 3.
# Ride at index 147 arrives at: 2023-01-01 17:55:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 17:55:00, new current location is ehvbst.
# Iteration 28: Current time 2023-01-01 17:55:00, Current location ehvbst
# Assigning ride at index 234 to bus 3.
# Ride at index 234 arrives at: 2023-01-01 18:20:00
# Ride ends at 2023-01-01 18:20:00, new current location is ehvapt.
# Iteration 29: Current time 2023-01-01 18:20:00, Current location ehvapt
# Assigning ride at index 70 to bus 3.
# Ride at index 70 arrives at: 2023-01-01 18:47:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2023-01-01 18:47:00, new current location is ehvbst.
# Iteration 30: Current time 2023-01-01 18:47:00, Current location ehvbst
# Assigning ride at index 322 to bus 3.
# Ride at index 322 arrives at: 2023-01-01 19:13:00
# Ride ends at 2023-01-01 19:13:00, new current location is ehvapt.
# Iteration 31: Current time 2023-01-01 19:13:00, Current location ehvapt
# Assigning ride at index 157 to bus 3.
# Ride at index 157 arrives at: 2023-01-01 19:40:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2023-01-01 19:40:00, new current location is ehvbst.
# Iteration 32: Current time 2023-01-01 19:40:00, Current location ehvbst
# Assigning ride at index 241 to bus 3.
# Ride at index 241 arrives at: 2023-01-01 20:05:00
# Ride ends at 2023-01-01 20:05:00, new current location is ehvapt.
# Iteration 33: Current time 2023-01-01 20:05:00, Current location ehvapt
# Assigning ride at index 77 to bus 3.
# Ride at index 77 arrives at: 2023-01-01 20:32:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2023-01-01 20:32:00, new current location is ehvbst.
# Iteration 34: Current time 2023-01-01 21:32:00, Current location ehvbst
# Assigning ride at index 246 to bus 3.
# Ride at index 246 arrives at: 2023-01-01 21:58:00
# Ride ends at 2023-01-01 21:58:00, new current location is ehvapt.
# Iteration 35: Current time 2023-01-01 21:58:00, Current location ehvapt
# Assigning ride at index 81 to bus 3.
# Ride at index 81 arrives at: 2023-01-01 22:26:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 22:26:00, new current location is ehvbst.
# Iteration 36: Current time 2023-01-01 22:26:00, Current location ehvbst
# Assigning ride at index 248 to bus 3.
# Ride at index 248 arrives at: 2023-01-01 22:58:00
# Ride ends at 2023-01-01 22:58:00, new current location is ehvapt.
# Iteration 37: Current time 2023-01-01 22:58:00, Current location ehvapt
# Assigning ride at index 83 to bus 3.
# Ride at index 83 arrives at: 2023-01-01 23:26:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 23:26:00, new current location is ehvbst.
# Iteration 38: Current time 2023-01-01 23:26:00, Current location ehvbst
# Assigning ride at index 250 to bus 3.
# Ride at index 250 arrives at: 2023-01-01 23:58:00
# Ride ends at 2023-01-01 23:58:00, new current location is ehvapt.
# Iteration 39: Current time 2023-01-01 23:58:00, Current location ehvapt
# No more rides available, terminating loop.
# Idle added from 2023-01-01 05:58:00 to 2023-01-01 06:34:00.
# Idle added from 2023-01-01 06:55:00 to 2023-01-01 06:59:00.
# Idle added from 2023-01-01 07:20:00 to 2023-01-01 07:26:00.
# Idle added from 2023-01-01 07:47:00 to 2023-01-01 07:49:00.
# Idle added from 2023-01-01 08:10:00 to 2023-01-01 08:16:00.
# Idle added from 2023-01-01 08:37:00 to 2023-01-01 08:39:00.
# Idle added from 2023-01-01 09:00:00 to 2023-01-01 09:04:00.
# Idle added from 2023-01-01 09:25:00 to 2023-01-01 09:29:00.
# Idle added from 2023-01-01 09:50:00 to 2023-01-01 09:56:00.
# Idle added from 2023-01-01 10:17:00 to 2023-01-01 10:19:00.
# Idle added from 2023-01-01 10:40:00 to 2023-01-01 10:46:00.
# Idle added from 2023-01-01 11:07:00 to 2023-01-01 11:09:00.
# Idle added from 2023-01-01 11:30:00 to 2023-01-01 11:34:00.
# Idle added from 2023-01-01 11:55:00 to 2023-01-01 11:59:00.
# Idle added from 2023-01-01 12:20:00 to 2023-01-01 12:26:00.
# Idle added from 2023-01-01 12:47:00 to 2023-01-01 13:49:00.
# Idle added from 2023-01-01 14:10:00 to 2023-01-01 14:16:00.
# Idle added from 2023-01-01 14:37:00 to 2023-01-01 14:39:00.
# Idle added from 2023-01-01 15:00:00 to 2023-01-01 15:04:00.
# Idle added from 2023-01-01 15:25:00 to 2023-01-01 15:29:00.
# Idle added from 2023-01-01 15:50:00 to 2023-01-01 15:56:00.
# Idle added from 2023-01-01 16:17:00 to 2023-01-01 16:19:00.
# Idle added from 2023-01-01 16:40:00 to 2023-01-01 16:46:00.
# Idle added from 2023-01-01 17:07:00 to 2023-01-01 17:09:00.
# Idle added from 2023-01-01 17:30:00 to 2023-01-01 17:34:00.
# Idle added from 2023-01-01 17:55:00 to 2023-01-01 17:59:00.
# Idle added from 2023-01-01 18:20:00 to 2023-01-01 18:26:00.
# Idle added from 2023-01-01 18:47:00 to 2023-01-01 18:52:00.
# Idle added from 2023-01-01 19:13:00 to 2023-01-01 19:19:00.
# Idle added from 2023-01-01 19:40:00 to 2023-01-01 19:44:00.
# Idle added from 2023-01-01 20:05:00 to 2023-01-01 20:11:00.
# Idle added from 2023-01-01 20:32:00 to 2023-01-01 21:37:00.
# Idle added from 2023-01-01 21:58:00 to 2023-01-01 22:05:00.
# Idle added from 2023-01-01 22:26:00 to 2023-01-01 22:37:00.
# Idle added from 2023-01-01 22:58:00 to 2023-01-01 23:05:00.
# Idle added from 2023-01-01 23:26:00 to 2023-01-01 23:37:00.
# Unieke vergelijkingssleutels in df_dienstregeling: 287
# Unieke vergelijkingssleutels in df_aangepast: 37
# Aantal regels in df_dienstregeling: 287
# Aantal regels in df_aangepast: 43
# Aantal regels in df_overgebleven: 250
# Iteration 1: Current time 2022-12-31 23:57:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2023-01-01 00:01:00, Current location ehvbst
# Assigning ride at index 165 to bus 4.
# Ride at index 165 arrives at: 2023-01-01 06:28:00
# Ride ends at 2023-01-01 06:28:00, new current location is ehvapt.
# Iteration 3: Current time 2023-01-01 06:28:00, Current location ehvapt
# Assigning ride at index 3 to bus 4.
# Ride at index 3 arrives at: 2023-01-01 07:32:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 07:32:00, new current location is ehvbst.
# Iteration 4: Current time 2023-01-01 07:32:00, Current location ehvbst
# Assigning ride at index 255 to bus 4.
# Ride at index 255 arrives at: 2023-01-01 07:57:00
# Ride ends at 2023-01-01 07:57:00, new current location is ehvapt.
# Iteration 5: Current time 2023-01-01 07:57:00, Current location ehvapt
# Assigning ride at index 90 to bus 4.
# Ride at index 90 arrives at: 2023-01-01 08:25:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 08:25:00, new current location is ehvbst.
# Iteration 6: Current time 2023-01-01 08:25:00, Current location ehvbst
# Assigning ride at index 177 to bus 4.
# Ride at index 177 arrives at: 2023-01-01 08:50:00
# Ride ends at 2023-01-01 08:50:00, new current location is ehvapt.
# Iteration 7: Current time 2023-01-01 08:50:00, Current location ehvapt
# Assigning ride at index 13 to bus 4.
# Ride at index 13 arrives at: 2023-01-01 09:17:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 09:17:00, new current location is ehvbst.
# Iteration 8: Current time 2023-01-01 09:17:00, Current location ehvbst
# Assigning ride at index 182 to bus 4.
# Ride at index 182 arrives at: 2023-01-01 09:40:00
# Ride ends at 2023-01-01 09:40:00, new current location is ehvapt.
# Iteration 9: Current time 2023-01-01 09:40:00, Current location ehvapt
# Assigning ride at index 18 to bus 4.
# Ride at index 18 arrives at: 2023-01-01 10:07:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 10:07:00, new current location is ehvbst.
# Iteration 10: Current time 2023-01-01 10:07:00, Current location ehvbst
# Assigning ride at index 187 to bus 4.
# Ride at index 187 arrives at: 2023-01-01 10:30:00
# Ride ends at 2023-01-01 10:30:00, new current location is ehvapt.
# Iteration 11: Current time 2023-01-01 10:30:00, Current location ehvapt
# Assigning ride at index 105 to bus 4.
# Ride at index 105 arrives at: 2023-01-01 10:55:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 10:55:00, new current location is ehvbst.
# Iteration 12: Current time 2023-01-01 10:55:00, Current location ehvbst
# Assigning ride at index 192 to bus 4.
# Ride at index 192 arrives at: 2023-01-01 11:20:00
# Ride ends at 2023-01-01 11:20:00, new current location is ehvapt.
# Iteration 13: Current time 2023-01-01 11:20:00, Current location ehvapt
# Assigning ride at index 28 to bus 4.
# Ride at index 28 arrives at: 2023-01-01 11:47:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2023-01-01 11:47:00, new current location is ehvbst.
# Iteration 14: Current time 2023-01-01 11:47:00, Current location ehvbst
# Assigning ride at index 197 to bus 4.
# Ride at index 197 arrives at: 2023-01-01 12:10:00
# Ride ends at 2023-01-01 12:10:00, new current location is ehvapt.
# Iteration 15: Current time 2023-01-01 12:10:00, Current location ehvapt
# Assigning ride at index 33 to bus 4.
# Ride at index 33 arrives at: 2023-01-01 12:37:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2023-01-01 12:37:00, new current location is ehvbst.
# Iteration 16: Current time 2023-01-01 12:37:00, Current location ehvbst
# Assigning ride at index 202 to bus 4.
# Ride at index 202 arrives at: 2023-01-01 13:00:00
# Ride ends at 2023-01-01 13:00:00, new current location is ehvapt.
# Iteration 17: Current time 2023-01-01 13:00:00, Current location ehvapt
# Assigning ride at index 120 to bus 4.
# Ride at index 120 arrives at: 2023-01-01 13:25:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2023-01-01 13:25:00, new current location is ehvbst.
# Iteration 18: Current time 2023-01-01 14:25:00, Current location ehvbst
# Assigning ride at index 213 to bus 4.
# Ride at index 213 arrives at: 2023-01-01 14:50:00
# Ride ends at 2023-01-01 14:50:00, new current location is ehvapt.
# Iteration 19: Current time 2023-01-01 14:50:00, Current location ehvapt
# Assigning ride at index 49 to bus 4.
# Ride at index 49 arrives at: 2023-01-01 15:17:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 15:17:00, new current location is ehvbst.
# Iteration 20: Current time 2023-01-01 15:17:00, Current location ehvbst
# Assigning ride at index 218 to bus 4.
# Ride at index 218 arrives at: 2023-01-01 15:40:00
# Ride ends at 2023-01-01 15:40:00, new current location is ehvapt.
# Iteration 21: Current time 2023-01-01 15:40:00, Current location ehvapt
# Assigning ride at index 54 to bus 4.
# Ride at index 54 arrives at: 2023-01-01 16:07:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 16:07:00, new current location is ehvbst.
# Iteration 22: Current time 2023-01-01 16:07:00, Current location ehvbst
# Assigning ride at index 223 to bus 4.
# Ride at index 223 arrives at: 2023-01-01 16:30:00
# Ride ends at 2023-01-01 16:30:00, new current location is ehvapt.
# Iteration 23: Current time 2023-01-01 16:30:00, Current location ehvapt
# Assigning ride at index 141 to bus 4.
# Ride at index 141 arrives at: 2023-01-01 16:55:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 16:55:00, new current location is ehvbst.
# Iteration 24: Current time 2023-01-01 16:55:00, Current location ehvbst
# Assigning ride at index 228 to bus 4.
# Ride at index 228 arrives at: 2023-01-01 17:20:00
# Ride ends at 2023-01-01 17:20:00, new current location is ehvapt.
# Iteration 25: Current time 2023-01-01 17:20:00, Current location ehvapt
# Assigning ride at index 64 to bus 4.
# Ride at index 64 arrives at: 2023-01-01 17:47:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 17:47:00, new current location is ehvbst.
# Iteration 26: Current time 2023-01-01 17:47:00, Current location ehvbst
# Assigning ride at index 233 to bus 4.
# Ride at index 233 arrives at: 2023-01-01 18:10:00
# Ride ends at 2023-01-01 18:10:00, new current location is ehvapt.
# Iteration 27: Current time 2023-01-01 18:10:00, Current location ehvapt
# Assigning ride at index 69 to bus 4.
# Ride at index 69 arrives at: 2023-01-01 18:37:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 18:37:00, new current location is ehvbst.
# Iteration 28: Current time 2023-01-01 18:37:00, Current location ehvbst
# Assigning ride at index 321 to bus 4.
# Ride at index 321 arrives at: 2023-01-01 18:58:00
# Ride ends at 2023-01-01 18:58:00, new current location is ehvapt.
# Iteration 29: Current time 2023-01-01 18:58:00, Current location ehvapt
# Assigning ride at index 156 to bus 4.
# Ride at index 156 arrives at: 2023-01-01 19:25:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2023-01-01 19:25:00, new current location is ehvbst.
# Iteration 30: Current time 2023-01-01 19:25:00, Current location ehvbst
# Assigning ride at index 240 to bus 4.
# Ride at index 240 arrives at: 2023-01-01 19:50:00
# Ride ends at 2023-01-01 19:50:00, new current location is ehvapt.
# Iteration 31: Current time 2023-01-01 19:50:00, Current location ehvapt
# Assigning ride at index 76 to bus 4.
# Ride at index 76 arrives at: 2023-01-01 20:17:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2023-01-01 20:17:00, new current location is ehvbst.
# Iteration 32: Current time 2023-01-01 20:17:00, Current location ehvbst
# Assigning ride at index 243 to bus 4.
# Ride at index 243 arrives at: 2023-01-01 20:43:00
# Ride ends at 2023-01-01 20:43:00, new current location is ehvapt.
# Iteration 33: Current time 2023-01-01 20:43:00, Current location ehvapt
# Assigning ride at index 162 to bus 4.
# Ride at index 162 arrives at: 2023-01-01 21:07:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2023-01-01 21:07:00, new current location is ehvbst.
# Iteration 34: Current time 2023-01-01 22:07:00, Current location ehvbst
# No more rides available, terminating loop.
# Idle added from 2023-01-01 06:28:00 to 2023-01-01 07:11:00.
# Idle added from 2023-01-01 07:32:00 to 2023-01-01 07:36:00.
# Idle added from 2023-01-01 07:57:00 to 2023-01-01 08:04:00.
# Idle added from 2023-01-01 08:25:00 to 2023-01-01 08:29:00.
# Idle added from 2023-01-01 08:50:00 to 2023-01-01 08:56:00.
# Idle added from 2023-01-01 09:17:00 to 2023-01-01 09:19:00.
# Idle added from 2023-01-01 09:40:00 to 2023-01-01 09:46:00.
# Idle added from 2023-01-01 10:07:00 to 2023-01-01 10:09:00.
# Idle added from 2023-01-01 10:30:00 to 2023-01-01 10:34:00.
# Idle added from 2023-01-01 10:55:00 to 2023-01-01 10:59:00.
# Idle added from 2023-01-01 11:20:00 to 2023-01-01 11:26:00.
# Idle added from 2023-01-01 11:47:00 to 2023-01-01 11:49:00.
# Idle added from 2023-01-01 12:10:00 to 2023-01-01 12:16:00.
# Idle added from 2023-01-01 12:37:00 to 2023-01-01 12:39:00.
# Idle added from 2023-01-01 13:00:00 to 2023-01-01 13:04:00.
# Idle added from 2023-01-01 13:25:00 to 2023-01-01 14:29:00.
# Idle added from 2023-01-01 14:50:00 to 2023-01-01 14:56:00.
# Idle added from 2023-01-01 15:17:00 to 2023-01-01 15:19:00.
# Idle added from 2023-01-01 15:40:00 to 2023-01-01 15:46:00.
# Idle added from 2023-01-01 16:07:00 to 2023-01-01 16:09:00.
# Idle added from 2023-01-01 16:30:00 to 2023-01-01 16:34:00.
# Idle added from 2023-01-01 16:55:00 to 2023-01-01 16:59:00.
# Idle added from 2023-01-01 17:20:00 to 2023-01-01 17:26:00.
# Idle added from 2023-01-01 17:47:00 to 2023-01-01 17:49:00.
# Idle added from 2023-01-01 18:10:00 to 2023-01-01 18:16:00.
# Idle added from 2023-01-01 18:58:00 to 2023-01-01 19:04:00.
# Idle added from 2023-01-01 19:25:00 to 2023-01-01 19:29:00.
# Idle added from 2023-01-01 19:50:00 to 2023-01-01 19:56:00.
# Idle added from 2023-01-01 20:17:00 to 2023-01-01 20:22:00.
# Idle added from 2023-01-01 20:43:00 to 2023-01-01 20:46:00.
# Unieke vergelijkingssleutels in df_dienstregeling: 250
# Unieke vergelijkingssleutels in df_aangepast: 32
# Aantal regels in df_dienstregeling: 250
# Aantal regels in df_aangepast: 35
# Aantal regels in df_overgebleven: 218
# Iteration 1: Current time 2022-12-31 23:57:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2023-01-01 00:01:00, Current location ehvbst
# Assigning ride at index 167 to bus 5.
# Ride at index 167 arrives at: 2023-01-01 07:07:00
# Ride ends at 2023-01-01 07:07:00, new current location is ehvapt.
# Iteration 3: Current time 2023-01-01 07:07:00, Current location ehvapt
# Assigning ride at index 87 to bus 5.
# Ride at index 87 arrives at: 2023-01-01 07:40:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 07:40:00, new current location is ehvbst.
# Iteration 4: Current time 2023-01-01 07:40:00, Current location ehvbst
# Assigning ride at index 256 to bus 5.
# Ride at index 256 arrives at: 2023-01-01 08:12:00
# Ride ends at 2023-01-01 08:12:00, new current location is ehvapt.
# Iteration 5: Current time 2023-01-01 08:12:00, Current location ehvapt
# Assigning ride at index 91 to bus 5.
# Ride at index 91 arrives at: 2023-01-01 08:40:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 08:40:00, new current location is ehvbst.
# Iteration 6: Current time 2023-01-01 08:40:00, Current location ehvbst
# Assigning ride at index 179 to bus 5.
# Ride at index 179 arrives at: 2023-01-01 09:10:00
# Ride ends at 2023-01-01 09:10:00, new current location is ehvapt.
# Iteration 7: Current time 2023-01-01 09:10:00, Current location ehvapt
# Assigning ride at index 15 to bus 5.
# Ride at index 15 arrives at: 2023-01-01 09:37:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 09:37:00, new current location is ehvbst.
# Iteration 8: Current time 2023-01-01 09:37:00, Current location ehvbst
# Assigning ride at index 184 to bus 5.
# Ride at index 184 arrives at: 2023-01-01 10:00:00
# Ride ends at 2023-01-01 10:00:00, new current location is ehvapt.
# Iteration 9: Current time 2023-01-01 10:00:00, Current location ehvapt
# Assigning ride at index 102 to bus 5.
# Ride at index 102 arrives at: 2023-01-01 10:25:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 10:25:00, new current location is ehvbst.
# Iteration 10: Current time 2023-01-01 10:25:00, Current location ehvbst
# Assigning ride at index 189 to bus 5.
# Ride at index 189 arrives at: 2023-01-01 10:50:00
# Ride ends at 2023-01-01 10:50:00, new current location is ehvapt.
# Iteration 11: Current time 2023-01-01 10:50:00, Current location ehvapt
# Assigning ride at index 25 to bus 5.
# Ride at index 25 arrives at: 2023-01-01 11:17:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 11:17:00, new current location is ehvbst.
# Iteration 12: Current time 2023-01-01 11:17:00, Current location ehvbst
# Assigning ride at index 194 to bus 5.
# Ride at index 194 arrives at: 2023-01-01 11:40:00
# Ride ends at 2023-01-01 11:40:00, new current location is ehvapt.
# Iteration 13: Current time 2023-01-01 11:40:00, Current location ehvapt
# Assigning ride at index 30 to bus 5.
# Ride at index 30 arrives at: 2023-01-01 12:07:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2023-01-01 12:07:00, new current location is ehvbst.
# Iteration 14: Current time 2023-01-01 12:07:00, Current location ehvbst
# Assigning ride at index 199 to bus 5.
# Ride at index 199 arrives at: 2023-01-01 12:30:00
# Ride ends at 2023-01-01 12:30:00, new current location is ehvapt.
# Iteration 15: Current time 2023-01-01 12:30:00, Current location ehvapt
# Assigning ride at index 117 to bus 5.
# Ride at index 117 arrives at: 2023-01-01 12:55:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2023-01-01 12:55:00, new current location is ehvbst.
# Iteration 16: Current time 2023-01-01 12:55:00, Current location ehvbst
# Assigning ride at index 204 to bus 5.
# Ride at index 204 arrives at: 2023-01-01 13:20:00
# Ride ends at 2023-01-01 13:20:00, new current location is ehvapt.
# Iteration 17: Current time 2023-01-01 13:20:00, Current location ehvapt
# Assigning ride at index 40 to bus 5.
# Ride at index 40 arrives at: 2023-01-01 13:47:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2023-01-01 13:47:00, new current location is ehvbst.
# Iteration 18: Current time 2023-01-01 14:47:00, Current location ehvbst
# Assigning ride at index 215 to bus 5.
# Ride at index 215 arrives at: 2023-01-01 15:10:00
# Ride ends at 2023-01-01 15:10:00, new current location is ehvapt.
# Iteration 19: Current time 2023-01-01 15:10:00, Current location ehvapt
# Assigning ride at index 51 to bus 5.
# Ride at index 51 arrives at: 2023-01-01 15:37:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 15:37:00, new current location is ehvbst.
# Iteration 20: Current time 2023-01-01 15:37:00, Current location ehvbst
# Assigning ride at index 220 to bus 5.
# Ride at index 220 arrives at: 2023-01-01 16:00:00
# Ride ends at 2023-01-01 16:00:00, new current location is ehvapt.
# Iteration 21: Current time 2023-01-01 16:00:00, Current location ehvapt
# Assigning ride at index 138 to bus 5.
# Ride at index 138 arrives at: 2023-01-01 16:25:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 16:25:00, new current location is ehvbst.
# Iteration 22: Current time 2023-01-01 16:25:00, Current location ehvbst
# Assigning ride at index 225 to bus 5.
# Ride at index 225 arrives at: 2023-01-01 16:50:00
# Ride ends at 2023-01-01 16:50:00, new current location is ehvapt.
# Iteration 23: Current time 2023-01-01 16:50:00, Current location ehvapt
# Assigning ride at index 61 to bus 5.
# Ride at index 61 arrives at: 2023-01-01 17:17:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 17:17:00, new current location is ehvbst.
# Iteration 24: Current time 2023-01-01 17:17:00, Current location ehvbst
# Assigning ride at index 230 to bus 5.
# Ride at index 230 arrives at: 2023-01-01 17:40:00
# Ride ends at 2023-01-01 17:40:00, new current location is ehvapt.
# Iteration 25: Current time 2023-01-01 17:40:00, Current location ehvapt
# Assigning ride at index 66 to bus 5.
# Ride at index 66 arrives at: 2023-01-01 18:07:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 18:07:00, new current location is ehvbst.
# Iteration 26: Current time 2023-01-01 18:07:00, Current location ehvbst
# Assigning ride at index 318 to bus 5.
# Ride at index 318 arrives at: 2023-01-01 18:28:00
# Ride ends at 2023-01-01 18:28:00, new current location is ehvapt.
# Iteration 27: Current time 2023-01-01 18:28:00, Current location ehvapt
# Assigning ride at index 153 to bus 5.
# Ride at index 153 arrives at: 2023-01-01 18:55:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 18:55:00, new current location is ehvbst.
# Iteration 28: Current time 2023-01-01 18:55:00, Current location ehvbst
# Assigning ride at index 238 to bus 5.
# Ride at index 238 arrives at: 2023-01-01 19:20:00
# Ride ends at 2023-01-01 19:20:00, new current location is ehvapt.
# Iteration 29: Current time 2023-01-01 19:20:00, Current location ehvapt
# Assigning ride at index 74 to bus 5.
# Ride at index 74 arrives at: 2023-01-01 19:47:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2023-01-01 19:47:00, new current location is ehvbst.
# Iteration 30: Current time 2023-01-01 19:47:00, Current location ehvbst
# Assigning ride at index 242 to bus 5.
# Ride at index 242 arrives at: 2023-01-01 20:28:00
# Ride ends at 2023-01-01 20:28:00, new current location is ehvapt.
# Iteration 31: Current time 2023-01-01 20:28:00, Current location ehvapt
# Assigning ride at index 78 to bus 5.
# Ride at index 78 arrives at: 2023-01-01 20:56:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2023-01-01 20:56:00, new current location is ehvbst.
# Iteration 32: Current time 2023-01-01 20:56:00, Current location ehvbst
# Unable to find a valid next location, terminating loop.
# Idle added from 2023-01-01 07:07:00 to 2023-01-01 07:19:00.
# Idle added from 2023-01-01 07:40:00 to 2023-01-01 07:51:00.
# Idle added from 2023-01-01 08:12:00 to 2023-01-01 08:19:00.
# Idle added from 2023-01-01 08:40:00 to 2023-01-01 08:49:00.
# Idle added from 2023-01-01 09:10:00 to 2023-01-01 09:16:00.
# Idle added from 2023-01-01 09:37:00 to 2023-01-01 09:39:00.
# Idle added from 2023-01-01 10:00:00 to 2023-01-01 10:04:00.
# Idle added from 2023-01-01 10:25:00 to 2023-01-01 10:29:00.
# Idle added from 2023-01-01 10:50:00 to 2023-01-01 10:56:00.
# Idle added from 2023-01-01 11:17:00 to 2023-01-01 11:19:00.
# Idle added from 2023-01-01 11:40:00 to 2023-01-01 11:46:00.
# Idle added from 2023-01-01 12:07:00 to 2023-01-01 12:09:00.
# Idle added from 2023-01-01 12:30:00 to 2023-01-01 12:34:00.
# Idle added from 2023-01-01 12:55:00 to 2023-01-01 12:59:00.
# Idle added from 2023-01-01 13:20:00 to 2023-01-01 13:26:00.
# Idle added from 2023-01-01 13:47:00 to 2023-01-01 14:49:00.
# Idle added from 2023-01-01 15:10:00 to 2023-01-01 15:16:00.
# Idle added from 2023-01-01 15:37:00 to 2023-01-01 15:39:00.
# Idle added from 2023-01-01 16:00:00 to 2023-01-01 16:04:00.
# Idle added from 2023-01-01 16:25:00 to 2023-01-01 16:29:00.
# Idle added from 2023-01-01 16:50:00 to 2023-01-01 16:56:00.
# Idle added from 2023-01-01 17:17:00 to 2023-01-01 17:19:00.
# Idle added from 2023-01-01 17:40:00 to 2023-01-01 17:46:00.
# Idle added from 2023-01-01 18:28:00 to 2023-01-01 18:34:00.
# Idle added from 2023-01-01 18:55:00 to 2023-01-01 18:59:00.
# Idle added from 2023-01-01 19:20:00 to 2023-01-01 19:26:00.
# Idle added from 2023-01-01 19:47:00 to 2023-01-01 20:07:00.
# Idle added from 2023-01-01 20:28:00 to 2023-01-01 20:35:00.
# Unieke vergelijkingssleutels in df_dienstregeling: 218
# Unieke vergelijkingssleutels in df_aangepast: 30
# Aantal regels in df_dienstregeling: 218
# Aantal regels in df_aangepast: 33
# Aantal regels in df_overgebleven: 188
# Iteration 1: Current time 2022-12-31 23:57:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2023-01-01 00:01:00, Current location ehvbst
# Assigning ride at index 252 to bus 6.
# Ride at index 252 arrives at: 2023-01-01 07:13:00
# Ride ends at 2023-01-01 07:13:00, new current location is ehvapt.
# Iteration 3: Current time 2023-01-01 07:13:00, Current location ehvapt
# Assigning ride at index 88 to bus 6.
# Ride at index 88 arrives at: 2023-01-01 07:55:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 07:55:00, new current location is ehvbst.
# Iteration 4: Current time 2023-01-01 07:55:00, Current location ehvbst
# Assigning ride at index 174 to bus 6.
# Ride at index 174 arrives at: 2023-01-01 08:20:00
# Ride ends at 2023-01-01 08:20:00, new current location is ehvapt.
# Iteration 5: Current time 2023-01-01 08:20:00, Current location ehvapt
# Assigning ride at index 10 to bus 6.
# Ride at index 10 arrives at: 2023-01-01 08:47:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 08:47:00, new current location is ehvbst.
# Iteration 6: Current time 2023-01-01 08:47:00, Current location ehvbst
# Assigning ride at index 262 to bus 6.
# Ride at index 262 arrives at: 2023-01-01 09:12:00
# Ride ends at 2023-01-01 09:12:00, new current location is ehvapt.
# Iteration 7: Current time 2023-01-01 09:12:00, Current location ehvapt
# Assigning ride at index 97 to bus 6.
# Ride at index 97 arrives at: 2023-01-01 09:40:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 09:40:00, new current location is ehvbst.
# Iteration 8: Current time 2023-01-01 09:40:00, Current location ehvbst
# Assigning ride at index 268 to bus 6.
# Ride at index 268 arrives at: 2023-01-01 10:12:00
# Ride ends at 2023-01-01 10:12:00, new current location is ehvapt.
# Iteration 9: Current time 2023-01-01 10:12:00, Current location ehvapt
# Assigning ride at index 103 to bus 6.
# Ride at index 103 arrives at: 2023-01-01 10:40:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 10:40:00, new current location is ehvbst.
# Iteration 10: Current time 2023-01-01 10:40:00, Current location ehvbst
# Assigning ride at index 191 to bus 6.
# Ride at index 191 arrives at: 2023-01-01 11:10:00
# Ride ends at 2023-01-01 11:10:00, new current location is ehvapt.
# Iteration 11: Current time 2023-01-01 11:10:00, Current location ehvapt
# Assigning ride at index 27 to bus 6.
# Ride at index 27 arrives at: 2023-01-01 11:37:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 11:37:00, new current location is ehvbst.
# Iteration 12: Current time 2023-01-01 11:37:00, Current location ehvbst
# Assigning ride at index 196 to bus 6.
# Ride at index 196 arrives at: 2023-01-01 12:00:00
# Ride ends at 2023-01-01 12:00:00, new current location is ehvapt.
# Iteration 13: Current time 2023-01-01 12:00:00, Current location ehvapt
# Assigning ride at index 114 to bus 6.
# Ride at index 114 arrives at: 2023-01-01 12:25:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2023-01-01 12:25:00, new current location is ehvbst.
# Iteration 14: Current time 2023-01-01 12:25:00, Current location ehvbst
# Assigning ride at index 201 to bus 6.
# Ride at index 201 arrives at: 2023-01-01 12:50:00
# Ride ends at 2023-01-01 12:50:00, new current location is ehvapt.
# Iteration 15: Current time 2023-01-01 12:50:00, Current location ehvapt
# Assigning ride at index 37 to bus 6.
# Ride at index 37 arrives at: 2023-01-01 13:17:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2023-01-01 13:17:00, new current location is ehvbst.
# Iteration 16: Current time 2023-01-01 13:17:00, Current location ehvbst
# Assigning ride at index 289 to bus 6.
# Ride at index 289 arrives at: 2023-01-01 13:42:00
# Ride ends at 2023-01-01 13:42:00, new current location is ehvapt.
# Iteration 17: Current time 2023-01-01 13:42:00, Current location ehvapt
# Assigning ride at index 124 to bus 6.
# Ride at index 124 arrives at: 2023-01-01 14:10:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2023-01-01 14:10:00, new current location is ehvbst.
# Iteration 18: Current time 2023-01-01 15:10:00, Current location ehvbst
# Assigning ride at index 301 to bus 6.
# Ride at index 301 arrives at: 2023-01-01 15:42:00
# Ride ends at 2023-01-01 15:42:00, new current location is ehvapt.
# Iteration 19: Current time 2023-01-01 15:42:00, Current location ehvapt
# Assigning ride at index 136 to bus 6.
# Ride at index 136 arrives at: 2023-01-01 16:10:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 16:10:00, new current location is ehvbst.
# Iteration 20: Current time 2023-01-01 16:10:00, Current location ehvbst
# Assigning ride at index 307 to bus 6.
# Ride at index 307 arrives at: 2023-01-01 16:42:00
# Ride ends at 2023-01-01 16:42:00, new current location is ehvapt.
# Iteration 21: Current time 2023-01-01 16:42:00, Current location ehvapt
# Assigning ride at index 142 to bus 6.
# Ride at index 142 arrives at: 2023-01-01 17:10:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 17:10:00, new current location is ehvbst.
# Iteration 22: Current time 2023-01-01 17:10:00, Current location ehvbst
# Assigning ride at index 313 to bus 6.
# Ride at index 313 arrives at: 2023-01-01 17:42:00
# Ride ends at 2023-01-01 17:42:00, new current location is ehvapt.
# Iteration 23: Current time 2023-01-01 17:42:00, Current location ehvapt
# Assigning ride at index 148 to bus 6.
# Ride at index 148 arrives at: 2023-01-01 18:10:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 18:10:00, new current location is ehvbst.
# Iteration 24: Current time 2023-01-01 18:10:00, Current location ehvbst
# Assigning ride at index 235 to bus 6.
# Ride at index 235 arrives at: 2023-01-01 18:35:00
# Ride ends at 2023-01-01 18:35:00, new current location is ehvapt.
# Iteration 25: Current time 2023-01-01 18:35:00, Current location ehvapt
# Assigning ride at index 71 to bus 6.
# Ride at index 71 arrives at: 2023-01-01 19:02:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 19:02:00, new current location is ehvbst.
# Iteration 26: Current time 2023-01-01 19:02:00, Current location ehvbst
# Assigning ride at index 324 to bus 6.
# Ride at index 324 arrives at: 2023-01-01 19:28:00
# Ride ends at 2023-01-01 19:28:00, new current location is ehvapt.
# Iteration 27: Current time 2023-01-01 19:28:00, Current location ehvapt
# Assigning ride at index 159 to bus 6.
# Ride at index 159 arrives at: 2023-01-01 19:55:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 19:55:00, new current location is ehvbst.
# Iteration 28: Current time 2023-01-01 19:55:00, Current location ehvbst
# Assigning ride at index 244 to bus 6.
# Ride at index 244 arrives at: 2023-01-01 20:58:00
# Ride ends at 2023-01-01 20:58:00, new current location is ehvapt.
# Iteration 29: Current time 2023-01-01 20:58:00, Current location ehvapt
# Assigning ride at index 79 to bus 6.
# Ride at index 79 arrives at: 2023-01-01 21:26:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2023-01-01 21:26:00, new current location is ehvbst.
# Iteration 30: Current time 2023-01-01 21:26:00, Current location ehvbst
# No more rides available, terminating loop.
# Idle added from 2023-01-01 07:13:00 to 2023-01-01 07:34:00.
# Idle added from 2023-01-01 07:55:00 to 2023-01-01 07:59:00.
# Idle added from 2023-01-01 08:20:00 to 2023-01-01 08:26:00.
# Idle added from 2023-01-01 08:47:00 to 2023-01-01 08:51:00.
# Idle added from 2023-01-01 09:12:00 to 2023-01-01 09:19:00.
# Idle added from 2023-01-01 09:40:00 to 2023-01-01 09:51:00.
# Idle added from 2023-01-01 10:12:00 to 2023-01-01 10:19:00.
# Idle added from 2023-01-01 10:40:00 to 2023-01-01 10:49:00.
# Idle added from 2023-01-01 11:10:00 to 2023-01-01 11:16:00.
# Idle added from 2023-01-01 11:37:00 to 2023-01-01 11:39:00.
# Idle added from 2023-01-01 12:00:00 to 2023-01-01 12:04:00.
# Idle added from 2023-01-01 12:25:00 to 2023-01-01 12:29:00.
# Idle added from 2023-01-01 12:50:00 to 2023-01-01 12:56:00.
# Idle added from 2023-01-01 13:17:00 to 2023-01-01 13:21:00.
# Idle added from 2023-01-01 13:42:00 to 2023-01-01 13:49:00.
# Idle added from 2023-01-01 14:10:00 to 2023-01-01 15:21:00.
# Idle added from 2023-01-01 15:42:00 to 2023-01-01 15:49:00.
# Idle added from 2023-01-01 16:10:00 to 2023-01-01 16:21:00.
# Idle added from 2023-01-01 16:42:00 to 2023-01-01 16:49:00.
# Idle added from 2023-01-01 17:10:00 to 2023-01-01 17:21:00.
# Idle added from 2023-01-01 17:42:00 to 2023-01-01 17:49:00.
# Idle added from 2023-01-01 18:10:00 to 2023-01-01 18:14:00.
# Idle added from 2023-01-01 18:35:00 to 2023-01-01 18:41:00.
# Idle added from 2023-01-01 19:02:00 to 2023-01-01 19:07:00.
# Idle added from 2023-01-01 19:28:00 to 2023-01-01 19:34:00.
# Idle added from 2023-01-01 19:55:00 to 2023-01-01 20:37:00.
# Idle added from 2023-01-01 20:58:00 to 2023-01-01 21:05:00.
# Unieke vergelijkingssleutels in df_dienstregeling: 188
# Unieke vergelijkingssleutels in df_aangepast: 28
# Aantal regels in df_dienstregeling: 188
# Aantal regels in df_aangepast: 31
# Aantal regels in df_overgebleven: 160
# Iteration 1: Current time 2022-12-31 23:57:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2023-01-01 00:01:00, Current location ehvbst
# Assigning ride at index 253 to bus 7.
# Ride at index 253 arrives at: 2023-01-01 07:27:00
# Ride ends at 2023-01-01 07:27:00, new current location is ehvapt.
# Iteration 3: Current time 2023-01-01 07:27:00, Current location ehvapt
# Assigning ride at index 5 to bus 7.
# Ride at index 5 arrives at: 2023-01-01 07:57:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 07:57:00, new current location is ehvbst.
# Iteration 4: Current time 2023-01-01 07:57:00, Current location ehvbst
# Assigning ride at index 258 to bus 7.
# Ride at index 258 arrives at: 2023-01-01 08:27:00
# Ride ends at 2023-01-01 08:27:00, new current location is ehvapt.
# Iteration 5: Current time 2023-01-01 08:27:00, Current location ehvapt
# Assigning ride at index 92 to bus 7.
# Ride at index 92 arrives at: 2023-01-01 08:48:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 08:48:00, new current location is ehvbst.
# Iteration 6: Current time 2023-01-01 08:48:00, Current location ehvbst
# Assigning ride at index 263 to bus 7.
# Ride at index 263 arrives at: 2023-01-01 09:15:00
# Ride ends at 2023-01-01 09:15:00, new current location is ehvapt.
# Iteration 7: Current time 2023-01-01 09:15:00, Current location ehvapt
# Assigning ride at index 98 to bus 7.
# Ride at index 98 arrives at: 2023-01-01 09:48:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 09:48:00, new current location is ehvbst.
# Iteration 8: Current time 2023-01-01 09:48:00, Current location ehvbst
# Assigning ride at index 269 to bus 7.
# Ride at index 269 arrives at: 2023-01-01 10:15:00
# Ride ends at 2023-01-01 10:15:00, new current location is ehvapt.
# Iteration 9: Current time 2023-01-01 10:15:00, Current location ehvapt
# Assigning ride at index 22 to bus 7.
# Ride at index 22 arrives at: 2023-01-01 10:47:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 10:47:00, new current location is ehvbst.
# Iteration 10: Current time 2023-01-01 10:47:00, Current location ehvbst
# Assigning ride at index 274 to bus 7.
# Ride at index 274 arrives at: 2023-01-01 11:12:00
# Ride ends at 2023-01-01 11:12:00, new current location is ehvapt.
# Iteration 11: Current time 2023-01-01 11:12:00, Current location ehvapt
# Assigning ride at index 109 to bus 7.
# Ride at index 109 arrives at: 2023-01-01 11:40:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 11:40:00, new current location is ehvbst.
# Iteration 12: Current time 2023-01-01 11:40:00, Current location ehvbst
# Assigning ride at index 280 to bus 7.
# Ride at index 280 arrives at: 2023-01-01 12:12:00
# Ride ends at 2023-01-01 12:12:00, new current location is ehvapt.
# Iteration 13: Current time 2023-01-01 12:12:00, Current location ehvapt
# Assigning ride at index 115 to bus 7.
# Ride at index 115 arrives at: 2023-01-01 12:40:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2023-01-01 12:40:00, new current location is ehvbst.
# Iteration 14: Current time 2023-01-01 12:40:00, Current location ehvbst
# Assigning ride at index 203 to bus 7.
# Ride at index 203 arrives at: 2023-01-01 13:10:00
# Ride ends at 2023-01-01 13:10:00, new current location is ehvapt.
# Iteration 15: Current time 2023-01-01 13:10:00, Current location ehvapt
# Assigning ride at index 39 to bus 7.
# Ride at index 39 arrives at: 2023-01-01 13:37:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2023-01-01 13:37:00, new current location is ehvbst.
# Iteration 16: Current time 2023-01-01 13:37:00, Current location ehvbst
# Assigning ride at index 208 to bus 7.
# Ride at index 208 arrives at: 2023-01-01 14:00:00
# Ride ends at 2023-01-01 14:00:00, new current location is ehvapt.
# Iteration 17: Current time 2023-01-01 14:00:00, Current location ehvapt
# Assigning ride at index 126 to bus 7.
# Ride at index 126 arrives at: 2023-01-01 14:25:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2023-01-01 14:25:00, new current location is ehvbst.
# Iteration 18: Current time 2023-01-01 15:25:00, Current location ehvbst
# Assigning ride at index 303 to bus 7.
# Ride at index 303 arrives at: 2023-01-01 15:57:00
# Ride ends at 2023-01-01 15:57:00, new current location is ehvapt.
# Iteration 19: Current time 2023-01-01 15:57:00, Current location ehvapt
# Assigning ride at index 137 to bus 7.
# Ride at index 137 arrives at: 2023-01-01 16:18:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 16:18:00, new current location is ehvbst.
# Iteration 20: Current time 2023-01-01 16:18:00, Current location ehvbst
# Assigning ride at index 308 to bus 7.
# Ride at index 308 arrives at: 2023-01-01 16:45:00
# Ride ends at 2023-01-01 16:45:00, new current location is ehvapt.
# Iteration 21: Current time 2023-01-01 16:45:00, Current location ehvapt
# Assigning ride at index 143 to bus 7.
# Ride at index 143 arrives at: 2023-01-01 17:18:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 17:18:00, new current location is ehvbst.
# Iteration 22: Current time 2023-01-01 17:18:00, Current location ehvbst
# Assigning ride at index 314 to bus 7.
# Ride at index 314 arrives at: 2023-01-01 17:45:00
# Ride ends at 2023-01-01 17:45:00, new current location is ehvapt.
# Iteration 23: Current time 2023-01-01 17:45:00, Current location ehvapt
# Assigning ride at index 149 to bus 7.
# Ride at index 149 arrives at: 2023-01-01 18:18:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 18:18:00, new current location is ehvbst.
# Iteration 24: Current time 2023-01-01 18:18:00, Current location ehvbst
# Assigning ride at index 320 to bus 7.
# Ride at index 320 arrives at: 2023-01-01 18:45:00
# Ride ends at 2023-01-01 18:45:00, new current location is ehvapt.
# Iteration 25: Current time 2023-01-01 18:45:00, Current location ehvapt
# Assigning ride at index 72 to bus 7.
# Ride at index 72 arrives at: 2023-01-01 19:17:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 19:17:00, new current location is ehvbst.
# Iteration 26: Current time 2023-01-01 19:17:00, Current location ehvbst
# Assigning ride at index 325 to bus 7.
# Ride at index 325 arrives at: 2023-01-01 19:43:00
# Ride ends at 2023-01-01 19:43:00, new current location is ehvapt.
# Iteration 27: Current time 2023-01-01 19:43:00, Current location ehvapt
# Assigning ride at index 160 to bus 7.
# Ride at index 160 arrives at: 2023-01-01 20:10:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 20:10:00, new current location is ehvbst.
# Iteration 28: Current time 2023-01-01 20:10:00, Current location ehvbst
# No more rides available, terminating loop.
# Idle added from 2023-01-01 07:27:00 to 2023-01-01 07:36:00.
# Idle added from 2023-01-01 07:57:00 to 2023-01-01 08:06:00.
# Idle added from 2023-01-01 08:48:00 to 2023-01-01 08:54:00.
# Idle added from 2023-01-01 09:15:00 to 2023-01-01 09:27:00.
# Idle added from 2023-01-01 09:48:00 to 2023-01-01 09:54:00.
# Idle added from 2023-01-01 10:15:00 to 2023-01-01 10:26:00.
# Idle added from 2023-01-01 10:47:00 to 2023-01-01 10:51:00.
# Idle added from 2023-01-01 11:12:00 to 2023-01-01 11:19:00.
# Idle added from 2023-01-01 11:40:00 to 2023-01-01 11:51:00.
# Idle added from 2023-01-01 12:12:00 to 2023-01-01 12:19:00.
# Idle added from 2023-01-01 12:40:00 to 2023-01-01 12:49:00.
# Idle added from 2023-01-01 13:10:00 to 2023-01-01 13:16:00.
# Idle added from 2023-01-01 13:37:00 to 2023-01-01 13:39:00.
# ...
# Assigning ride at index 32 to bus 12.
# Ride at index 32 arrives at: 2023-01-01 12:27:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 12:27:00, new current location is ehvbst.
# Iteration 10: Current time 2023-01-01 12:27:00, Current location ehvbst
# Assigning ride at index 285 to bus 12.
# Ride at index 285 arrives at: 2023-01-01 12:57:00
# Ride ends at 2023-01-01 12:57:00, new current location is ehvapt.
# Iteration 11: Current time 2023-01-01 12:57:00, Current location ehvapt
# Assigning ride at index 119 to bus 12.
# Ride at index 119 arrives at: 2023-01-01 13:18:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 13:18:00, new current location is ehvbst.
# Iteration 12: Current time 2023-01-01 13:18:00, Current location ehvbst
# Assigning ride at index 207 to bus 12.
# Ride at index 207 arrives at: 2023-01-01 13:50:00
# Ride ends at 2023-01-01 13:50:00, new current location is ehvapt.
# Iteration 13: Current time 2023-01-01 13:50:00, Current location ehvapt
# Assigning ride at index 125 to bus 12.
# Ride at index 125 arrives at: 2023-01-01 14:18:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2023-01-01 14:18:00, new current location is ehvbst.
# Iteration 14: Current time 2023-01-01 14:18:00, Current location ehvbst
# Assigning ride at index 295 to bus 12.
# Ride at index 295 arrives at: 2023-01-01 14:42:00
# Ride ends at 2023-01-01 14:42:00, new current location is ehvapt.
# Iteration 15: Current time 2023-01-01 14:42:00, Current location ehvapt
# Assigning ride at index 130 to bus 12.
# Ride at index 130 arrives at: 2023-01-01 15:10:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2023-01-01 15:10:00, new current location is ehvbst.
# Iteration 16: Current time 2023-01-01 15:10:00, Current location ehvbst
# Assigning ride at index 302 to bus 12.
# Ride at index 302 arrives at: 2023-01-01 15:45:00
# Ride ends at 2023-01-01 15:45:00, new current location is ehvapt.
# Iteration 17: Current time 2023-01-01 15:45:00, Current location ehvapt
# Assigning ride at index 56 to bus 12.
# Ride at index 56 arrives at: 2023-01-01 16:27:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2023-01-01 16:27:00, new current location is ehvbst.
# Iteration 18: Current time 2023-01-01 17:27:00, Current location ehvbst
# Unable to find a valid next location, terminating loop.
# Idle added from 2023-01-01 08:15:00 to 2023-01-01 09:06:00.
# Idle added from 2023-01-01 09:27:00 to 2023-01-01 09:36:00.
# Idle added from 2023-01-01 09:57:00 to 2023-01-01 10:06:00.
# Idle added from 2023-01-01 10:27:00 to 2023-01-01 10:36:00.
# Idle added from 2023-01-01 10:57:00 to 2023-01-01 11:06:00.
# Idle added from 2023-01-01 11:27:00 to 2023-01-01 11:36:00.
# Idle added from 2023-01-01 11:57:00 to 2023-01-01 12:06:00.
# Idle added from 2023-01-01 12:27:00 to 2023-01-01 12:36:00.
# Idle added from 2023-01-01 13:18:00 to 2023-01-01 13:29:00.
# Idle added from 2023-01-01 13:50:00 to 2023-01-01 13:57:00.
# Idle added from 2023-01-01 14:18:00 to 2023-01-01 14:21:00.
# Idle added from 2023-01-01 14:42:00 to 2023-01-01 14:49:00.
# Idle added from 2023-01-01 15:10:00 to 2023-01-01 15:24:00.
# Idle added from 2023-01-01 15:45:00 to 2023-01-01 16:06:00.
# Unieke vergelijkingssleutels in df_dienstregeling: 42
# Unieke vergelijkingssleutels in df_aangepast: 16
# Aantal regels in df_dienstregeling: 42
# Aantal regels in df_aangepast: 16
# Aantal regels in df_overgebleven: 26
# Iteration 1: Current time 2022-12-31 23:57:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2023-01-01 00:01:00, Current location ehvbst
# Assigning ride at index 260 to bus 13.
# Ride at index 260 arrives at: 2023-01-01 08:45:00
# Ride ends at 2023-01-01 08:45:00, new current location is ehvapt.
# Iteration 3: Current time 2023-01-01 08:45:00, Current location ehvapt
# Assigning ride at index 38 to bus 13.
# Ride at index 38 arrives at: 2023-01-01 13:27:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 13:27:00, new current location is ehvbst.
# Iteration 4: Current time 2023-01-01 13:27:00, Current location ehvbst
# Assigning ride at index 291 to bus 13.
# Ride at index 291 arrives at: 2023-01-01 13:57:00
# Ride ends at 2023-01-01 13:57:00, new current location is ehvapt.
# Iteration 5: Current time 2023-01-01 13:57:00, Current location ehvapt
# Assigning ride at index 44 to bus 13.
# Ride at index 44 arrives at: 2023-01-01 14:27:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 14:27:00, new current location is ehvbst.
# Iteration 6: Current time 2023-01-01 14:27:00, Current location ehvbst
# Assigning ride at index 297 to bus 13.
# Ride at index 297 arrives at: 2023-01-01 14:57:00
# Ride ends at 2023-01-01 14:57:00, new current location is ehvapt.
# Iteration 7: Current time 2023-01-01 14:57:00, Current location ehvapt
# Assigning ride at index 131 to bus 13.
# Ride at index 131 arrives at: 2023-01-01 15:18:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 15:18:00, new current location is ehvbst.
# Iteration 8: Current time 2023-01-01 15:18:00, Current location ehvbst
# Assigning ride at index 222 to bus 13.
# Ride at index 222 arrives at: 2023-01-01 16:20:00
# Ride ends at 2023-01-01 16:20:00, new current location is ehvapt.
# Iteration 9: Current time 2023-01-01 16:20:00, Current location ehvapt
# Assigning ride at index 140 to bus 13.
# Ride at index 140 arrives at: 2023-01-01 16:48:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 16:48:00, new current location is ehvbst.
# Iteration 10: Current time 2023-01-01 16:48:00, Current location ehvbst
# Assigning ride at index 312 to bus 13.
# Ride at index 312 arrives at: 2023-01-01 17:27:00
# Ride ends at 2023-01-01 17:27:00, new current location is ehvapt.
# Iteration 11: Current time 2023-01-01 17:27:00, Current location ehvapt
# Assigning ride at index 65 to bus 13.
# Ride at index 65 arrives at: 2023-01-01 17:57:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2023-01-01 17:57:00, new current location is ehvbst.
# Iteration 12: Current time 2023-01-01 17:57:00, Current location ehvbst
# No more rides available, terminating loop.
# Idle added from 2023-01-01 08:45:00 to 2023-01-01 13:06:00.
# Idle added from 2023-01-01 13:27:00 to 2023-01-01 13:36:00.
# Idle added from 2023-01-01 13:57:00 to 2023-01-01 14:06:00.
# Idle added from 2023-01-01 14:27:00 to 2023-01-01 14:36:00.
# Idle added from 2023-01-01 15:18:00 to 2023-01-01 15:59:00.
# Idle added from 2023-01-01 16:20:00 to 2023-01-01 16:27:00.
# Idle added from 2023-01-01 16:48:00 to 2023-01-01 17:06:00.
# Idle added from 2023-01-01 17:27:00 to 2023-01-01 17:36:00.
# Unieke vergelijkingssleutels in df_dienstregeling: 26
# Unieke vergelijkingssleutels in df_aangepast: 10
# Aantal regels in df_dienstregeling: 26
# Aantal regels in df_aangepast: 13
# Aantal regels in df_overgebleven: 16
# Iteration 1: Current time 2022-12-31 23:57:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2023-01-01 00:01:00, Current location ehvbst
# Assigning ride at index 284 to bus 14.
# Ride at index 284 arrives at: 2023-01-01 12:45:00
# Ride ends at 2023-01-01 12:45:00, new current location is ehvapt.
# Iteration 3: Current time 2023-01-01 12:45:00, Current location ehvapt
# Assigning ride at index 41 to bus 14.
# Ride at index 41 arrives at: 2023-01-01 13:57:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 13:57:00, new current location is ehvbst.
# Iteration 4: Current time 2023-01-01 13:57:00, Current location ehvbst
# Assigning ride at index 294 to bus 14.
# Ride at index 294 arrives at: 2023-01-01 14:27:00
# Ride ends at 2023-01-01 14:27:00, new current location is ehvapt.
# Iteration 5: Current time 2023-01-01 14:27:00, Current location ehvapt
# Assigning ride at index 47 to bus 14.
# Ride at index 47 arrives at: 2023-01-01 14:57:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2023-01-01 14:57:00, new current location is ehvbst.
# Iteration 6: Current time 2023-01-01 14:57:00, Current location ehvbst
# Assigning ride at index 300 to bus 14.
# Ride at index 300 arrives at: 2023-01-01 15:27:00
# Ride ends at 2023-01-01 15:27:00, new current location is ehvapt.
# Iteration 7: Current time 2023-01-01 15:27:00, Current location ehvapt
# Assigning ride at index 134 to bus 14.
# Ride at index 134 arrives at: 2023-01-01 15:48:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2023-01-01 15:48:00, new current location is ehvbst.
# Iteration 8: Current time 2023-01-01 15:48:00, Current location ehvbst
# Assigning ride at index 306 to bus 14.
# Ride at index 306 arrives at: 2023-01-01 16:27:00
# Ride ends at 2023-01-01 16:27:00, new current location is ehvapt.
# Iteration 9: Current time 2023-01-01 16:27:00, Current location ehvapt
# Assigning ride at index 59 to bus 14.
# Ride at index 59 arrives at: 2023-01-01 16:57:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2023-01-01 16:57:00, new current location is ehvbst.
# Iteration 10: Current time 2023-01-01 16:57:00, Current location ehvbst
# No more rides available, terminating loop.
# Idle added from 2023-01-01 12:45:00 to 2023-01-01 13:36:00.
# Idle added from 2023-01-01 13:57:00 to 2023-01-01 14:06:00.
# Idle added from 2023-01-01 14:27:00 to 2023-01-01 14:36:00.
# Idle added from 2023-01-01 14:57:00 to 2023-01-01 15:06:00.
# Idle added from 2023-01-01 15:48:00 to 2023-01-01 16:06:00.
# Idle added from 2023-01-01 16:27:00 to 2023-01-01 16:36:00.
# Unieke vergelijkingssleutels in df_dienstregeling: 16
# Unieke vergelijkingssleutels in df_aangepast: 8
# Aantal regels in df_dienstregeling: 16
# Aantal regels in df_aangepast: 8
# Aantal regels in df_overgebleven: 8
# Iteration 1: Current time 2022-12-31 23:57:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2023-01-01 00:01:00, Current location ehvbst
# Assigning ride at index 287 to bus 15.
# Ride at index 287 arrives at: 2023-01-01 13:15:00
# Ride ends at 2023-01-01 13:15:00, new current location is ehvapt.
# Iteration 3: Current time 2023-01-01 13:15:00, Current location ehvapt
# Assigning ride at index 50 to bus 15.
# Ride at index 50 arrives at: 2023-01-01 15:27:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 15:27:00, new current location is ehvbst.
# Iteration 4: Current time 2023-01-01 15:27:00, Current location ehvbst
# Unable to find a valid next location, terminating loop.
# Idle added from 2023-01-01 13:15:00 to 2023-01-01 15:06:00.
# Unieke vergelijkingssleutels in df_dienstregeling: 8
# Unieke vergelijkingssleutels in df_aangepast: 2
# Aantal regels in df_dienstregeling: 8
# Aantal regels in df_aangepast: 5
# Aantal regels in df_overgebleven: 6
# Iteration 1: Current time 2022-12-31 23:57:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2023-01-01 00:01:00, Current location ehvbst
# Assigning ride at index 296 to bus 16.
# Ride at index 296 arrives at: 2023-01-01 14:45:00
# Ride ends at 2023-01-01 14:45:00, new current location is ehvapt.
# Iteration 3: Current time 2023-01-01 14:45:00, Current location ehvapt
# Assigning ride at index 135 to bus 16.
# Ride at index 135 arrives at: 2023-01-01 15:55:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 15:55:00, new current location is ehvbst.
# Iteration 4: Current time 2023-01-01 15:55:00, Current location ehvbst
# No more rides available, terminating loop.
# Idle added from 2023-01-01 14:45:00 to 2023-01-01 15:34:00.
# Unieke vergelijkingssleutels in df_dienstregeling: 6
# Unieke vergelijkingssleutels in df_aangepast: 2
# Aantal regels in df_dienstregeling: 6
# Aantal regels in df_aangepast: 2
# Aantal regels in df_overgebleven: 4
# Iteration 1: Current time 2022-12-31 23:57:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2023-01-01 00:01:00, Current location ehvbst
# Assigning ride at index 299 to bus 17.
# Ride at index 299 arrives at: 2023-01-01 15:15:00
# Ride ends at 2023-01-01 15:15:00, new current location is ehvapt.
# Iteration 3: Current time 2023-01-01 15:15:00, Current location ehvapt
# Assigning ride at index 53 to bus 17.
# Ride at index 53 arrives at: 2023-01-01 15:57:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2023-01-01 15:57:00, new current location is ehvbst.
# Iteration 4: Current time 2023-01-01 15:57:00, Current location ehvbst
# No more rides available, terminating loop.
# Idle added from 2023-01-01 15:15:00 to 2023-01-01 15:36:00.
# Unieke vergelijkingssleutels in df_dienstregeling: 4
# Unieke vergelijkingssleutels in df_aangepast: 2
# Aantal regels in df_dienstregeling: 4
# Aantal regels in df_aangepast: 2
# Aantal regels in df_overgebleven: 2
# Iteration 1: Current time 2022-12-31 23:57:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2023-01-01 00:01:00, Current location ehvbst
# Assigning ride at index 217 to bus 18.
# Ride at index 217 arrives at: 2023-01-01 15:30:00
# Ride ends at 2023-01-01 15:30:00, new current location is ehvapt.
# Iteration 3: Current time 2023-01-01 15:30:00, Current location ehvapt
# No more rides available, terminating loop.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\BramH\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'afstand in meters_y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 20
#      17 df_with_idle = add_idle_activity(df_processed_ritten[df_processed_ritten['Omloop'] == omloopnummer_voor_de_while_loop])
#      19 # Filter en bereken
# ---> 20 omloop_df = filter_and_calculate(df_with_idle, df_afstandsmatrix)
#      22 # Toevoegen van SOC kolommen aan de DataFrame met ritten
#      23 df_with_soc = calculate_soc(omloop_df)
#
# Cell In[16], line 177, in filter_and_calculate(df_ritten, df_afstandsmatrix)
#     169 omloop_1_df = omloop_1_df.merge(
#     170     df_afstandsmatrix[['code_afstand', 'afstand in meters']],
#     171     left_on='code_omloop',
#     172     right_on='code_afstand',
#     173     how='left'
#     174 )
#     176 # Kies de juiste kolom na de merge
# --> 177 omloop_1_df['afstand in meters'] = omloop_1_df['afstand in meters_y'].fillna(0)
#     179 # Verwijder onnodige suffixed kolommen
#     180 kolommen_verwijderen = ['afstand in meters_x', 'afstand in meters_y', 'code_afstand_x', 'code_afstand_y']
#
# File c:\Users\BramH\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\BramH\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'afstand in meters_y'

# %% [markdown]
# ## Dictionary met df_omloopnummer's idle tiijd geven en samenvoegen

# %%
len(omloopnummersdf_dict)
# Out:
# 17

# %%
import pandas as pd

def add_idle_activities(df):
    """Voegt 'idle' activiteiten toe als er een gat is tussen ritten."""
    rows_to_add = []

    # Zorg ervoor dat de datetime-kolommen zijn geconverteerd naar het juiste formaat
    df['vertrek_datetime'] = pd.to_datetime(df['vertrek_datetime'])
    df['aankomst_datetime'] = pd.to_datetime(df['aankomst_datetime'])

    # Sorteer het DataFrame op basis van vertrektijden
    df = df.sort_values(by='vertrek_datetime').reset_index(drop=True)

    for i in range(1, len(df)):
        vorige_rit = df.iloc[i - 1]
        huidige_rit = df.iloc[i]

        # Controleer op een tijdsverschil van meer dan 0 minuten
        if vorige_rit['aankomst_datetime'] < huidige_rit['vertrek_datetime']:
            idle_start = vorige_rit['aankomst_datetime']
            idle_end = huidige_rit['vertrek_datetime']

            # Creëer een nieuwe rij met expliciete None waarden
            new_row = {
                'startlocatie': vorige_rit['eindlocatie'],
                'eindlocatie': huidige_rit['startlocatie'],
                'vertrektijd': None,
                'buslijn': None,
                'vertrek_datetime': idle_start,
                'aankomst_datetime': idle_end,
                'Omloop': vorige_rit['Omloop'],
                'code_omloop': None,
                'activiteit': 'idle',
                'afstand in km': None,
                'Batterijgebruik': None,
                'code_afstand': None,
                'afstand in meters': None,
                'SOC_start': vorige_rit['SOC_start'],
                'SOC_eind': vorige_rit['SOC_eind']
            }

            # Voeg de nieuwe 'idle' rij toe
            rows_to_add.append(new_row)

    # Voeg de nieuwe 'idle' rijen toe aan het DataFrame
    if rows_to_add:
        idle_df = pd.DataFrame(rows_to_add)
        df = pd.concat([df, idle_df], ignore_index=True)

    # Herverdeel de DataFrame om ervoor te zorgen dat alles in de juiste volgorde staat
    df = df.sort_values(by='vertrek_datetime').reset_index(drop=True)
    return df

# Doorloop alle keys in de dictionary
for key in omloopnummersdf_dict.keys():
    # Pas de add_idle_activities functie toe op elke DataFrame
    omloopnummersdf_dict[key] = add_idle_activities(omloopnummersdf_dict[key])

omloopnummersdf_dict['df_omloopnummer_11'].head()
# Out:
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
# C:\Users\BramH\AppData\Local\Temp\ipykernel_48068\2211025830.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, idle_df], ignore_index=True)
#   startlocatie eindlocatie vertrektijd buslijn    vertrek_datetime  \
# 0       ehvbst      ehvapt       07:39     401 2023-01-01 07:39:00
# 1       ehvapt      ehvapt        None    None 2023-01-01 08:00:00
# 2       ehvapt      ehvbst       08:36     401 2023-01-01 08:36:00
# 3       ehvbst      ehvbst        None    None 2023-01-01 08:57:00
# 4       ehvbst      ehvapt       09:06     400 2023-01-01 09:06:00
#
#     aankomst_datetime  Omloop        code_omloop activiteit  afstand in km  \
# 0 2023-01-01 08:00:00      11  ehvbst_ehvapt_401  dienstrit          9.003
# 1 2023-01-01 08:36:00      11               None       idle            NaN
# 2 2023-01-01 08:57:00      11  ehvapt_ehvbst_401  dienstrit          9.050
# 3 2023-01-01 09:06:00      11               None       idle            NaN
# 4 2023-01-01 09:27:00      11  ehvbst_ehvapt_400  dienstrit         10.708
#
#    Batterijgebruik       code_afstand  afstand in meters  SOC_start  SOC_eind
# 0          10.8036  ehvbst_ehvapt_401             9003.0   243.0000  232.1964
# 1              NaN               None                NaN   243.0000  232.1964
# 2          10.8600  ehvapt_ehvbst_401             9050.0   232.1964  221.3364
# 3              NaN               None                NaN   232.1964  221.3364
# 4          12.8496  ehvbst_ehvapt_400            10708.0   221.3364  208.4868

# %%
omloopnummersdf_dict['df_omloopnummer_15']
# Out:
#   startlocatie eindlocatie vertrektijd buslijn    vertrek_datetime  \
# 0       ehvbst      ehvapt       12:54     400 2023-01-01 12:54:00
# 1       ehvapt   ehvgarage        None    None 2023-01-01 13:15:00
# 2    ehvgarage   ehvgarage        None    None 2023-01-01 13:19:00
# 3    ehvgarage      ehvapt        None    None 2023-01-01 14:04:00
# 4       ehvapt      ehvapt        None    None 2023-01-01 14:08:00
# 5       ehvapt      ehvbst       15:06     401 2023-01-01 15:06:00
#
#     aankomst_datetime  Omloop        code_omloop    activiteit  afstand in km  \
# 0 2023-01-01 13:15:00      15  ehvbst_ehvapt_400     dienstrit         10.708
# 1 2023-01-01 13:19:00      15               None  materiaalrit            NaN
# 2 2023-01-01 14:04:00      15               None       opladen            NaN
# 3 2023-01-01 14:08:00      15               None  materiaalrit            NaN
# 4 2023-01-01 15:06:00      15               None          idle            NaN
# 5 2023-01-01 15:27:00      15  ehvapt_ehvbst_401     dienstrit          9.050
#
#    Batterijgebruik       code_afstand  afstand in meters  SOC_start  SOC_eind
# 0          12.8496  ehvbst_ehvapt_400            10708.0   243.0000  230.1504
# 1           0.2000               None                NaN   230.1504  229.9504
# 2         -13.0496               None                NaN   229.9504  243.0000
# 3           0.2000               None                NaN   243.0000  242.8000
# 4              NaN               None                NaN   243.0000  242.8000
# 5          10.8600  ehvapt_ehvbst_401             9050.0   242.8000  231.9400

# %%
# dictionary met omloopnummer df's samenvoegen
alle_omloopnummers = pd.concat(omloopnummersdf_dict.values(), ignore_index=True)

# %%
# uploaden naar excel
alle_omloopnummers.to_excel("4. Verbeterde omloopplanning.xlsx", index=False)

# %% [markdown]
# # Oude code

# %% [markdown]
# ## Nieuwe poging voor alle omloopnummers

# %%
import pandas as pd
from datetime import timedelta

# Constante variabelen
ENERGIE_VERBRUIK_PER_KM = 1.2  # kWh per gereden kilometer
OPLAADKRACHT_PER_UUR = 450  # kWh per uur tot 90%
MAX_BATT_CAPA = 300  # kWh
SOC_START = 0.9  # factor
SOC_MIN = 0.1  # factor
BATTERIJ_SLIJTAGE = 0.9  # Factor
SOH = MAX_BATT_CAPA * BATTERIJ_SLIJTAGE
omloopnummer_voor_de_while_loop = 1

def load_data():
    """Functie om data in te laden."""
    df_omloopplanning = pd.read_excel('omloopplanning.xlsx', engine='openpyxl')
    df_dienstregeling = pd.read_excel('Connexxion data - 2024-2025.xlsx', engine='openpyxl')
    df_afstandsmatrix = pd.read_excel('Connexxion data - 2024-2025.xlsx', engine='openpyxl', sheet_name='Afstandsmatrix')
    return df_omloopplanning, df_dienstregeling, df_afstandsmatrix

def create_parameters_df():
    """Functie om een parameters DataFrame te maken."""
    soc_ochtend = SOH * SOC_START
    soc_minimum = SOH * SOC_MIN
    data = {
        'Parameter': ['Max Batterij Capaciteit', 'SOC Start', 'SOC Minimum', 'Batterij Slijtage', 'SOH', 'SOC Ochtend', 'SOC Minimum', 'Batterijverbuik', 'Oplaadsnelheid'],
        'Waarde': [MAX_BATT_CAPA, SOC_START, SOC_MIN, BATTERIJ_SLIJTAGE, SOH, soc_ochtend, soc_minimum, ENERGIE_VERBRUIK_PER_KM, OPLAADKRACHT_PER_UUR],
        'Eenheid': ['kWh', 'Factor', 'Factor', 'Factor', 'kW (MBC * BS)', 'kW (SOH * SOC S)', 'kW (SOH * SOC M)', 'kWh/km', 'kWh/uur']
    }
    return pd.DataFrame(data)

def convert_to_datetime(time_str):
    """Functie om tijden naar datetime om te zetten."""
    if pd.isna(time_str):
        # Als de tijd ontbreekt, retourneer een NaT Timestamp
        return pd.NaT

    try:
        time_obj = pd.to_datetime(time_str, format='%H:%M').time()
    except TypeError:
        # Fallback als time_str geen geschikt formaat heeft
        return pd.NaT

    upper_boundary = pd.to_datetime('23:59', format='%H:%M').time()
    lower_boundary = pd.to_datetime('04:00', format='%H:%M').time()
    
    if lower_boundary <= time_obj <= upper_boundary:
        return pd.Timestamp('2024-08-29') + pd.Timedelta(hours=time_obj.hour, minutes=time_obj.minute)
    else:
        return pd.Timestamp('2024-08-30') + pd.Timedelta(hours=time_obj.hour, minutes=time_obj.minute)

def process_schedule_data(df_dienstregeling):
    """Functie om de nieuwe dienstregeling te verwerken."""
    df = df_dienstregeling.copy()
    
    # Vervang NaN door een standaardwaarde voordat je de conversie uitvoert
    df['buslijn'] = df['buslijn'].fillna(0).astype(int).astype(str)

    df['vertrek_datetime'] = df['vertrektijd'].apply(convert_to_datetime)
    df['Omloop'] = 0
    df_sorted = df.sort_values(by=['vertrek_datetime', 'buslijn'])
    df_sorted['code_omloop'] = df_sorted['startlocatie'].str.strip().str.lower() + '_' + \
                               df_sorted['eindlocatie'].str.strip().str.lower() + '_' + \
                               df_sorted['buslijn']
    return df_sorted

def process_distance_matrix(df_afstandsmatrix):
    """Functie om de afstandsmatrix te verwerken."""
    df = df_afstandsmatrix.copy()
    df['buslijn'] = df['buslijn'].fillna(0).astype(int).astype(str)
    df['code_afstand'] = df['startlocatie'].str.strip().str.lower() + '_' + \
                         df['eindlocatie'].str.strip().str.lower() + '_' + \
                         df['buslijn']
    return df

def setUpDataframes(df_nieuwe_dienstregelingv2, df_afstandsmatrix):
    """Kopieer en bereid dataframes voor gebruik voor de inplanting."""
    df = df_nieuwe_dienstregelingv2.copy()
    df['vertrek_datetime'] = pd.to_datetime(df['vertrek_datetime'])
    df['aankomst_datetime'] = pd.NaT
    df['Omloop'] = pd.NA
    return df

def vindt_reistijd(df_afstandsmatrix, startlocatie, eindlocatie):
    """Vind de reistijd tussen start- en eindlocatie."""
    rij = df_afstandsmatrix[
        (df_afstandsmatrix['startlocatie'] == startlocatie) &
        (df_afstandsmatrix['eindlocatie'] == eindlocatie)
    ]
    if not rij.empty:
        return int(rij['min reistijd in min'].values[0])
    return None

def inplannen_busritten(df_ritten, df_afstandsmatrix):
    """Functie om busritten in te plannen met een verplichte rusttijd na elke vijfde keer bij 'ehvbst'."""
    bus_nr = 1
    actuele_tijd = df_ritten.iloc[0]['vertrek_datetime'] - timedelta(minutes=4)  # Start bij de garage
    huidige_locatie = 'ehvgar'
    count_ehvbst = 0  # Tel hoe vaak de bus bij 'ehvbst' is aangekomen
    iteration_count = 0

    while True:
        iteration_count += 1
        print(f"Iteration {iteration_count}: Current time {actuele_tijd}, Current location {huidige_locatie}")

        mogelijk_ritten = df_ritten[
            (df_ritten['Omloop'].isna()) & 
            (df_ritten['vertrek_datetime'] >= actuele_tijd) & 
            (df_ritten['startlocatie'] == huidige_locatie)
        ]

        if not mogelijk_ritten.empty:
            row = mogelijk_ritten.iloc[0]  # Kies de eerst mogelijke rit
            print(f"Assigning ride at index {row.name} to bus {bus_nr}.")
            df_ritten.at[row.name, 'Omloop'] = bus_nr

            rit_duur = vindt_reistijd(df_afstandsmatrix, row['startlocatie'], row['eindlocatie'])
            if rit_duur is not None:
                aankomsttijd = row['vertrek_datetime'] + timedelta(minutes=rit_duur)
                df_ritten.at[row.name, 'aankomst_datetime'] = aankomsttijd
                print(f"Ride at index {row.name} arrives at: {aankomsttijd}")

                actuele_tijd = aankomsttijd
                huidige_locatie = row['eindlocatie']

                # Bijhouden hoe vaak 'ehvbst' bereikt is
                if huidige_locatie == 'ehvbst':
                    count_ehvbst += 1
                    print(f"Bus has now arrived at 'ehvbst' {count_ehvbst} times.")
                    
                    # Bij elke 5e keer een pauze van een uur incasseren
                    if count_ehvbst == 8:
                        print("Taking a break for 1 hour at 'ehvbst'.")
                        actuele_tijd += timedelta(hours=1)
                        count_ehvbst = 0  # Reset de teller
                
                print(f"Ride ends at {aankomsttijd}, new current location is {huidige_locatie}.")
            continue

        volgende_startlocaties = df_ritten[
            (df_ritten['Omloop'].isna()) &
            (df_ritten['vertrek_datetime'] > actuele_tijd)
        ]

        if volgende_startlocaties.empty:
            print("No more rides available, terminating loop.")
            break

        next_location_found = False
        for _, row in volgende_startlocaties.iterrows():
            reistijd = vindt_reistijd(df_afstandsmatrix, huidige_locatie, row['startlocatie'])
            if reistijd is not None and (actuele_tijd + timedelta(minutes=reistijd)) <= row['vertrek_datetime']:
                print(f"Moving to new start location {row['startlocatie']} with travel time {reistijd} minutes.")
                actuele_tijd += timedelta(minutes=reistijd)
                huidige_locatie = row['startlocatie']
                next_location_found = True
                break

        if not next_location_found:
            print("Unable to find a valid next location, terminating loop.")
            break

    return df_ritten

def filter_and_calculate(df_ritten, df_afstandsmatrix):
    """Filter de DataFrame en bereken afstand en batterijverbruik."""
    omloop_1_df = df_ritten[df_ritten['Omloop'] == 1].copy()

    # Voeg de 'afstand in meters' toe uit de afstandsmatrix
    omloop_1_df = omloop_1_df.merge(
        df_afstandsmatrix[['code_afstand', 'afstand in meters']],
        left_on='code_omloop',
        right_on='code_afstand',
        how='left'
    )

    # Kies de juiste kolom na de merge
    omloop_1_df['afstand in meters'] = omloop_1_df['afstand in meters_y'].fillna(0)

    # Verwijder onnodige suffixed kolommen
    kolommen_verwijderen = ['afstand in meters_x', 'afstand in meters_y', 'code_afstand_x', 'code_afstand_y']
    bestaande_kolommen = [kolom for kolom in kolommen_verwijderen if kolom in omloop_1_df.columns]
    omloop_1_df.drop(columns=bestaande_kolommen, inplace=True)

    # Bereken de afstand in kilometers
    omloop_1_df['afstand in km'] = omloop_1_df['afstand in meters'] / 1000

    # Bereken batterijgebruik voor actieve activiteit
    omloop_1_df['Batterijgebruik'] = omloop_1_df['afstand in km'] * ENERGIE_VERBRUIK_PER_KM

    # Stel batterijgebruik in op 0.01 als de activiteit 'idle' is
    omloop_1_df.loc[omloop_1_df['activiteit'] == 'idle', 'Batterijgebruik'] = 0.01

    return omloop_1_df

def add_activiteit_column(df):
    """Voegt een 'activiteit' kolom toe gebaseerd op de aanwezigheid van een omloopnummer."""
    df['activiteit'] = df['Omloop'].apply(lambda x: 'dienstrit' if pd.notna(x) else 'geen dienst')
    return df

def add_idle_activity(df):
    """Voegt 'idle' activiteiten toe waar nodig."""
    rows_to_add = []

    # Sorteer het DataFrame op basis van vertrektijd, zodat ritten op volgorde worden verwerkt.
    df = df.sort_values(by='vertrek_datetime').reset_index(drop=True)

    for i in range(1, len(df)):
        vorige_rit = df.iloc[i - 1]
        huidige_rit = df.iloc[i]

        # Controleer beide datetimes en zorg dat de times valid zijn voor het bepalen van idle tijd
        if pd.notna(vorige_rit['aankomst_datetime']) and vorige_rit['aankomst_datetime'] < huidige_rit['vertrek_datetime']:
            idle_start = vorige_rit['aankomst_datetime']
            # Idle activiteit eindigt bij de start van de volgende rit
            idle_end = huidige_rit['vertrek_datetime']

            # Voeg een rij toe voor de "idle" periode
            rows_to_add.append({
                'startlocatie': vorige_rit['eindlocatie'],
                'eindlocatie': vorige_rit['eindlocatie'],
                'vertrek_datetime': idle_start,
                'aankomst_datetime': idle_end,
                'buslijn': '',
                'Omloop': vorige_rit['Omloop'],
                'activiteit': 'idle',
                'afstand in meters': 0,
                'afstand in km': 0,
                'Batterijgebruik': 0.01,
                 'code_omloop': str(huidige_rit['startlocatie']) + '_' + \
                                str(huidige_rit['startlocatie']) + '_' + \
                                str('Idle')
            })
            # Debug print om te zien welke idle rij toegevoegd is
            print(f"Idle added from {idle_start} to {idle_end}.")

    # Voeg de 'idle' rijen toe aan de DataFrame als er rijen zijn
    if rows_to_add:
        idle_df = pd.DataFrame(rows_to_add)
        df = pd.concat([df, idle_df], ignore_index=True)

    # Herverdeel de DataFrame om ervoor te zorgen dat alles op volgorde staat
    df = df.sort_values(by='vertrek_datetime').reset_index(drop=True)
    return df

def calculate_soc(df, initial_soc=243):
    """Voegt SOC_start en SOC_eind kolommen toe aan de DataFrame."""
    # Sorteren is belangrijk om juiste volgorde te behouden
    df = df.sort_values(['Omloop', 'vertrek_datetime']).reset_index(drop=True)

    # Initialiseren van de SOC kolommen
    df['SOC_start'] = 0.0
    df['SOC_eind'] = 0.0
    
    for omloop in df['Omloop'].unique():
        omloop_data = df[df['Omloop'] == omloop]
        prev_soc_eind = initial_soc
        
        for index, row in omloop_data.iterrows():
            if index == omloop_data.index[0]:  # Eerste rit van Omloop
                soc_start = initial_soc
            else:
                soc_start = prev_soc_eind

            # Bereken de SOC_eind
            soc_eind = soc_start - row['Batterijgebruik']

            # Update DataFrame
            df.at[index, 'SOC_start'] = soc_start
            df.at[index, 'SOC_eind'] = soc_eind

            # Update previous SOC_eind for next iteration
            prev_soc_eind = soc_eind

    return df

def manage_battery_and_charging(df, target_soc=243, drive_time=timedelta(minutes=4), charge_duration=timedelta(minutes=45)):
    """Laad de bus op als er een uur idle tijd is tussen de aankomst en het vertrek van ritten."""
    df = df.sort_values(['Omloop', 'vertrek_datetime']).reset_index(drop=True)
    adjusted_rows = []
    prev_soc_eind = target_soc  # Begin met volle lading

    # Default structure for a row
    default_row = {
        'startlocatie': None,
        'eindlocatie': None,
        'vertrektijd': None,
        'buslijn': None,
        'vertrek_datetime': None,
        'aankomst_datetime': None,
        'Omloop': None,
        'code_omloop': None,
        'activiteit': None,
        'afstand in km': None,
        'Batterijgebruik': None,
        'code_afstand': None,
        'afstand in meters': None,
        'SOC_start': None,
        'SOC_eind': None,
    }

    for index, row in df.iterrows():
        soc_start = prev_soc_eind if index != 0 else target_soc
        soc_eind = soc_start - row['Batterijgebruik']

        # Voeg de huidige rit toe
        adjusted_rows.append({
            **default_row,
            **row.to_dict(),
            'SOC_start': soc_start,
            'SOC_eind': soc_eind,
        })
        prev_soc_eind = soc_eind

        # Check of er een uur idle tijd is na deze rit
        if index < len(df) - 1:
            next_row = df.iloc[index + 1]

            # Bereken de idle tijd tussen de huidige aankomst en de volgende vertrek
            idle_time = next_row['vertrek_datetime'] - row['aankomst_datetime']

            # Als er voldoende idle tijd is
            if idle_time >= timedelta(hours=1):
                # Voeg materiaalrit naar garage toe
                to_garage_end_time = row['aankomst_datetime'] + drive_time
                adjusted_rows.append({
                    **default_row,
                    'startlocatie': row['eindlocatie'],
                    'eindlocatie': 'ehvgarage',
                    'vertrek_datetime': row['aankomst_datetime'],
                    'aankomst_datetime': to_garage_end_time,
                    'activiteit': 'materiaalrit',
                    'Batterijgebruik': 0.2,
                    'SOC_start': soc_eind,
                    'SOC_eind': soc_eind - 0.2,
                    'Omloop': row['Omloop']
                })

                # Laad de bus op
                charge_time_start = to_garage_end_time
                soc_charged = target_soc  # Doel SOC

                charge_time_end = charge_time_start + charge_duration
                adjusted_rows.append({
                    **default_row,
                    'startlocatie': 'ehvgarage',
                    'eindlocatie': 'ehvgarage',
                    'vertrek_datetime': charge_time_start,
                    'aankomst_datetime': charge_time_end,
                    'activiteit': 'opladen',
                    'Batterijgebruik': (soc_eind - 0.2 - soc_charged),  # Negatief om opladen aan te geven
                    'SOC_start': soc_eind - 0.2,
                    'SOC_eind': soc_charged,
                    'Omloop': row['Omloop']
                })

                # Materiaal rit terug naar de oorspronkelijke eindlocatie
                return_time = charge_time_end + drive_time
                adjusted_rows.append({
                    **default_row,
                    'startlocatie': 'ehvgarage',
                    'eindlocatie': row['eindlocatie'],
                    'vertrek_datetime': charge_time_end,
                    'aankomst_datetime': return_time,
                    'activiteit': 'materiaalrit',
                    'Batterijgebruik': 0.2,
                    'SOC_start': soc_charged,
                    'SOC_eind': soc_charged - 0.2,
                    'Omloop': row['Omloop']
                })

                prev_soc_eind = soc_charged - 0.2

    adjusted_df = pd.DataFrame(adjusted_rows)
    adjusted_df = adjusted_df.sort_values(by='vertrek_datetime').reset_index(drop=True)
    return adjusted_df

# Inladen van data
df_omloopplanning, df_dienstregeling, df_afstandsmatrix = load_data()

# Maak de parameters DataFrame en laat deze zien
df_parameters = create_parameters_df()
display(df_parameters)

# Verwerk dienstregeling en afstandsmatrix data
df_nieuwe_dienstregelingv2 = process_schedule_data(df_dienstregeling)
df_afstandsmatrix = process_distance_matrix(df_afstandsmatrix)

# Setting up the dataframes
df_nieuwe_dienstregelingv1 = setUpDataframes(df_nieuwe_dienstregelingv2, df_afstandsmatrix)

# Plan de busritten
df_processed_ritten = inplannen_busritten(df_nieuwe_dienstregelingv1, df_afstandsmatrix)

# Voer de functie uit na het verwerken van ritten
df_processed_ritten = add_activiteit_column(df_processed_ritten)

# Voeg de idle activiteiten in de verwerkte ritten toe
# Voer een test uit en controleer op output
df_with_idle = add_idle_activity(df_processed_ritten[df_processed_ritten['Omloop'] == 1])
# display(df_with_idle[df_with_idle['activiteit'] == 'idle'])
# display(df_with_idle.head(50))

# Filter en bereken
omloop_df = filter_and_calculate(df_with_idle, df_afstandsmatrix)

# Toevoegen van SOC kolommen aan de DataFrame met ritten
df_with_soc = calculate_soc(omloop_df)

# Filter out rows with 'idle' activity and simulate battery charging and material trips
df_filtered = df_with_soc[df_with_soc['activiteit'] != 'idle']
# display(df_filtered.head(50))
df_adjusted = manage_battery_and_charging(df_filtered)

df_omloopnummer_1 = df_adjusted.copy()
# Weergeven van het resultaat
# display(df_omloopnummer_1)

# display(df_dienstregeling)

def get_remaining_rows(df_dienstregeling, df_omloopnummer_1):
    # Vervang NaN waarden door een standaardwaarde, bijvoorbeeld 0
    df_dienstregeling['buslijn'] = df_dienstregeling['buslijn'].fillna(0).astype(int)
    df_omloopnummer_1['buslijn'] = df_omloopnummer_1['buslijn'].fillna(0).astype(int)

    # Converteer tijden naar een gemeenschappelijke representatie voor vergelijking
    df_dienstregeling['vertrektijd'] = pd.to_datetime(df_dienstregeling['vertrektijd'], format='%H:%M', errors='coerce').dt.time
    df_omloopnummer_1['vertrek_datetime'] = pd.to_datetime(df_omloopnummer_1['vertrek_datetime'], errors='coerce').dt.time

    # Maakt strings voor vergelijking
    df_dienstregeling['compare_key'] = df_dienstregeling.apply(
        lambda x: f"{x['startlocatie']}|{x['eindlocatie']}|{x['vertrektijd']}|{x['buslijn']}", axis=1
    )
    df_omloopnummer_1['compare_key'] = df_omloopnummer_1.apply(
        lambda x: f"{x['startlocatie']}|{x['eindlocatie']}|{x['vertrek_datetime']}|{x['buslijn']}", axis=1
    )

    # Haal de compare_keys op die uniek zijn voor df_dienstregeling
    unique_keys = set(df_dienstregeling['compare_key']) - set(df_omloopnummer_1['compare_key'])

    # Filter rijen in df_dienstregeling die uniek zijn
    remaining_df = df_dienstregeling[df_dienstregeling['compare_key'].isin(unique_keys)].drop(columns=['compare_key'])
    
    return remaining_df

# Gebruik de functie om de resterende regels te krijgen
df_remaining = get_remaining_rows(df_dienstregeling, df_omloopnummer_1)

# Print de resultaten
print(f"Aantal regels in df_dienstregeling: {df_dienstregeling.shape[0]}")
print(f"Aantal regels in df_omloopnummer_1: {df_omloopnummer_1.shape[0]}")
print(f"Aantal regels in df_remaining: {df_remaining.shape[0]}")
df_dienstregeling = df_remaining.copy()
display(df_dienstregeling)
# Out:
#                  Parameter  Waarde           Eenheid
# 0  Max Batterij Capaciteit   300.0               kWh
# 1                SOC Start     0.9            Factor
# 2              SOC Minimum     0.1            Factor
# 3        Batterij Slijtage     0.9            Factor
# 4                      SOH   270.0     kW (MBC * BS)
# 5              SOC Ochtend   243.0  kW (SOH * SOC S)
# 6              SOC Minimum    27.0  kW (SOH * SOC M)
# 7          Batterijverbuik     1.2            kWh/km
# 8           Oplaadsnelheid   450.0           kWh/uur
# Iteration 1: Current time 2024-08-29 05:03:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2024-08-29 05:07:00, Current location ehvbst
# Assigning ride at index 163 to bus 1.
# Ride at index 163 arrives at: 2024-08-29 05:28:00
# Ride ends at 2024-08-29 05:28:00, new current location is ehvapt.
# Iteration 3: Current time 2024-08-29 05:28:00, Current location ehvapt
# Assigning ride at index 0 to bus 1.
# Ride at index 0 arrives at: 2024-08-29 06:25:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 06:25:00, new current location is ehvbst.
# Iteration 4: Current time 2024-08-29 06:25:00, Current location ehvbst
# Assigning ride at index 166 to bus 1.
# Ride at index 166 arrives at: 2024-08-29 06:52:00
# Ride ends at 2024-08-29 06:52:00, new current location is ehvapt.
# Iteration 5: Current time 2024-08-29 06:52:00, Current location ehvapt
# Assigning ride at index 2 to bus 1.
# Ride at index 2 arrives at: 2024-08-29 07:17:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 07:17:00, new current location is ehvbst.
# Iteration 6: Current time 2024-08-29 07:17:00, Current location ehvbst
# Assigning ride at index 170 to bus 1.
# Ride at index 170 arrives at: 2024-08-29 07:40:00
# Ride ends at 2024-08-29 07:40:00, new current location is ehvapt.
# Iteration 7: Current time 2024-08-29 07:40:00, Current location ehvapt
# Assigning ride at index 6 to bus 1.
# Ride at index 6 arrives at: 2024-08-29 08:07:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 08:07:00, new current location is ehvbst.
# Iteration 8: Current time 2024-08-29 08:07:00, Current location ehvbst
# Assigning ride at index 175 to bus 1.
# Ride at index 175 arrives at: 2024-08-29 08:30:00
# Ride ends at 2024-08-29 08:30:00, new current location is ehvapt.
# Iteration 9: Current time 2024-08-29 08:30:00, Current location ehvapt
# Assigning ride at index 93 to bus 1.
# Ride at index 93 arrives at: 2024-08-29 08:55:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 08:55:00, new current location is ehvbst.
# Iteration 10: Current time 2024-08-29 08:55:00, Current location ehvbst
# Assigning ride at index 180 to bus 1.
# Ride at index 180 arrives at: 2024-08-29 09:20:00
# Ride ends at 2024-08-29 09:20:00, new current location is ehvapt.
# Iteration 11: Current time 2024-08-29 09:20:00, Current location ehvapt
# Assigning ride at index 16 to bus 1.
# Ride at index 16 arrives at: 2024-08-29 09:47:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2024-08-29 09:47:00, new current location is ehvbst.
# Iteration 12: Current time 2024-08-29 09:47:00, Current location ehvbst
# Assigning ride at index 185 to bus 1.
# Ride at index 185 arrives at: 2024-08-29 10:10:00
# Ride ends at 2024-08-29 10:10:00, new current location is ehvapt.
# Iteration 13: Current time 2024-08-29 10:10:00, Current location ehvapt
# Assigning ride at index 21 to bus 1.
# Ride at index 21 arrives at: 2024-08-29 10:37:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2024-08-29 10:37:00, new current location is ehvbst.
# Iteration 14: Current time 2024-08-29 10:37:00, Current location ehvbst
# Assigning ride at index 190 to bus 1.
# Ride at index 190 arrives at: 2024-08-29 11:00:00
# Ride ends at 2024-08-29 11:00:00, new current location is ehvapt.
# Iteration 15: Current time 2024-08-29 11:00:00, Current location ehvapt
# Assigning ride at index 108 to bus 1.
# Ride at index 108 arrives at: 2024-08-29 11:25:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2024-08-29 11:25:00, new current location is ehvbst.
# Iteration 16: Current time 2024-08-29 11:25:00, Current location ehvbst
# Assigning ride at index 195 to bus 1.
# Ride at index 195 arrives at: 2024-08-29 11:50:00
# Ride ends at 2024-08-29 11:50:00, new current location is ehvapt.
# Iteration 17: Current time 2024-08-29 11:50:00, Current location ehvapt
# Assigning ride at index 31 to bus 1.
# Ride at index 31 arrives at: 2024-08-29 12:17:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 12:17:00, new current location is ehvbst.
# Iteration 18: Current time 2024-08-29 13:17:00, Current location ehvbst
# Assigning ride at index 206 to bus 1.
# Ride at index 206 arrives at: 2024-08-29 13:40:00
# Ride ends at 2024-08-29 13:40:00, new current location is ehvapt.
# Iteration 19: Current time 2024-08-29 13:40:00, Current location ehvapt
# Assigning ride at index 42 to bus 1.
# Ride at index 42 arrives at: 2024-08-29 14:07:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 14:07:00, new current location is ehvbst.
# Iteration 20: Current time 2024-08-29 14:07:00, Current location ehvbst
# Assigning ride at index 211 to bus 1.
# Ride at index 211 arrives at: 2024-08-29 14:30:00
# Ride ends at 2024-08-29 14:30:00, new current location is ehvapt.
# Iteration 21: Current time 2024-08-29 14:30:00, Current location ehvapt
# Assigning ride at index 129 to bus 1.
# Ride at index 129 arrives at: 2024-08-29 14:55:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 14:55:00, new current location is ehvbst.
# Iteration 22: Current time 2024-08-29 14:55:00, Current location ehvbst
# Assigning ride at index 216 to bus 1.
# Ride at index 216 arrives at: 2024-08-29 15:20:00
# Ride ends at 2024-08-29 15:20:00, new current location is ehvapt.
# Iteration 23: Current time 2024-08-29 15:20:00, Current location ehvapt
# Assigning ride at index 52 to bus 1.
# Ride at index 52 arrives at: 2024-08-29 15:47:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 15:47:00, new current location is ehvbst.
# Iteration 24: Current time 2024-08-29 15:47:00, Current location ehvbst
# Assigning ride at index 221 to bus 1.
# Ride at index 221 arrives at: 2024-08-29 16:10:00
# Ride ends at 2024-08-29 16:10:00, new current location is ehvapt.
# Iteration 25: Current time 2024-08-29 16:10:00, Current location ehvapt
# Assigning ride at index 57 to bus 1.
# Ride at index 57 arrives at: 2024-08-29 16:37:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 16:37:00, new current location is ehvbst.
# Iteration 26: Current time 2024-08-29 16:37:00, Current location ehvbst
# Assigning ride at index 226 to bus 1.
# Ride at index 226 arrives at: 2024-08-29 17:00:00
# Ride ends at 2024-08-29 17:00:00, new current location is ehvapt.
# Iteration 27: Current time 2024-08-29 17:00:00, Current location ehvapt
# Assigning ride at index 144 to bus 1.
# Ride at index 144 arrives at: 2024-08-29 17:25:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2024-08-29 17:25:00, new current location is ehvbst.
# Iteration 28: Current time 2024-08-29 17:25:00, Current location ehvbst
# Assigning ride at index 231 to bus 1.
# Ride at index 231 arrives at: 2024-08-29 17:50:00
# Ride ends at 2024-08-29 17:50:00, new current location is ehvapt.
# Iteration 29: Current time 2024-08-29 17:50:00, Current location ehvapt
# Assigning ride at index 67 to bus 1.
# Ride at index 67 arrives at: 2024-08-29 18:17:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2024-08-29 18:17:00, new current location is ehvbst.
# Iteration 30: Current time 2024-08-29 18:17:00, Current location ehvbst
# Assigning ride at index 319 to bus 1.
# Ride at index 319 arrives at: 2024-08-29 18:43:00
# Ride ends at 2024-08-29 18:43:00, new current location is ehvapt.
# Iteration 31: Current time 2024-08-29 18:43:00, Current location ehvapt
# Assigning ride at index 154 to bus 1.
# Ride at index 154 arrives at: 2024-08-29 19:10:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2024-08-29 19:10:00, new current location is ehvbst.
# Iteration 32: Current time 2024-08-29 19:10:00, Current location ehvbst
# Assigning ride at index 239 to bus 1.
# Ride at index 239 arrives at: 2024-08-29 19:35:00
# Ride ends at 2024-08-29 19:35:00, new current location is ehvapt.
# Iteration 33: Current time 2024-08-29 19:35:00, Current location ehvapt
# Assigning ride at index 75 to bus 1.
# Ride at index 75 arrives at: 2024-08-29 20:02:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 20:02:00, new current location is ehvbst.
# Iteration 34: Current time 2024-08-29 21:02:00, Current location ehvbst
# Assigning ride at index 245 to bus 1.
# Ride at index 245 arrives at: 2024-08-29 21:28:00
# Ride ends at 2024-08-29 21:28:00, new current location is ehvapt.
# Iteration 35: Current time 2024-08-29 21:28:00, Current location ehvapt
# Assigning ride at index 80 to bus 1.
# Ride at index 80 arrives at: 2024-08-29 21:56:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 21:56:00, new current location is ehvbst.
# Iteration 36: Current time 2024-08-29 21:56:00, Current location ehvbst
# Assigning ride at index 247 to bus 1.
# Ride at index 247 arrives at: 2024-08-29 22:28:00
# Ride ends at 2024-08-29 22:28:00, new current location is ehvapt.
# Iteration 37: Current time 2024-08-29 22:28:00, Current location ehvapt
# Assigning ride at index 82 to bus 1.
# Ride at index 82 arrives at: 2024-08-29 22:56:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 22:56:00, new current location is ehvbst.
# Iteration 38: Current time 2024-08-29 22:56:00, Current location ehvbst
# Assigning ride at index 249 to bus 1.
# Ride at index 249 arrives at: 2024-08-29 23:28:00
# Ride ends at 2024-08-29 23:28:00, new current location is ehvapt.
# Iteration 39: Current time 2024-08-29 23:28:00, Current location ehvapt
# Assigning ride at index 84 to bus 1.
# Ride at index 84 arrives at: 2024-08-29 23:56:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 23:56:00, new current location is ehvbst.
# Iteration 40: Current time 2024-08-29 23:56:00, Current location ehvbst
# Assigning ride at index 251 to bus 1.
# Ride at index 251 arrives at: 2024-08-30 00:30:00
# Ride ends at 2024-08-30 00:30:00, new current location is ehvapt.
# Iteration 41: Current time 2024-08-30 00:30:00, Current location ehvapt
# Assigning ride at index 86 to bus 1.
# Ride at index 86 arrives at: 2024-08-30 00:52:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-30 00:52:00, new current location is ehvbst.
# Iteration 42: Current time 2024-08-30 00:52:00, Current location ehvbst
# No more rides available, terminating loop.
# Idle added from 2024-08-29 05:28:00 to 2024-08-29 06:04:00.
# Idle added from 2024-08-29 06:25:00 to 2024-08-29 06:31:00.
# Idle added from 2024-08-29 06:52:00 to 2024-08-29 06:56:00.
# Idle added from 2024-08-29 07:17:00 to 2024-08-29 07:19:00.
# Idle added from 2024-08-29 07:40:00 to 2024-08-29 07:46:00.
# Idle added from 2024-08-29 08:07:00 to 2024-08-29 08:09:00.
# Idle added from 2024-08-29 08:30:00 to 2024-08-29 08:34:00.
# Idle added from 2024-08-29 08:55:00 to 2024-08-29 08:59:00.
# Idle added from 2024-08-29 09:20:00 to 2024-08-29 09:26:00.
# Idle added from 2024-08-29 09:47:00 to 2024-08-29 09:49:00.
# Idle added from 2024-08-29 10:10:00 to 2024-08-29 10:16:00.
# Idle added from 2024-08-29 10:37:00 to 2024-08-29 10:39:00.
# Idle added from 2024-08-29 11:00:00 to 2024-08-29 11:04:00.
# Idle added from 2024-08-29 11:25:00 to 2024-08-29 11:29:00.
# Idle added from 2024-08-29 11:50:00 to 2024-08-29 11:56:00.
# Idle added from 2024-08-29 12:17:00 to 2024-08-29 13:19:00.
# Idle added from 2024-08-29 13:40:00 to 2024-08-29 13:46:00.
# Idle added from 2024-08-29 14:07:00 to 2024-08-29 14:09:00.
# Idle added from 2024-08-29 14:30:00 to 2024-08-29 14:34:00.
# Idle added from 2024-08-29 14:55:00 to 2024-08-29 14:59:00.
# Idle added from 2024-08-29 15:20:00 to 2024-08-29 15:26:00.
# Idle added from 2024-08-29 15:47:00 to 2024-08-29 15:49:00.
# Idle added from 2024-08-29 16:10:00 to 2024-08-29 16:16:00.
# Idle added from 2024-08-29 16:37:00 to 2024-08-29 16:39:00.
# Idle added from 2024-08-29 17:00:00 to 2024-08-29 17:04:00.
# Idle added from 2024-08-29 17:25:00 to 2024-08-29 17:29:00.
# Idle added from 2024-08-29 17:50:00 to 2024-08-29 17:56:00.
# Idle added from 2024-08-29 18:17:00 to 2024-08-29 18:22:00.
# Idle added from 2024-08-29 18:43:00 to 2024-08-29 18:49:00.
# Idle added from 2024-08-29 19:10:00 to 2024-08-29 19:14:00.
# Idle added from 2024-08-29 19:35:00 to 2024-08-29 19:41:00.
# Idle added from 2024-08-29 20:02:00 to 2024-08-29 21:07:00.
# Idle added from 2024-08-29 21:28:00 to 2024-08-29 21:35:00.
# Idle added from 2024-08-29 21:56:00 to 2024-08-29 22:07:00.
# Idle added from 2024-08-29 22:28:00 to 2024-08-29 22:35:00.
# Idle added from 2024-08-29 22:56:00 to 2024-08-29 23:07:00.
# Idle added from 2024-08-29 23:28:00 to 2024-08-29 23:35:00.
# Idle added from 2024-08-29 23:56:00 to 2024-08-30 00:09:00.
# Idle added from 2024-08-30 00:30:00 to 2024-08-30 00:31:00.
# Aantal regels in df_dienstregeling: 328
# Aantal regels in df_omloopnummer_1: 46
# Aantal regels in df_remaining: 288
#     startlocatie vertrektijd      eindlocatie  buslijn
# 1         ehvapt    06:34:00           ehvbst      401
# 3         ehvapt    07:11:00           ehvbst      401
# 4         ehvapt    07:26:00           ehvbst      401
# 5         ehvapt    07:36:00           ehvbst      401
# 7         ehvapt    07:56:00           ehvbst      401
# ..           ...         ...              ...      ...
# 323       ehvbst    18:54:00           ehvapt      400
# 324       ehvbst    19:07:00           ehvapt      400
# 325       ehvbst    19:22:00           ehvapt      400
# 326          NaN         NaT              NaN        0
# 327       ehvbst    19:45:00  foute test data      395
#
# [288 rows x 4 columns]

# %%
def get_remaining_rows(df_dienstregeling, df_omloopnummer_1):
    # Vervang NaN waarden door een standaardwaarde, bijvoorbeeld 0
    df_dienstregeling['buslijn'] = df_dienstregeling['buslijn'].fillna(0).astype(int)
    df_omloopnummer_1['buslijn'] = df_omloopnummer_1['buslijn'].fillna(0).astype(int)

    # Converteer tijden naar een gemeenschappelijke representatie voor vergelijking
    df_dienstregeling['vertrektijd'] = pd.to_datetime(df_dienstregeling['vertrektijd'], format='%H:%M', errors='coerce').dt.time
    df_omloopnummer_1['vertrek_datetime'] = pd.to_datetime(df_omloopnummer_1['vertrek_datetime'], errors='coerce').dt.time

    # Maakt strings voor vergelijking
    df_dienstregeling['compare_key'] = df_dienstregeling.apply(
        lambda x: f"{x['startlocatie']}|{x['eindlocatie']}|{x['vertrektijd']}|{x['buslijn']}", axis=1
    )
    df_omloopnummer_1['compare_key'] = df_omloopnummer_1.apply(
        lambda x: f"{x['startlocatie']}|{x['eindlocatie']}|{x['vertrek_datetime']}|{x['buslijn']}", axis=1
    )

    # Haal de compare_keys op die uniek zijn voor df_dienstregeling
    unique_keys = set(df_dienstregeling['compare_key']) - set(df_omloopnummer_1['compare_key'])

    # Filter rijen in df_dienstregeling die uniek zijn
    remaining_df = df_dienstregeling[df_dienstregeling['compare_key'].isin(unique_keys)].drop(columns=['compare_key'])
    
    return remaining_df

# Gebruik de functie om de resterende regels te krijgen
df_remaining = get_remaining_rows(df_dienstregeling, df_omloopnummer_1)

# Print de resultaten
print(f"Aantal regels in df_dienstregeling: {df_dienstregeling.shape[0]}")
print(f"Aantal regels in df_omloopnummer_1: {df_omloopnummer_1.shape[0]}")
print(f"Aantal regels in df_remaining: {df_remaining.shape[0]}")
print(df_remaining)
# Out:
# Aantal regels in df_dienstregeling: 328
# Aantal regels in df_omloopnummer_1: 46
# Aantal regels in df_remaining: 2
#     startlocatie vertrektijd      eindlocatie  buslijn
# 326          NaN         NaT              NaN        0
# 327       ehvbst         NaT  foute test data      395

# %% [markdown]
# ## Beste versie tot nu toe

# %%
import pandas as pd
from datetime import timedelta

# Constante variabelen
ENERGIE_VERBRUIK_PER_KM = 1.2  # kWh per gereden kilometer
OPLAADKRACHT_PER_UUR = 450  # kWh per uur tot 90%
MAX_BATT_CAPA = 300  # kWh
SOC_START = 0.9  # factor
SOC_MIN = 0.1  # factor
BATTERIJ_SLIJTAGE = 0.9  # Factor
SOH = MAX_BATT_CAPA * BATTERIJ_SLIJTAGE

def load_data():
    """Functie om data in te laden."""
    df_omloopplanning = pd.read_excel('omloopplanning.xlsx', engine='openpyxl')
    df_dienstregeling = pd.read_excel('Connexxion data - 2024-2025.xlsx', engine='openpyxl')
    df_afstandsmatrix = pd.read_excel('Connexxion data - 2024-2025.xlsx', engine='openpyxl', sheet_name='Afstandsmatrix')
    return df_omloopplanning, df_dienstregeling, df_afstandsmatrix

def create_parameters_df():
    """Functie om een parameters DataFrame te maken."""
    soc_ochtend = SOH * SOC_START
    soc_minimum = SOH * SOC_MIN
    data = {
        'Parameter': ['Max Batterij Capaciteit', 'SOC Start', 'SOC Minimum', 'Batterij Slijtage', 'SOH', 'SOC Ochtend', 'SOC Minimum', 'Batterijverbuik', 'Oplaadsnelheid'],
        'Waarde': [MAX_BATT_CAPA, SOC_START, SOC_MIN, BATTERIJ_SLIJTAGE, SOH, soc_ochtend, soc_minimum, ENERGIE_VERBRUIK_PER_KM, OPLAADKRACHT_PER_UUR],
        'Eenheid': ['kWh', 'Factor', 'Factor', 'Factor', 'kW (MBC * BS)', 'kW (SOH * SOC S)', 'kW (SOH * SOC M)', 'kWh/km', 'kWh/uur']
    }
    return pd.DataFrame(data)

def convert_to_datetime(time_str):
    """Functie om tijden naar datetime om te zetten."""
    if pd.isna(time_str):
        # Als de tijd ontbreekt, retourneer een NaT Timestamp
        return pd.NaT

    try:
        time_obj = pd.to_datetime(time_str, format='%H:%M').time()
    except TypeError:
        # Fallback als time_str geen geschikt formaat heeft
        return pd.NaT

    upper_boundary = pd.to_datetime('23:59', format='%H:%M').time()
    lower_boundary = pd.to_datetime('04:00', format='%H:%M').time()
    
    if lower_boundary <= time_obj <= upper_boundary:
        return pd.Timestamp('2024-08-29') + pd.Timedelta(hours=time_obj.hour, minutes=time_obj.minute)
    else:
        return pd.Timestamp('2024-08-30') + pd.Timedelta(hours=time_obj.hour, minutes=time_obj.minute)

def process_schedule_data(df_dienstregeling):
    """Functie om de nieuwe dienstregeling te verwerken."""
    df = df_dienstregeling.copy()
    
    # Vervang NaN door een standaardwaarde voordat je de conversie uitvoert
    df['buslijn'] = df['buslijn'].fillna(0).astype(int).astype(str)

    df['vertrek_datetime'] = df['vertrektijd'].apply(convert_to_datetime)
    df['Omloop'] = 0
    df_sorted = df.sort_values(by=['vertrek_datetime', 'buslijn'])
    df_sorted['code_omloop'] = df_sorted['startlocatie'].str.strip().str.lower() + '_' + \
                               df_sorted['eindlocatie'].str.strip().str.lower() + '_' + \
                               df_sorted['buslijn']
    return df_sorted

def process_distance_matrix(df_afstandsmatrix):
    """Functie om de afstandsmatrix te verwerken."""
    df = df_afstandsmatrix.copy()
    df['buslijn'] = df['buslijn'].fillna(0).astype(int).astype(str)
    df['code_afstand'] = df['startlocatie'].str.strip().str.lower() + '_' + \
                         df['eindlocatie'].str.strip().str.lower() + '_' + \
                         df['buslijn']
    return df

def setUpDataframes(df_nieuwe_dienstregelingv2, df_afstandsmatrix):
    """Kopieer en bereid dataframes voor gebruik voor de inplanting."""
    df = df_nieuwe_dienstregelingv2.copy()
    df['vertrek_datetime'] = pd.to_datetime(df['vertrek_datetime'])
    df['aankomst_datetime'] = pd.NaT
    df['Omloop'] = pd.NA
    return df

def vindt_reistijd(df_afstandsmatrix, startlocatie, eindlocatie):
    """Vind de reistijd tussen start- en eindlocatie."""
    rij = df_afstandsmatrix[
        (df_afstandsmatrix['startlocatie'] == startlocatie) &
        (df_afstandsmatrix['eindlocatie'] == eindlocatie)
    ]
    if not rij.empty:
        return int(rij['min reistijd in min'].values[0])
    return None

def inplannen_busritten(df_ritten, df_afstandsmatrix):
    """Functie om busritten in te plannen met een verplichte rusttijd na elke vijfde keer bij 'ehvbst'."""
    bus_nr = 1
    actuele_tijd = df_ritten.iloc[0]['vertrek_datetime'] - timedelta(minutes=4)  # Start bij de garage
    huidige_locatie = 'ehvgar'
    count_ehvbst = 0  # Tel hoe vaak de bus bij 'ehvbst' is aangekomen
    iteration_count = 0

    while True:
        iteration_count += 1
        print(f"Iteration {iteration_count}: Current time {actuele_tijd}, Current location {huidige_locatie}")

        mogelijk_ritten = df_ritten[
            (df_ritten['Omloop'].isna()) & 
            (df_ritten['vertrek_datetime'] >= actuele_tijd) & 
            (df_ritten['startlocatie'] == huidige_locatie)
        ]

        if not mogelijk_ritten.empty:
            row = mogelijk_ritten.iloc[0]  # Kies de eerst mogelijke rit
            print(f"Assigning ride at index {row.name} to bus {bus_nr}.")
            df_ritten.at[row.name, 'Omloop'] = bus_nr

            rit_duur = vindt_reistijd(df_afstandsmatrix, row['startlocatie'], row['eindlocatie'])
            if rit_duur is not None:
                aankomsttijd = row['vertrek_datetime'] + timedelta(minutes=rit_duur)
                df_ritten.at[row.name, 'aankomst_datetime'] = aankomsttijd
                print(f"Ride at index {row.name} arrives at: {aankomsttijd}")

                actuele_tijd = aankomsttijd
                huidige_locatie = row['eindlocatie']

                # Bijhouden hoe vaak 'ehvbst' bereikt is
                if huidige_locatie == 'ehvbst':
                    count_ehvbst += 1
                    print(f"Bus has now arrived at 'ehvbst' {count_ehvbst} times.")
                    
                    # Bij elke 5e keer een pauze van een uur incasseren
                    if count_ehvbst == 8:
                        print("Taking a break for 1 hour at 'ehvbst'.")
                        actuele_tijd += timedelta(hours=1)
                        count_ehvbst = 0  # Reset de teller
                
                print(f"Ride ends at {aankomsttijd}, new current location is {huidige_locatie}.")
            continue

        volgende_startlocaties = df_ritten[
            (df_ritten['Omloop'].isna()) &
            (df_ritten['vertrek_datetime'] > actuele_tijd)
        ]

        if volgende_startlocaties.empty:
            print("No more rides available, terminating loop.")
            break

        next_location_found = False
        for _, row in volgende_startlocaties.iterrows():
            reistijd = vindt_reistijd(df_afstandsmatrix, huidige_locatie, row['startlocatie'])
            if reistijd is not None and (actuele_tijd + timedelta(minutes=reistijd)) <= row['vertrek_datetime']:
                print(f"Moving to new start location {row['startlocatie']} with travel time {reistijd} minutes.")
                actuele_tijd += timedelta(minutes=reistijd)
                huidige_locatie = row['startlocatie']
                next_location_found = True
                break

        if not next_location_found:
            print("Unable to find a valid next location, terminating loop.")
            break

    return df_ritten

def filter_and_calculate(df_ritten, df_afstandsmatrix):
    """Filter de DataFrame en bereken afstand en batterijverbruik."""
    omloop_1_df = df_ritten[df_ritten['Omloop'] == 1].copy()

    # Voeg de 'afstand in meters' toe uit de afstandsmatrix
    omloop_1_df = omloop_1_df.merge(
        df_afstandsmatrix[['code_afstand', 'afstand in meters']],
        left_on='code_omloop',
        right_on='code_afstand',
        how='left'
    )

    # Kies de juiste kolom na de merge
    omloop_1_df['afstand in meters'] = omloop_1_df['afstand in meters_y'].fillna(0)

    # Verwijder onnodige suffixed kolommen
    kolommen_verwijderen = ['afstand in meters_x', 'afstand in meters_y', 'code_afstand_x', 'code_afstand_y']
    bestaande_kolommen = [kolom for kolom in kolommen_verwijderen if kolom in omloop_1_df.columns]
    omloop_1_df.drop(columns=bestaande_kolommen, inplace=True)

    # Bereken de afstand in kilometers
    omloop_1_df['afstand in km'] = omloop_1_df['afstand in meters'] / 1000

    # Bereken batterijgebruik voor actieve activiteit
    omloop_1_df['Batterijgebruik'] = omloop_1_df['afstand in km'] * ENERGIE_VERBRUIK_PER_KM

    # Stel batterijgebruik in op 0.01 als de activiteit 'idle' is
    omloop_1_df.loc[omloop_1_df['activiteit'] == 'idle', 'Batterijgebruik'] = 0.01

    return omloop_1_df

def add_activiteit_column(df):
    """Voegt een 'activiteit' kolom toe gebaseerd op de aanwezigheid van een omloopnummer."""
    df['activiteit'] = df['Omloop'].apply(lambda x: 'dienstrit' if pd.notna(x) else 'geen dienst')
    return df

def add_idle_activity(df):
    """Voegt 'idle' activiteiten toe waar nodig."""
    rows_to_add = []

    # Sorteer het DataFrame op basis van vertrektijd, zodat ritten op volgorde worden verwerkt.
    df = df.sort_values(by='vertrek_datetime').reset_index(drop=True)

    for i in range(1, len(df)):
        vorige_rit = df.iloc[i - 1]
        huidige_rit = df.iloc[i]

        # Controleer beide datetimes en zorg dat de times valid zijn voor het bepalen van idle tijd
        if pd.notna(vorige_rit['aankomst_datetime']) and vorige_rit['aankomst_datetime'] < huidige_rit['vertrek_datetime']:
            idle_start = vorige_rit['aankomst_datetime']
            # Idle activiteit eindigt bij de start van de volgende rit
            idle_end = huidige_rit['vertrek_datetime']

            # Voeg een rij toe voor de "idle" periode
            rows_to_add.append({
                'startlocatie': vorige_rit['eindlocatie'],
                'eindlocatie': vorige_rit['eindlocatie'],
                'vertrek_datetime': idle_start,
                'aankomst_datetime': idle_end,
                'buslijn': '',
                'Omloop': vorige_rit['Omloop'],
                'activiteit': 'idle',
                'afstand in meters': 0,
                'afstand in km': 0,
                'Batterijgebruik': 0.01,
                 'code_omloop': str(huidige_rit['startlocatie']) + '_' + \
                                str(huidige_rit['startlocatie']) + '_' + \
                                str('Idle')
            })
            # Debug print om te zien welke idle rij toegevoegd is
            print(f"Idle added from {idle_start} to {idle_end}.")

    # Voeg de 'idle' rijen toe aan de DataFrame als er rijen zijn
    if rows_to_add:
        idle_df = pd.DataFrame(rows_to_add)
        df = pd.concat([df, idle_df], ignore_index=True)

    # Herverdeel de DataFrame om ervoor te zorgen dat alles op volgorde staat
    df = df.sort_values(by='vertrek_datetime').reset_index(drop=True)
    return df

def calculate_soc(df, initial_soc=243):
    """Voegt SOC_start en SOC_eind kolommen toe aan de DataFrame."""
    # Sorteren is belangrijk om juiste volgorde te behouden
    df = df.sort_values(['Omloop', 'vertrek_datetime']).reset_index(drop=True)

    # Initialiseren van de SOC kolommen
    df['SOC_start'] = 0.0
    df['SOC_eind'] = 0.0
    
    for omloop in df['Omloop'].unique():
        omloop_data = df[df['Omloop'] == omloop]
        prev_soc_eind = initial_soc
        
        for index, row in omloop_data.iterrows():
            if index == omloop_data.index[0]:  # Eerste rit van Omloop
                soc_start = initial_soc
            else:
                soc_start = prev_soc_eind

            # Bereken de SOC_eind
            soc_eind = soc_start - row['Batterijgebruik']

            # Update DataFrame
            df.at[index, 'SOC_start'] = soc_start
            df.at[index, 'SOC_eind'] = soc_eind

            # Update previous SOC_eind for next iteration
            prev_soc_eind = soc_eind

    return df

def manage_battery_and_charging(df, target_soc=243, drive_time=timedelta(minutes=4), charge_duration=timedelta(minutes=45)):
    """Laad de bus op als er een uur idle tijd is tussen de aankomst en het vertrek van ritten."""
    df = df.sort_values(['Omloop', 'vertrek_datetime']).reset_index(drop=True)
    adjusted_rows = []
    prev_soc_eind = target_soc  # Begin met volle lading

    # Default structure for a row
    default_row = {
        'startlocatie': None,
        'eindlocatie': None,
        'vertrektijd': None,
        'buslijn': None,
        'vertrek_datetime': None,
        'aankomst_datetime': None,
        'Omloop': None,
        'code_omloop': None,
        'activiteit': None,
        'afstand in km': None,
        'Batterijgebruik': None,
        'code_afstand': None,
        'afstand in meters': None,
        'SOC_start': None,
        'SOC_eind': None,
    }

    for index, row in df.iterrows():
        soc_start = prev_soc_eind if index != 0 else target_soc
        soc_eind = soc_start - row['Batterijgebruik']

        # Voeg de huidige rit toe
        adjusted_rows.append({
            **default_row,
            **row.to_dict(),
            'SOC_start': soc_start,
            'SOC_eind': soc_eind,
        })
        prev_soc_eind = soc_eind

        # Check of er een uur idle tijd is na deze rit
        if index < len(df) - 1:
            next_row = df.iloc[index + 1]

            # Bereken de idle tijd tussen de huidige aankomst en de volgende vertrek
            idle_time = next_row['vertrek_datetime'] - row['aankomst_datetime']

            # Als er voldoende idle tijd is
            if idle_time >= timedelta(hours=1):
                # Voeg materiaalrit naar garage toe
                to_garage_end_time = row['aankomst_datetime'] + drive_time
                adjusted_rows.append({
                    **default_row,
                    'startlocatie': row['eindlocatie'],
                    'eindlocatie': 'ehvgarage',
                    'vertrek_datetime': row['aankomst_datetime'],
                    'aankomst_datetime': to_garage_end_time,
                    'activiteit': 'materiaalrit',
                    'Batterijgebruik': 0.2,
                    'SOC_start': soc_eind,
                    'SOC_eind': soc_eind - 0.2,
                    'Omloop': row['Omloop']
                })

                # Laad de bus op
                charge_time_start = to_garage_end_time
                soc_charged = target_soc  # Doel SOC

                charge_time_end = charge_time_start + charge_duration
                adjusted_rows.append({
                    **default_row,
                    'startlocatie': 'ehvgarage',
                    'eindlocatie': 'ehvgarage',
                    'vertrek_datetime': charge_time_start,
                    'aankomst_datetime': charge_time_end,
                    'activiteit': 'opladen',
                    'Batterijgebruik': (soc_eind - 0.2 - soc_charged),  # Negatief om opladen aan te geven
                    'SOC_start': soc_eind - 0.2,
                    'SOC_eind': soc_charged,
                    'Omloop': row['Omloop']
                })

                # Materiaal rit terug naar de oorspronkelijke eindlocatie
                return_time = charge_time_end + drive_time
                adjusted_rows.append({
                    **default_row,
                    'startlocatie': 'ehvgarage',
                    'eindlocatie': row['eindlocatie'],
                    'vertrek_datetime': charge_time_end,
                    'aankomst_datetime': return_time,
                    'activiteit': 'materiaalrit',
                    'Batterijgebruik': 0.2,
                    'SOC_start': soc_charged,
                    'SOC_eind': soc_charged - 0.2,
                    'Omloop': row['Omloop']
                })

                prev_soc_eind = soc_charged - 0.2

    adjusted_df = pd.DataFrame(adjusted_rows)
    adjusted_df = adjusted_df.sort_values(by='vertrek_datetime').reset_index(drop=True)
    return adjusted_df

# Inladen van data
df_omloopplanning, df_dienstregeling, df_afstandsmatrix = load_data()

# Maak de parameters DataFrame en laat deze zien
df_parameters = create_parameters_df()
display(df_parameters)

# Verwerk dienstregeling en afstandsmatrix data
df_nieuwe_dienstregelingv2 = process_schedule_data(df_dienstregeling)
df_afstandsmatrix = process_distance_matrix(df_afstandsmatrix)

# Setting up the dataframes
df_nieuwe_dienstregelingv1 = setUpDataframes(df_nieuwe_dienstregelingv2, df_afstandsmatrix)

# Plan de busritten
df_processed_ritten = inplannen_busritten(df_nieuwe_dienstregelingv1, df_afstandsmatrix)

# Voer de functie uit na het verwerken van ritten
df_processed_ritten = add_activiteit_column(df_processed_ritten)

# Voeg de idle activiteiten in de verwerkte ritten toe
# Voer een test uit en controleer op output
df_with_idle = add_idle_activity(df_processed_ritten[df_processed_ritten['Omloop'] == 1])
# display(df_with_idle[df_with_idle['activiteit'] == 'idle'])
# display(df_with_idle.head(50))

# Filter en bereken
omloop_df = filter_and_calculate(df_with_idle, df_afstandsmatrix)

# Toevoegen van SOC kolommen aan de DataFrame met ritten
df_with_soc = calculate_soc(omloop_df)

# Filter out rows with 'idle' activity and simulate battery charging and material trips
df_filtered = df_with_soc[df_with_soc['activiteit'] != 'idle']
display(df_filtered.head(50))
df_adjusted = manage_battery_and_charging(df_filtered)

# Weergeven van het resultaat
display(df_adjusted)
# Out:
#                  Parameter  Waarde           Eenheid
# 0  Max Batterij Capaciteit   300.0               kWh
# 1                SOC Start     0.9            Factor
# 2              SOC Minimum     0.1            Factor
# 3        Batterij Slijtage     0.9            Factor
# 4                      SOH   270.0     kW (MBC * BS)
# 5              SOC Ochtend   243.0  kW (SOH * SOC S)
# 6              SOC Minimum    27.0  kW (SOH * SOC M)
# 7          Batterijverbuik     1.2            kWh/km
# 8           Oplaadsnelheid   450.0           kWh/uur
# Iteration 1: Current time 2024-08-29 05:03:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2024-08-29 05:07:00, Current location ehvbst
# Assigning ride at index 163 to bus 1.
# Ride at index 163 arrives at: 2024-08-29 05:28:00
# Ride ends at 2024-08-29 05:28:00, new current location is ehvapt.
# Iteration 3: Current time 2024-08-29 05:28:00, Current location ehvapt
# Assigning ride at index 0 to bus 1.
# Ride at index 0 arrives at: 2024-08-29 06:25:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 06:25:00, new current location is ehvbst.
# Iteration 4: Current time 2024-08-29 06:25:00, Current location ehvbst
# Assigning ride at index 166 to bus 1.
# Ride at index 166 arrives at: 2024-08-29 06:52:00
# Ride ends at 2024-08-29 06:52:00, new current location is ehvapt.
# Iteration 5: Current time 2024-08-29 06:52:00, Current location ehvapt
# Assigning ride at index 2 to bus 1.
# Ride at index 2 arrives at: 2024-08-29 07:17:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 07:17:00, new current location is ehvbst.
# Iteration 6: Current time 2024-08-29 07:17:00, Current location ehvbst
# Assigning ride at index 170 to bus 1.
# Ride at index 170 arrives at: 2024-08-29 07:40:00
# Ride ends at 2024-08-29 07:40:00, new current location is ehvapt.
# Iteration 7: Current time 2024-08-29 07:40:00, Current location ehvapt
# Assigning ride at index 6 to bus 1.
# Ride at index 6 arrives at: 2024-08-29 08:07:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 08:07:00, new current location is ehvbst.
# Iteration 8: Current time 2024-08-29 08:07:00, Current location ehvbst
# Assigning ride at index 175 to bus 1.
# Ride at index 175 arrives at: 2024-08-29 08:30:00
# Ride ends at 2024-08-29 08:30:00, new current location is ehvapt.
# Iteration 9: Current time 2024-08-29 08:30:00, Current location ehvapt
# Assigning ride at index 93 to bus 1.
# Ride at index 93 arrives at: 2024-08-29 08:55:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 08:55:00, new current location is ehvbst.
# Iteration 10: Current time 2024-08-29 08:55:00, Current location ehvbst
# Assigning ride at index 180 to bus 1.
# Ride at index 180 arrives at: 2024-08-29 09:20:00
# Ride ends at 2024-08-29 09:20:00, new current location is ehvapt.
# Iteration 11: Current time 2024-08-29 09:20:00, Current location ehvapt
# Assigning ride at index 16 to bus 1.
# Ride at index 16 arrives at: 2024-08-29 09:47:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2024-08-29 09:47:00, new current location is ehvbst.
# Iteration 12: Current time 2024-08-29 09:47:00, Current location ehvbst
# Assigning ride at index 185 to bus 1.
# Ride at index 185 arrives at: 2024-08-29 10:10:00
# Ride ends at 2024-08-29 10:10:00, new current location is ehvapt.
# Iteration 13: Current time 2024-08-29 10:10:00, Current location ehvapt
# Assigning ride at index 21 to bus 1.
# Ride at index 21 arrives at: 2024-08-29 10:37:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2024-08-29 10:37:00, new current location is ehvbst.
# Iteration 14: Current time 2024-08-29 10:37:00, Current location ehvbst
# Assigning ride at index 190 to bus 1.
# Ride at index 190 arrives at: 2024-08-29 11:00:00
# Ride ends at 2024-08-29 11:00:00, new current location is ehvapt.
# Iteration 15: Current time 2024-08-29 11:00:00, Current location ehvapt
# Assigning ride at index 108 to bus 1.
# Ride at index 108 arrives at: 2024-08-29 11:25:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2024-08-29 11:25:00, new current location is ehvbst.
# Iteration 16: Current time 2024-08-29 11:25:00, Current location ehvbst
# Assigning ride at index 195 to bus 1.
# Ride at index 195 arrives at: 2024-08-29 11:50:00
# Ride ends at 2024-08-29 11:50:00, new current location is ehvapt.
# Iteration 17: Current time 2024-08-29 11:50:00, Current location ehvapt
# Assigning ride at index 31 to bus 1.
# Ride at index 31 arrives at: 2024-08-29 12:17:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 12:17:00, new current location is ehvbst.
# Iteration 18: Current time 2024-08-29 13:17:00, Current location ehvbst
# Assigning ride at index 206 to bus 1.
# Ride at index 206 arrives at: 2024-08-29 13:40:00
# Ride ends at 2024-08-29 13:40:00, new current location is ehvapt.
# Iteration 19: Current time 2024-08-29 13:40:00, Current location ehvapt
# Assigning ride at index 42 to bus 1.
# Ride at index 42 arrives at: 2024-08-29 14:07:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 14:07:00, new current location is ehvbst.
# Iteration 20: Current time 2024-08-29 14:07:00, Current location ehvbst
# Assigning ride at index 211 to bus 1.
# Ride at index 211 arrives at: 2024-08-29 14:30:00
# Ride ends at 2024-08-29 14:30:00, new current location is ehvapt.
# Iteration 21: Current time 2024-08-29 14:30:00, Current location ehvapt
# Assigning ride at index 129 to bus 1.
# Ride at index 129 arrives at: 2024-08-29 14:55:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 14:55:00, new current location is ehvbst.
# Iteration 22: Current time 2024-08-29 14:55:00, Current location ehvbst
# Assigning ride at index 216 to bus 1.
# Ride at index 216 arrives at: 2024-08-29 15:20:00
# Ride ends at 2024-08-29 15:20:00, new current location is ehvapt.
# Iteration 23: Current time 2024-08-29 15:20:00, Current location ehvapt
# Assigning ride at index 52 to bus 1.
# Ride at index 52 arrives at: 2024-08-29 15:47:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 15:47:00, new current location is ehvbst.
# Iteration 24: Current time 2024-08-29 15:47:00, Current location ehvbst
# Assigning ride at index 221 to bus 1.
# Ride at index 221 arrives at: 2024-08-29 16:10:00
# Ride ends at 2024-08-29 16:10:00, new current location is ehvapt.
# Iteration 25: Current time 2024-08-29 16:10:00, Current location ehvapt
# Assigning ride at index 57 to bus 1.
# Ride at index 57 arrives at: 2024-08-29 16:37:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 16:37:00, new current location is ehvbst.
# Iteration 26: Current time 2024-08-29 16:37:00, Current location ehvbst
# Assigning ride at index 226 to bus 1.
# Ride at index 226 arrives at: 2024-08-29 17:00:00
# Ride ends at 2024-08-29 17:00:00, new current location is ehvapt.
# Iteration 27: Current time 2024-08-29 17:00:00, Current location ehvapt
# Assigning ride at index 144 to bus 1.
# Ride at index 144 arrives at: 2024-08-29 17:25:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2024-08-29 17:25:00, new current location is ehvbst.
# Iteration 28: Current time 2024-08-29 17:25:00, Current location ehvbst
# Assigning ride at index 231 to bus 1.
# Ride at index 231 arrives at: 2024-08-29 17:50:00
# Ride ends at 2024-08-29 17:50:00, new current location is ehvapt.
# Iteration 29: Current time 2024-08-29 17:50:00, Current location ehvapt
# Assigning ride at index 67 to bus 1.
# Ride at index 67 arrives at: 2024-08-29 18:17:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2024-08-29 18:17:00, new current location is ehvbst.
# Iteration 30: Current time 2024-08-29 18:17:00, Current location ehvbst
# Assigning ride at index 319 to bus 1.
# Ride at index 319 arrives at: 2024-08-29 18:43:00
# Ride ends at 2024-08-29 18:43:00, new current location is ehvapt.
# Iteration 31: Current time 2024-08-29 18:43:00, Current location ehvapt
# Assigning ride at index 154 to bus 1.
# Ride at index 154 arrives at: 2024-08-29 19:10:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2024-08-29 19:10:00, new current location is ehvbst.
# Iteration 32: Current time 2024-08-29 19:10:00, Current location ehvbst
# Assigning ride at index 239 to bus 1.
# Ride at index 239 arrives at: 2024-08-29 19:35:00
# Ride ends at 2024-08-29 19:35:00, new current location is ehvapt.
# Iteration 33: Current time 2024-08-29 19:35:00, Current location ehvapt
# Assigning ride at index 75 to bus 1.
# Ride at index 75 arrives at: 2024-08-29 20:02:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 20:02:00, new current location is ehvbst.
# Iteration 34: Current time 2024-08-29 21:02:00, Current location ehvbst
# Assigning ride at index 245 to bus 1.
# Ride at index 245 arrives at: 2024-08-29 21:28:00
# Ride ends at 2024-08-29 21:28:00, new current location is ehvapt.
# Iteration 35: Current time 2024-08-29 21:28:00, Current location ehvapt
# Assigning ride at index 80 to bus 1.
# Ride at index 80 arrives at: 2024-08-29 21:56:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 21:56:00, new current location is ehvbst.
# Iteration 36: Current time 2024-08-29 21:56:00, Current location ehvbst
# Assigning ride at index 247 to bus 1.
# Ride at index 247 arrives at: 2024-08-29 22:28:00
# Ride ends at 2024-08-29 22:28:00, new current location is ehvapt.
# Iteration 37: Current time 2024-08-29 22:28:00, Current location ehvapt
# Assigning ride at index 82 to bus 1.
# Ride at index 82 arrives at: 2024-08-29 22:56:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 22:56:00, new current location is ehvbst.
# Iteration 38: Current time 2024-08-29 22:56:00, Current location ehvbst
# Assigning ride at index 249 to bus 1.
# Ride at index 249 arrives at: 2024-08-29 23:28:00
# Ride ends at 2024-08-29 23:28:00, new current location is ehvapt.
# Iteration 39: Current time 2024-08-29 23:28:00, Current location ehvapt
# Assigning ride at index 84 to bus 1.
# Ride at index 84 arrives at: 2024-08-29 23:56:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 23:56:00, new current location is ehvbst.
# Iteration 40: Current time 2024-08-29 23:56:00, Current location ehvbst
# Assigning ride at index 251 to bus 1.
# Ride at index 251 arrives at: 2024-08-30 00:30:00
# Ride ends at 2024-08-30 00:30:00, new current location is ehvapt.
# Iteration 41: Current time 2024-08-30 00:30:00, Current location ehvapt
# Assigning ride at index 86 to bus 1.
# Ride at index 86 arrives at: 2024-08-30 00:52:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-30 00:52:00, new current location is ehvbst.
# Iteration 42: Current time 2024-08-30 00:52:00, Current location ehvbst
# No more rides available, terminating loop.
# Idle added from 2024-08-29 05:28:00 to 2024-08-29 06:04:00.
# Idle added from 2024-08-29 06:25:00 to 2024-08-29 06:31:00.
# Idle added from 2024-08-29 06:52:00 to 2024-08-29 06:56:00.
# Idle added from 2024-08-29 07:17:00 to 2024-08-29 07:19:00.
# Idle added from 2024-08-29 07:40:00 to 2024-08-29 07:46:00.
# Idle added from 2024-08-29 08:07:00 to 2024-08-29 08:09:00.
# Idle added from 2024-08-29 08:30:00 to 2024-08-29 08:34:00.
# Idle added from 2024-08-29 08:55:00 to 2024-08-29 08:59:00.
# Idle added from 2024-08-29 09:20:00 to 2024-08-29 09:26:00.
# Idle added from 2024-08-29 09:47:00 to 2024-08-29 09:49:00.
# Idle added from 2024-08-29 10:10:00 to 2024-08-29 10:16:00.
# Idle added from 2024-08-29 10:37:00 to 2024-08-29 10:39:00.
# Idle added from 2024-08-29 11:00:00 to 2024-08-29 11:04:00.
# Idle added from 2024-08-29 11:25:00 to 2024-08-29 11:29:00.
# Idle added from 2024-08-29 11:50:00 to 2024-08-29 11:56:00.
# Idle added from 2024-08-29 12:17:00 to 2024-08-29 13:19:00.
# Idle added from 2024-08-29 13:40:00 to 2024-08-29 13:46:00.
# Idle added from 2024-08-29 14:07:00 to 2024-08-29 14:09:00.
# Idle added from 2024-08-29 14:30:00 to 2024-08-29 14:34:00.
# Idle added from 2024-08-29 14:55:00 to 2024-08-29 14:59:00.
# Idle added from 2024-08-29 15:20:00 to 2024-08-29 15:26:00.
# Idle added from 2024-08-29 15:47:00 to 2024-08-29 15:49:00.
# Idle added from 2024-08-29 16:10:00 to 2024-08-29 16:16:00.
# Idle added from 2024-08-29 16:37:00 to 2024-08-29 16:39:00.
# Idle added from 2024-08-29 17:00:00 to 2024-08-29 17:04:00.
# Idle added from 2024-08-29 17:25:00 to 2024-08-29 17:29:00.
# Idle added from 2024-08-29 17:50:00 to 2024-08-29 17:56:00.
# Idle added from 2024-08-29 18:17:00 to 2024-08-29 18:22:00.
# Idle added from 2024-08-29 18:43:00 to 2024-08-29 18:49:00.
# Idle added from 2024-08-29 19:10:00 to 2024-08-29 19:14:00.
# Idle added from 2024-08-29 19:35:00 to 2024-08-29 19:41:00.
# Idle added from 2024-08-29 20:02:00 to 2024-08-29 21:07:00.
# Idle added from 2024-08-29 21:28:00 to 2024-08-29 21:35:00.
# Idle added from 2024-08-29 21:56:00 to 2024-08-29 22:07:00.
# Idle added from 2024-08-29 22:28:00 to 2024-08-29 22:35:00.
# Idle added from 2024-08-29 22:56:00 to 2024-08-29 23:07:00.
# Idle added from 2024-08-29 23:28:00 to 2024-08-29 23:35:00.
# Idle added from 2024-08-29 23:56:00 to 2024-08-30 00:09:00.
# Idle added from 2024-08-30 00:30:00 to 2024-08-30 00:31:00.
#    startlocatie vertrektijd eindlocatie buslijn    vertrek_datetime Omloop  \
# 0        ehvbst       05:07      ehvapt     401 2024-08-29 05:07:00      1
# 2        ehvapt       06:04      ehvbst     401 2024-08-29 06:04:00      1
# 4        ehvbst       06:31      ehvapt     401 2024-08-29 06:31:00      1
# 6        ehvapt       06:56      ehvbst     401 2024-08-29 06:56:00      1
# 8        ehvbst       07:19      ehvapt     401 2024-08-29 07:19:00      1
# 10       ehvapt       07:46      ehvbst     401 2024-08-29 07:46:00      1
# 12       ehvbst       08:09      ehvapt     401 2024-08-29 08:09:00      1
# 14       ehvapt       08:34      ehvbst     400 2024-08-29 08:34:00      1
# 16       ehvbst       08:59      ehvapt     401 2024-08-29 08:59:00      1
# 18       ehvapt       09:26      ehvbst     401 2024-08-29 09:26:00      1
# 20       ehvbst       09:49      ehvapt     401 2024-08-29 09:49:00      1
# 22       ehvapt       10:16      ehvbst     401 2024-08-29 10:16:00      1
# 24       ehvbst       10:39      ehvapt     401 2024-08-29 10:39:00      1
# 26       ehvapt       11:04      ehvbst     400 2024-08-29 11:04:00      1
# 28       ehvbst       11:29      ehvapt     401 2024-08-29 11:29:00      1
# 30       ehvapt       11:56      ehvbst     401 2024-08-29 11:56:00      1
# 32       ehvbst       13:19      ehvapt     401 2024-08-29 13:19:00      1
# 34       ehvapt       13:46      ehvbst     401 2024-08-29 13:46:00      1
# 36       ehvbst       14:09      ehvapt     401 2024-08-29 14:09:00      1
# 38       ehvapt       14:34      ehvbst     400 2024-08-29 14:34:00      1
# 40       ehvbst       14:59      ehvapt     401 2024-08-29 14:59:00      1
# 42       ehvapt       15:26      ehvbst     401 2024-08-29 15:26:00      1
# 44       ehvbst       15:49      ehvapt     401 2024-08-29 15:49:00      1
# 46       ehvapt       16:16      ehvbst     401 2024-08-29 16:16:00      1
# 48       ehvbst       16:39      ehvapt     401 2024-08-29 16:39:00      1
# 50       ehvapt       17:04      ehvbst     400 2024-08-29 17:04:00      1
# 52       ehvbst       17:29      ehvapt     401 2024-08-29 17:29:00      1
# 54       ehvapt       17:56      ehvbst     401 2024-08-29 17:56:00      1
# 56       ehvbst       18:22      ehvapt     400 2024-08-29 18:22:00      1
# 58       ehvapt       18:49      ehvbst     400 2024-08-29 18:49:00      1
# 60       ehvbst       19:14      ehvapt     401 2024-08-29 19:14:00      1
# 62       ehvapt       19:41      ehvbst     401 2024-08-29 19:41:00      1
# 64       ehvbst       21:07      ehvapt     401 2024-08-29 21:07:00      1
# 66       ehvapt       21:35      ehvbst     401 2024-08-29 21:35:00      1
# 68       ehvbst       22:07      ehvapt     401 2024-08-29 22:07:00      1
# 70       ehvapt       22:35      ehvbst     401 2024-08-29 22:35:00      1
# 72       ehvbst       23:07      ehvapt     401 2024-08-29 23:07:00      1
# 74       ehvapt       23:35      ehvbst     401 2024-08-29 23:35:00      1
# 76       ehvbst       00:09      ehvapt     401 2024-08-30 00:09:00      1
# 78       ehvapt       00:31      ehvbst     401 2024-08-30 00:31:00      1
#
#           code_omloop   aankomst_datetime activiteit  afstand in km  \
# 0   ehvbst_ehvapt_401 2024-08-29 05:28:00  dienstrit          9.003
# 2   ehvapt_ehvbst_401 2024-08-29 06:25:00  dienstrit          9.050
# 4   ehvbst_ehvapt_401 2024-08-29 06:52:00  dienstrit          9.003
# 6   ehvapt_ehvbst_401 2024-08-29 07:17:00  dienstrit          9.050
# 8   ehvbst_ehvapt_401 2024-08-29 07:40:00  dienstrit          9.003
# 10  ehvapt_ehvbst_401 2024-08-29 08:07:00  dienstrit          9.050
# 12  ehvbst_ehvapt_401 2024-08-29 08:30:00  dienstrit          9.003
# 14  ehvapt_ehvbst_400 2024-08-29 08:55:00  dienstrit         10.250
# 16  ehvbst_ehvapt_401 2024-08-29 09:20:00  dienstrit          9.003
# 18  ehvapt_ehvbst_401 2024-08-29 09:47:00  dienstrit          9.050
# 20  ehvbst_ehvapt_401 2024-08-29 10:10:00  dienstrit          9.003
# 22  ehvapt_ehvbst_401 2024-08-29 10:37:00  dienstrit          9.050
# 24  ehvbst_ehvapt_401 2024-08-29 11:00:00  dienstrit          9.003
# 26  ehvapt_ehvbst_400 2024-08-29 11:25:00  dienstrit         10.250
# 28  ehvbst_ehvapt_401 2024-08-29 11:50:00  dienstrit          9.003
# 30  ehvapt_ehvbst_401 2024-08-29 12:17:00  dienstrit          9.050
# 32  ehvbst_ehvapt_401 2024-08-29 13:40:00  dienstrit          9.003
# 34  ehvapt_ehvbst_401 2024-08-29 14:07:00  dienstrit          9.050
# 36  ehvbst_ehvapt_401 2024-08-29 14:30:00  dienstrit          9.003
# 38  ehvapt_ehvbst_400 2024-08-29 14:55:00  dienstrit         10.250
# 40  ehvbst_ehvapt_401 2024-08-29 15:20:00  dienstrit          9.003
# 42  ehvapt_ehvbst_401 2024-08-29 15:47:00  dienstrit          9.050
# 44  ehvbst_ehvapt_401 2024-08-29 16:10:00  dienstrit          9.003
# 46  ehvapt_ehvbst_401 2024-08-29 16:37:00  dienstrit          9.050
# 48  ehvbst_ehvapt_401 2024-08-29 17:00:00  dienstrit          9.003
# 50  ehvapt_ehvbst_400 2024-08-29 17:25:00  dienstrit         10.250
# 52  ehvbst_ehvapt_401 2024-08-29 17:50:00  dienstrit          9.003
# 54  ehvapt_ehvbst_401 2024-08-29 18:17:00  dienstrit          9.050
# 56  ehvbst_ehvapt_400 2024-08-29 18:43:00  dienstrit         10.708
# 58  ehvapt_ehvbst_400 2024-08-29 19:10:00  dienstrit         10.250
# 60  ehvbst_ehvapt_401 2024-08-29 19:35:00  dienstrit          9.003
# 62  ehvapt_ehvbst_401 2024-08-29 20:02:00  dienstrit          9.050
# 64  ehvbst_ehvapt_401 2024-08-29 21:28:00  dienstrit          9.003
# 66  ehvapt_ehvbst_401 2024-08-29 21:56:00  dienstrit          9.050
# 68  ehvbst_ehvapt_401 2024-08-29 22:28:00  dienstrit          9.003
# 70  ehvapt_ehvbst_401 2024-08-29 22:56:00  dienstrit          9.050
# 72  ehvbst_ehvapt_401 2024-08-29 23:28:00  dienstrit          9.003
# 74  ehvapt_ehvbst_401 2024-08-29 23:56:00  dienstrit          9.050
# 76  ehvbst_ehvapt_401 2024-08-30 00:30:00  dienstrit          9.003
# 78  ehvapt_ehvbst_401 2024-08-30 00:52:00  dienstrit          9.050
#
#     Batterijgebruik       code_afstand  afstand in meters  SOC_start  SOC_eind
# 0           10.8036  ehvbst_ehvapt_401             9003.0   243.0000  232.1964
# 2           10.8600  ehvapt_ehvbst_401             9050.0   232.1864  221.3264
# 4           10.8036  ehvbst_ehvapt_401             9003.0   221.3164  210.5128
# 6           10.8600  ehvapt_ehvbst_401             9050.0   210.5028  199.6428
# 8           10.8036  ehvbst_ehvapt_401             9003.0   199.6328  188.8292
# 10          10.8600  ehvapt_ehvbst_401             9050.0   188.8192  177.9592
# 12          10.8036  ehvbst_ehvapt_401             9003.0   177.9492  167.1456
# 14          12.3000  ehvapt_ehvbst_400            10250.0   167.1356  154.8356
# 16          10.8036  ehvbst_ehvapt_401             9003.0   154.8256  144.0220
# 18          10.8600  ehvapt_ehvbst_401             9050.0   144.0120  133.1520
# 20          10.8036  ehvbst_ehvapt_401             9003.0   133.1420  122.3384
# 22          10.8600  ehvapt_ehvbst_401             9050.0   122.3284  111.4684
# 24          10.8036  ehvbst_ehvapt_401             9003.0   111.4584  100.6548
# 26          12.3000  ehvapt_ehvbst_400            10250.0   100.6448   88.3448
# 28          10.8036  ehvbst_ehvapt_401             9003.0    88.3348   77.5312
# 30          10.8600  ehvapt_ehvbst_401             9050.0    77.5212   66.6612
# 32          10.8036  ehvbst_ehvapt_401             9003.0    66.6512   55.8476
# 34          10.8600  ehvapt_ehvbst_401             9050.0    55.8376   44.9776
# 36          10.8036  ehvbst_ehvapt_401             9003.0    44.9676   34.1640
# 38          12.3000  ehvapt_ehvbst_400            10250.0    34.1540   21.8540
# 40          10.8036  ehvbst_ehvapt_401             9003.0    21.8440   11.0404
# 42          10.8600  ehvapt_ehvbst_401             9050.0    11.0304    0.1704
# 44          10.8036  ehvbst_ehvapt_401             9003.0     0.1604  -10.6432
# 46          10.8600  ehvapt_ehvbst_401             9050.0   -10.6532  -21.5132
# 48          10.8036  ehvbst_ehvapt_401             9003.0   -21.5232  -32.3268
# 50          12.3000  ehvapt_ehvbst_400            10250.0   -32.3368  -44.6368
# 52          10.8036  ehvbst_ehvapt_401             9003.0   -44.6468  -55.4504
# 54          10.8600  ehvapt_ehvbst_401             9050.0   -55.4604  -66.3204
# 56          12.8496  ehvbst_ehvapt_400            10708.0   -66.3304  -79.1800
# 58          12.3000  ehvapt_ehvbst_400            10250.0   -79.1900  -91.4900
# 60          10.8036  ehvbst_ehvapt_401             9003.0   -91.5000 -102.3036
# 62          10.8600  ehvapt_ehvbst_401             9050.0  -102.3136 -113.1736
# 64          10.8036  ehvbst_ehvapt_401             9003.0  -113.1836 -123.9872
# 66          10.8600  ehvapt_ehvbst_401             9050.0  -123.9972 -134.8572
# 68          10.8036  ehvbst_ehvapt_401             9003.0  -134.8672 -145.6708
# 70          10.8600  ehvapt_ehvbst_401             9050.0  -145.6808 -156.5408
# 72          10.8036  ehvbst_ehvapt_401             9003.0  -156.5508 -167.3544
# 74          10.8600  ehvapt_ehvbst_401             9050.0  -167.3644 -178.2244
# 76          10.8036  ehvbst_ehvapt_401             9003.0  -178.2344 -189.0380
# 78          10.8600  ehvapt_ehvbst_401             9050.0  -189.0480 -199.9080
#    startlocatie eindlocatie vertrektijd buslijn    vertrek_datetime  \
# 0        ehvbst      ehvapt       05:07     401 2024-08-29 05:07:00
# 1        ehvapt      ehvbst       06:04     401 2024-08-29 06:04:00
# 2        ehvbst      ehvapt       06:31     401 2024-08-29 06:31:00
# 3        ehvapt      ehvbst       06:56     401 2024-08-29 06:56:00
# 4        ehvbst      ehvapt       07:19     401 2024-08-29 07:19:00
# 5        ehvapt      ehvbst       07:46     401 2024-08-29 07:46:00
# 6        ehvbst      ehvapt       08:09     401 2024-08-29 08:09:00
# 7        ehvapt      ehvbst       08:34     400 2024-08-29 08:34:00
# 8        ehvbst      ehvapt       08:59     401 2024-08-29 08:59:00
# 9        ehvapt      ehvbst       09:26     401 2024-08-29 09:26:00
# 10       ehvbst      ehvapt       09:49     401 2024-08-29 09:49:00
# 11       ehvapt      ehvbst       10:16     401 2024-08-29 10:16:00
# 12       ehvbst      ehvapt       10:39     401 2024-08-29 10:39:00
# 13       ehvapt      ehvbst       11:04     400 2024-08-29 11:04:00
# 14       ehvbst      ehvapt       11:29     401 2024-08-29 11:29:00
# 15       ehvapt      ehvbst       11:56     401 2024-08-29 11:56:00
# 16       ehvbst   ehvgarage        None    None 2024-08-29 12:17:00
# 17    ehvgarage   ehvgarage        None    None 2024-08-29 12:21:00
# 18    ehvgarage      ehvbst        None    None 2024-08-29 13:06:00
# 19       ehvbst      ehvapt       13:19     401 2024-08-29 13:19:00
# 20       ehvapt      ehvbst       13:46     401 2024-08-29 13:46:00
# 21       ehvbst      ehvapt       14:09     401 2024-08-29 14:09:00
# 22       ehvapt      ehvbst       14:34     400 2024-08-29 14:34:00
# 23       ehvbst      ehvapt       14:59     401 2024-08-29 14:59:00
# 24       ehvapt      ehvbst       15:26     401 2024-08-29 15:26:00
# 25       ehvbst      ehvapt       15:49     401 2024-08-29 15:49:00
# 26       ehvapt      ehvbst       16:16     401 2024-08-29 16:16:00
# 27       ehvbst      ehvapt       16:39     401 2024-08-29 16:39:00
# 28       ehvapt      ehvbst       17:04     400 2024-08-29 17:04:00
# 29       ehvbst      ehvapt       17:29     401 2024-08-29 17:29:00
# 30       ehvapt      ehvbst       17:56     401 2024-08-29 17:56:00
# 31       ehvbst      ehvapt       18:22     400 2024-08-29 18:22:00
# 32       ehvapt      ehvbst       18:49     400 2024-08-29 18:49:00
# 33       ehvbst      ehvapt       19:14     401 2024-08-29 19:14:00
# 34       ehvapt      ehvbst       19:41     401 2024-08-29 19:41:00
# 35       ehvbst   ehvgarage        None    None 2024-08-29 20:02:00
# 36    ehvgarage   ehvgarage        None    None 2024-08-29 20:06:00
# 37    ehvgarage      ehvbst        None    None 2024-08-29 20:51:00
# 38       ehvbst      ehvapt       21:07     401 2024-08-29 21:07:00
# 39       ehvapt      ehvbst       21:35     401 2024-08-29 21:35:00
# 40       ehvbst      ehvapt       22:07     401 2024-08-29 22:07:00
# 41       ehvapt      ehvbst       22:35     401 2024-08-29 22:35:00
# 42       ehvbst      ehvapt       23:07     401 2024-08-29 23:07:00
# 43       ehvapt      ehvbst       23:35     401 2024-08-29 23:35:00
# 44       ehvbst      ehvapt       00:09     401 2024-08-30 00:09:00
# 45       ehvapt      ehvbst       00:31     401 2024-08-30 00:31:00
#
#      aankomst_datetime  Omloop        code_omloop    activiteit  \
# 0  2024-08-29 05:28:00       1  ehvbst_ehvapt_401     dienstrit
# 1  2024-08-29 06:25:00       1  ehvapt_ehvbst_401     dienstrit
# 2  2024-08-29 06:52:00       1  ehvbst_ehvapt_401     dienstrit
# 3  2024-08-29 07:17:00       1  ehvapt_ehvbst_401     dienstrit
# 4  2024-08-29 07:40:00       1  ehvbst_ehvapt_401     dienstrit
# 5  2024-08-29 08:07:00       1  ehvapt_ehvbst_401     dienstrit
# 6  2024-08-29 08:30:00       1  ehvbst_ehvapt_401     dienstrit
# 7  2024-08-29 08:55:00       1  ehvapt_ehvbst_400     dienstrit
# 8  2024-08-29 09:20:00       1  ehvbst_ehvapt_401     dienstrit
# 9  2024-08-29 09:47:00       1  ehvapt_ehvbst_401     dienstrit
# 10 2024-08-29 10:10:00       1  ehvbst_ehvapt_401     dienstrit
# 11 2024-08-29 10:37:00       1  ehvapt_ehvbst_401     dienstrit
# 12 2024-08-29 11:00:00       1  ehvbst_ehvapt_401     dienstrit
# 13 2024-08-29 11:25:00       1  ehvapt_ehvbst_400     dienstrit
# 14 2024-08-29 11:50:00       1  ehvbst_ehvapt_401     dienstrit
# 15 2024-08-29 12:17:00       1  ehvapt_ehvbst_401     dienstrit
# 16 2024-08-29 12:21:00       1               None  materiaalrit
# 17 2024-08-29 13:06:00       1               None       opladen
# 18 2024-08-29 13:10:00       1               None  materiaalrit
# 19 2024-08-29 13:40:00       1  ehvbst_ehvapt_401     dienstrit
# 20 2024-08-29 14:07:00       1  ehvapt_ehvbst_401     dienstrit
# 21 2024-08-29 14:30:00       1  ehvbst_ehvapt_401     dienstrit
# 22 2024-08-29 14:55:00       1  ehvapt_ehvbst_400     dienstrit
# 23 2024-08-29 15:20:00       1  ehvbst_ehvapt_401     dienstrit
# 24 2024-08-29 15:47:00       1  ehvapt_ehvbst_401     dienstrit
# 25 2024-08-29 16:10:00       1  ehvbst_ehvapt_401     dienstrit
# 26 2024-08-29 16:37:00       1  ehvapt_ehvbst_401     dienstrit
# 27 2024-08-29 17:00:00       1  ehvbst_ehvapt_401     dienstrit
# 28 2024-08-29 17:25:00       1  ehvapt_ehvbst_400     dienstrit
# 29 2024-08-29 17:50:00       1  ehvbst_ehvapt_401     dienstrit
# 30 2024-08-29 18:17:00       1  ehvapt_ehvbst_401     dienstrit
# 31 2024-08-29 18:43:00       1  ehvbst_ehvapt_400     dienstrit
# 32 2024-08-29 19:10:00       1  ehvapt_ehvbst_400     dienstrit
# 33 2024-08-29 19:35:00       1  ehvbst_ehvapt_401     dienstrit
# 34 2024-08-29 20:02:00       1  ehvapt_ehvbst_401     dienstrit
# 35 2024-08-29 20:06:00       1               None  materiaalrit
# 36 2024-08-29 20:51:00       1               None       opladen
# 37 2024-08-29 20:55:00       1               None  materiaalrit
# 38 2024-08-29 21:28:00       1  ehvbst_ehvapt_401     dienstrit
# 39 2024-08-29 21:56:00       1  ehvapt_ehvbst_401     dienstrit
# 40 2024-08-29 22:28:00       1  ehvbst_ehvapt_401     dienstrit
# 41 2024-08-29 22:56:00       1  ehvapt_ehvbst_401     dienstrit
# 42 2024-08-29 23:28:00       1  ehvbst_ehvapt_401     dienstrit
# 43 2024-08-29 23:56:00       1  ehvapt_ehvbst_401     dienstrit
# 44 2024-08-30 00:30:00       1  ehvbst_ehvapt_401     dienstrit
# 45 2024-08-30 00:52:00       1  ehvapt_ehvbst_401     dienstrit
#
#     afstand in km  Batterijgebruik       code_afstand  afstand in meters  \
# 0           9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 1           9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 2           9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 3           9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 4           9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 5           9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 6           9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 7          10.250          12.3000  ehvapt_ehvbst_400            10250.0
# 8           9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 9           9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 10          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 11          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 12          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 13         10.250          12.3000  ehvapt_ehvbst_400            10250.0
# 14          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 15          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 16            NaN           0.2000               None                NaN
# 17            NaN        -176.3888               None                NaN
# 18            NaN           0.2000               None                NaN
# 19          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 20          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 21          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 22         10.250          12.3000  ehvapt_ehvbst_400            10250.0
# 23          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 24          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 25          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 26          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 27          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 28         10.250          12.3000  ehvapt_ehvbst_400            10250.0
# 29          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 30          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 31         10.708          12.8496  ehvbst_ehvapt_400            10708.0
# 32         10.250          12.3000  ehvapt_ehvbst_400            10250.0
# 33          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 34          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 35            NaN           0.2000               None                NaN
# 36            NaN        -180.0748               None                NaN
# 37            NaN           0.2000               None                NaN
# 38          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 39          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 40          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 41          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 42          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 43          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 44          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 45          9.050          10.8600  ehvapt_ehvbst_401             9050.0
#
#     SOC_start  SOC_eind
# 0    243.0000  232.1964
# 1    232.1964  221.3364
# 2    221.3364  210.5328
# 3    210.5328  199.6728
# 4    199.6728  188.8692
# 5    188.8692  178.0092
# 6    178.0092  167.2056
# 7    167.2056  154.9056
# 8    154.9056  144.1020
# 9    144.1020  133.2420
# 10   133.2420  122.4384
# 11   122.4384  111.5784
# 12   111.5784  100.7748
# 13   100.7748   88.4748
# 14    88.4748   77.6712
# 15    77.6712   66.8112
# 16    66.8112   66.6112
# 17    66.6112  243.0000
# 18   243.0000  242.8000
# 19   242.8000  231.9964
# 20   231.9964  221.1364
# 21   221.1364  210.3328
# 22   210.3328  198.0328
# 23   198.0328  187.2292
# 24   187.2292  176.3692
# 25   176.3692  165.5656
# 26   165.5656  154.7056
# 27   154.7056  143.9020
# 28   143.9020  131.6020
# 29   131.6020  120.7984
# 30   120.7984  109.9384
# 31   109.9384   97.0888
# 32    97.0888   84.7888
# 33    84.7888   73.9852
# 34    73.9852   63.1252
# 35    63.1252   62.9252
# 36    62.9252  243.0000
# 37   243.0000  242.8000
# 38   242.8000  231.9964
# 39   231.9964  221.1364
# 40   221.1364  210.3328
# 41   210.3328  199.4728
# 42   199.4728  188.6692
# 43   188.6692  177.8092
# 44   177.8092  167.0056
# 45   167.0056  156.1456

# %%
import pandas as pd
from datetime import timedelta

# Constante variabelen
ENERGIE_VERBRUIK_PER_KM = 1.2  # kWh per gereden kilometer
OPLAADKRACHT_PER_UUR = 450  # kWh per uur tot 90%
MAX_BATT_CAPA = 300  # kWh
SOC_START = 0.9  # factor
SOC_MIN = 0.1  # factor
BATTERIJ_SLIJTAGE = 0.9  # Factor
SOH = MAX_BATT_CAPA * BATTERIJ_SLIJTAGE

def load_data():
    """Functie om data in te laden."""
    df_omloopplanning = pd.read_excel('omloopplanning.xlsx', engine='openpyxl')
    df_dienstregeling = pd.read_excel('Connexxion data - 2024-2025.xlsx', engine='openpyxl')
    df_afstandsmatrix = pd.read_excel('Connexxion data - 2024-2025.xlsx', engine='openpyxl', sheet_name='Afstandsmatrix')
    return df_omloopplanning, df_dienstregeling, df_afstandsmatrix

def create_parameters_df():
    """Functie om een parameters DataFrame te maken."""
    soc_ochtend = SOH * SOC_START
    soc_minimum = SOH * SOC_MIN
    data = {
        'Parameter': ['Max Batterij Capaciteit', 'SOC Start', 'SOC Minimum', 'Batterij Slijtage', 'SOH', 'SOC Ochtend', 'SOC Minimum', 'Batterijverbuik', 'Oplaadsnelheid'],
        'Waarde': [MAX_BATT_CAPA, SOC_START, SOC_MIN, BATTERIJ_SLIJTAGE, SOH, soc_ochtend, soc_minimum, ENERGIE_VERBRUIK_PER_KM, OPLAADKRACHT_PER_UUR],
        'Eenheid': ['kWh', 'Factor', 'Factor', 'Factor', 'kW (MBC * BS)', 'kW (SOH * SOC S)', 'kW (SOH * SOC M)', 'kWh/km', 'kWh/uur']
    }
    return pd.DataFrame(data)

def convert_to_datetime(time_str):
    """Functie om tijden naar datetime om te zetten."""
    if pd.isna(time_str):
        # Als de tijd ontbreekt, retourneer een NaT Timestamp
        return pd.NaT

    try:
        time_obj = pd.to_datetime(time_str, format='%H:%M').time()
    except TypeError:
        # Fallback als time_str geen geschikt formaat heeft
        return pd.NaT

    upper_boundary = pd.to_datetime('23:59', format='%H:%M').time()
    lower_boundary = pd.to_datetime('04:00', format='%H:%M').time()
    
    if lower_boundary <= time_obj <= upper_boundary:
        return pd.Timestamp('2024-08-29') + pd.Timedelta(hours=time_obj.hour, minutes=time_obj.minute)
    else:
        return pd.Timestamp('2024-08-30') + pd.Timedelta(hours=time_obj.hour, minutes=time_obj.minute)

def process_schedule_data(df_dienstregeling):
    """Functie om de nieuwe dienstregeling te verwerken."""
    df = df_dienstregeling.copy()
    
    # Vervang NaN door een standaardwaarde voordat je de conversie uitvoert
    df['buslijn'] = df['buslijn'].fillna(0).astype(int).astype(str)

    df['vertrek_datetime'] = df['vertrektijd'].apply(convert_to_datetime)
    df['Omloop'] = 0
    df_sorted = df.sort_values(by=['vertrek_datetime', 'buslijn'])
    df_sorted['code_omloop'] = df_sorted['startlocatie'].str.strip().str.lower() + '_' + \
                               df_sorted['eindlocatie'].str.strip().str.lower() + '_' + \
                               df_sorted['buslijn']
    return df_sorted

def process_distance_matrix(df_afstandsmatrix):
    """Functie om de afstandsmatrix te verwerken."""
    df = df_afstandsmatrix.copy()
    df['buslijn'] = df['buslijn'].fillna(0).astype(int).astype(str)
    df['code_afstand'] = df['startlocatie'].str.strip().str.lower() + '_' + \
                         df['eindlocatie'].str.strip().str.lower() + '_' + \
                         df['buslijn']
    return df

def setUpDataframes(df_nieuwe_dienstregelingv2, df_afstandsmatrix):
    """Kopieer en bereid dataframes voor gebruik voor de inplanting."""
    df = df_nieuwe_dienstregelingv2.copy()
    df['vertrek_datetime'] = pd.to_datetime(df['vertrek_datetime'])
    df['aankomst_datetime'] = pd.NaT
    df['Omloop'] = pd.NA
    return df

def vindt_reistijd(df_afstandsmatrix, startlocatie, eindlocatie):
    """Vind de reistijd tussen start- en eindlocatie."""
    rij = df_afstandsmatrix[
        (df_afstandsmatrix['startlocatie'] == startlocatie) &
        (df_afstandsmatrix['eindlocatie'] == eindlocatie)
    ]
    if not rij.empty:
        return int(rij['min reistijd in min'].values[0])
    return None

def inplannen_busritten(df_ritten, df_afstandsmatrix):
    """Functie om busritten in te plannen met een verplichte rusttijd na elke vijfde keer bij 'ehvbst'."""
    bus_nr = 1
    actuele_tijd = df_ritten.iloc[0]['vertrek_datetime'] - timedelta(minutes=4)  # Start bij de garage
    huidige_locatie = 'ehvgar'
    count_ehvbst = 0  # Tel hoe vaak de bus bij 'ehvbst' is aangekomen
    iteration_count = 0

    while True:
        iteration_count += 1
        print(f"Iteration {iteration_count}: Current time {actuele_tijd}, Current location {huidige_locatie}")

        mogelijk_ritten = df_ritten[
            (df_ritten['Omloop'].isna()) & 
            (df_ritten['vertrek_datetime'] >= actuele_tijd) & 
            (df_ritten['startlocatie'] == huidige_locatie)
        ]

        if not mogelijk_ritten.empty:
            row = mogelijk_ritten.iloc[0]  # Kies de eerst mogelijke rit
            print(f"Assigning ride at index {row.name} to bus {bus_nr}.")
            df_ritten.at[row.name, 'Omloop'] = bus_nr

            rit_duur = vindt_reistijd(df_afstandsmatrix, row['startlocatie'], row['eindlocatie'])
            if rit_duur is not None:
                aankomsttijd = row['vertrek_datetime'] + timedelta(minutes=rit_duur)
                df_ritten.at[row.name, 'aankomst_datetime'] = aankomsttijd
                print(f"Ride at index {row.name} arrives at: {aankomsttijd}")

                actuele_tijd = aankomsttijd
                huidige_locatie = row['eindlocatie']

                # Bijhouden hoe vaak 'ehvbst' bereikt is
                if huidige_locatie == 'ehvbst':
                    count_ehvbst += 1
                    print(f"Bus has now arrived at 'ehvbst' {count_ehvbst} times.")
                    
                    # Bij elke 8e keer een pauze van een uur incasseren
                    if count_ehvbst == 8:
                        print("Taking a break for 1 hour at 'ehvbst'.")
                        actuele_tijd += timedelta(hours=1)
                        count_ehvbst = 0  # Reset de teller
                
                print(f"Ride ends at {aankomsttijd}, new current location is {huidige_locatie}.")
            continue

        volgende_startlocaties = df_ritten[
            (df_ritten['Omloop'].isna()) &
            (df_ritten['vertrek_datetime'] > actuele_tijd)
        ]

        if volgende_startlocaties.empty:
            print("No more rides available, terminating loop.")
            break

        next_location_found = False
        for _, row in volgende_startlocaties.iterrows():
            reistijd = vindt_reistijd(df_afstandsmatrix, huidige_locatie, row['startlocatie'])
            if reistijd is not None and (actuele_tijd + timedelta(minutes=reistijd)) <= row['vertrek_datetime']:
                print(f"Moving to new start location {row['startlocatie']} with travel time {reistijd} minutes.")
                actuele_tijd += timedelta(minutes=reistijd)
                huidige_locatie = row['startlocatie']
                next_location_found = True
                break

        if not next_location_found:
            print("Unable to find a valid next location, terminating loop.")
            break

    return df_ritten

def filter_and_calculate(df_ritten, df_afstandsmatrix):
    """Filter de DataFrame en bereken afstand en batterijverbruik."""
    omloop_1_df = df_ritten[df_ritten['Omloop'] == 1].copy()

    # Voeg de 'afstand in meters' toe uit de afstandsmatrix
    omloop_1_df = omloop_1_df.merge(
        df_afstandsmatrix[['code_afstand', 'afstand in meters']],
        left_on='code_omloop',
        right_on='code_afstand',
        how='left'
    )

    # Kies de juiste kolom na de merge
    omloop_1_df['afstand in meters'] = omloop_1_df['afstand in meters_y'].fillna(0)

    # Verwijder onnodige suffixed kolommen
    kolommen_verwijderen = ['afstand in meters_x', 'afstand in meters_y', 'code_afstand_x', 'code_afstand_y']
    bestaande_kolommen = [kolom for kolom in kolommen_verwijderen if kolom in omloop_1_df.columns]
    omloop_1_df.drop(columns=bestaande_kolommen, inplace=True)

    # Bereken de afstand in kilometers
    omloop_1_df['afstand in km'] = omloop_1_df['afstand in meters'] / 1000

    # Bereken batterijgebruik voor actieve activiteit
    omloop_1_df['Batterijgebruik'] = omloop_1_df['afstand in km'] * ENERGIE_VERBRUIK_PER_KM

    # Stel batterijgebruik in op 0.01 als de activiteit 'idle' is
    omloop_1_df.loc[omloop_1_df['activiteit'] == 'idle', 'Batterijgebruik'] = 0.01

    return omloop_1_df

def add_activiteit_column(df):
    """Voegt een 'activiteit' kolom toe gebaseerd op de aanwezigheid van een omloopnummer."""
    df['activiteit'] = df['Omloop'].apply(lambda x: 'dienstrit' if pd.notna(x) else 'geen dienst')
    return df

def add_idle_activity(df):
    """Voegt 'idle' activiteiten toe waar nodig."""
    rows_to_add = []

    # Sorteer het DataFrame op basis van vertrektijd, zodat ritten op volgorde worden verwerkt.
    df = df.sort_values(by='vertrek_datetime').reset_index(drop=True)

    for i in range(1, len(df)):
        vorige_rit = df.iloc[i - 1]
        huidige_rit = df.iloc[i]

        # Controleer beide datetimes en zorg dat de times valid zijn voor het bepalen van idle tijd
        if pd.notna(vorige_rit['aankomst_datetime']) and vorige_rit['aankomst_datetime'] < huidige_rit['vertrek_datetime']:
            idle_start = vorige_rit['aankomst_datetime']
            # Idle activiteit eindigt bij de start van de volgende rit
            idle_end = huidige_rit['vertrek_datetime']

            # Voeg een rij toe voor de "idle" periode
            rows_to_add.append({
                'startlocatie': vorige_rit['eindlocatie'],
                'eindlocatie': vorige_rit['eindlocatie'],
                'vertrek_datetime': idle_start,
                'aankomst_datetime': idle_end,
                'buslijn': '',
                'Omloop': vorige_rit['Omloop'],
                'activiteit': 'idle',
                'afstand in meters': 0,
                'afstand in km': 0,
                'Batterijgebruik': 0.01,
                 'code_omloop': str(huidige_rit['startlocatie']) + '_' + \
                                str(huidige_rit['startlocatie']) + '_' + \
                                str('Idle')
            })
            # Debug print om te zien welke idle rij toegevoegd is
            print(f"Idle added from {idle_start} to {idle_end}.")

    # Voeg de 'idle' rijen toe aan de DataFrame als er rijen zijn
    if rows_to_add:
        idle_df = pd.DataFrame(rows_to_add)
        df = pd.concat([df, idle_df], ignore_index=True)

    # Herverdeel de DataFrame om ervoor te zorgen dat alles op volgorde staat
    df = df.sort_values(by='vertrek_datetime').reset_index(drop=True)
    return df

def calculate_soc(df, initial_soc=243):
    """Voegt SOC_start en SOC_eind kolommen toe aan de DataFrame."""
    # Sorteren is belangrijk om juiste volgorde te behouden
    df = df.sort_values(['Omloop', 'vertrek_datetime']).reset_index(drop=True)

    # Initialiseren van de SOC kolommen
    df['SOC_start'] = 0.0
    df['SOC_eind'] = 0.0
    
    for omloop in df['Omloop'].unique():
        omloop_data = df[df['Omloop'] == omloop]
        prev_soc_eind = initial_soc
        
        for index, row in omloop_data.iterrows():
            if index == omloop_data.index[0]:  # Eerste rit van Omloop
                soc_start = initial_soc
            else:
                soc_start = prev_soc_eind

            # Bereken de SOC_eind
            soc_eind = soc_start - row['Batterijgebruik']

            # Update DataFrame
            df.at[index, 'SOC_start'] = soc_start
            df.at[index, 'SOC_eind'] = soc_eind

            # Update previous SOC_eind for next iteration
            prev_soc_eind = soc_eind

    return df

def manage_battery_and_charging(df, target_soc=243, drive_time=timedelta(minutes=4), charge_duration=timedelta(minutes=45)):
    """Laad de bus op om een doel-SOC te bereiken als er genoeg tijd is tussen activiteiten."""
    df = df.sort_values(['Omloop', 'vertrek_datetime']).reset_index(drop=True)
    adjusted_rows = []
    prev_soc_eind = target_soc  # Start altijd met volle lading

    # Default structure for a row
    default_row = {
        'startlocatie': None,
        'eindlocatie': None,
        'vertrektijd': None,
        'buslijn': None,
        'vertrek_datetime': None,
        'aankomst_datetime': None,
        'Omloop': None,
        'code_omloop': None,
        'activiteit': None,
        'afstand in km': None,
        'Batterijgebruik': None,
        'code_afstand': None,
        'afstand in meters': None,
        'SOC_start': None,
        'SOC_eind': None,
    }

    for index, row in df.iterrows():
        soc_start = prev_soc_eind if index != 0 else target_soc
        soc_eind = soc_start - row['Batterijgebruik']

        # Check of er voldoende tijd is voor laden
        if index < len(df) - 1:
            next_vertrek = df.iloc[index + 1]['vertrek_datetime']
            idle_time = next_vertrek - row['aankomst_datetime']

            if idle_time >= (drive_time + charge_duration + drive_time):
                # Materiaal rit naar garage
                to_garage_end_time = row['aankomst_datetime'] + drive_time
                adjusted_rows.append({
                    **default_row,
                    **row.to_dict(),
                    'startlocatie': 'ehvbst',
                    'eindlocatie': 'ehvgarage',
                    'vertrek_datetime': row['aankomst_datetime'],
                    'aankomst_datetime': to_garage_end_time,
                    'activiteit': 'materiaalrit',
                    'Batterijgebruik': 0.2,
                    'SOC_start': soc_start,
                    'SOC_eind': soc_start - 0.2,
                })

                # Laad de bus op tot de gewenste SOC
                charge_time_start = to_garage_end_time
                charge_time_end = charge_time_start + charge_duration
                soc_charged = target_soc 

                adjusted_rows.append({
                    **default_row,
                    'startlocatie': 'ehvgarage',
                    'eindlocatie': 'ehvgarage',
                    'vertrek_datetime': charge_time_start,
                    'aankomst_datetime': charge_time_end,
                    'activiteit': 'opladen',
                    'Batterijgebruik': soc_start - 0.2 - soc_charged,  # Negatief om opladen aan te geven
                    'SOC_start': soc_start - 0.2,
                    'SOC_eind': soc_charged,
                    'Omloop': row['Omloop']
                })

                # Materiaal rit terug naar 'ehvbst'
                return_time = charge_time_end + drive_time
                adjusted_rows.append({
                    **default_row,
                    **row.to_dict(),
                    'startlocatie': 'ehvgarage',
                    'eindlocatie': 'ehvbst',
                    'vertrek_datetime': charge_time_end,
                    'aankomst_datetime': return_time,
                    'activiteit': 'materiaalrit',
                    'Batterijgebruik': 0.2,
                    'SOC_start': soc_charged,
                    'SOC_eind': soc_charged - 0.2,
                })

                prev_soc_eind = soc_charged - 0.2
                continue

        # Voeg de huidige regel toe zoals hij is
        adjusted_rows.append({
            **default_row,
            **row.to_dict(),
            'SOC_start': soc_start,
            'SOC_eind': soc_eind,
        })
        prev_soc_eind = soc_eind

    adjusted_df = pd.DataFrame(adjusted_rows)
    adjusted_df = adjusted_df.sort_values(by='vertrek_datetime').reset_index(drop=True)
    return adjusted_df

# Inladen van data
df_omloopplanning, df_dienstregeling, df_afstandsmatrix = load_data()

# Maak de parameters DataFrame en laat deze zien
df_parameters = create_parameters_df()
display(df_parameters)

# Verwerk dienstregeling en afstandsmatrix data
df_nieuwe_dienstregelingv2 = process_schedule_data(df_dienstregeling)
df_afstandsmatrix = process_distance_matrix(df_afstandsmatrix)

# Setting up the dataframes
df_nieuwe_dienstregelingv1 = setUpDataframes(df_nieuwe_dienstregelingv2, df_afstandsmatrix)

# Plan de busritten
df_processed_ritten = inplannen_busritten(df_nieuwe_dienstregelingv1, df_afstandsmatrix)

# Voer de functie uit na het verwerken van ritten
df_processed_ritten = add_activiteit_column(df_processed_ritten)

# Voeg de idle activiteiten in de verwerkte ritten toe
# Voer een test uit en controleer op output
df_with_idle = add_idle_activity(df_processed_ritten[df_processed_ritten['Omloop'] == 1])
# display(df_with_idle[df_with_idle['activiteit'] == 'idle'])
display(df_with_idle)
# Filter en bereken
omloop_df = filter_and_calculate(df_with_idle, df_afstandsmatrix)

# Toevoegen van SOC kolommen aan de DataFrame met ritten
df_with_soc = calculate_soc(omloop_df)

# Filter out rows with 'idle' activity and simulate battery charging and material trips
df_filtered = df_with_soc[df_with_soc['activiteit'] != 'idle']
df_adjusted = manage_battery_and_charging(df_filtered)

# Weergeven van het resultaat
display(df_adjusted)
# Out:
#                  Parameter  Waarde           Eenheid
# 0  Max Batterij Capaciteit   300.0               kWh
# 1                SOC Start     0.9            Factor
# 2              SOC Minimum     0.1            Factor
# 3        Batterij Slijtage     0.9            Factor
# 4                      SOH   270.0     kW (MBC * BS)
# 5              SOC Ochtend   243.0  kW (SOH * SOC S)
# 6              SOC Minimum    27.0  kW (SOH * SOC M)
# 7          Batterijverbuik     1.2            kWh/km
# 8           Oplaadsnelheid   450.0           kWh/uur
# Iteration 1: Current time 2024-08-29 05:03:00, Current location ehvgar
# Moving to new start location ehvbst with travel time 4 minutes.
# Iteration 2: Current time 2024-08-29 05:07:00, Current location ehvbst
# Assigning ride at index 163 to bus 1.
# Ride at index 163 arrives at: 2024-08-29 05:28:00
# Ride ends at 2024-08-29 05:28:00, new current location is ehvapt.
# Iteration 3: Current time 2024-08-29 05:28:00, Current location ehvapt
# Assigning ride at index 0 to bus 1.
# Ride at index 0 arrives at: 2024-08-29 06:25:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 06:25:00, new current location is ehvbst.
# Iteration 4: Current time 2024-08-29 06:25:00, Current location ehvbst
# Assigning ride at index 166 to bus 1.
# Ride at index 166 arrives at: 2024-08-29 06:52:00
# Ride ends at 2024-08-29 06:52:00, new current location is ehvapt.
# Iteration 5: Current time 2024-08-29 06:52:00, Current location ehvapt
# Assigning ride at index 2 to bus 1.
# Ride at index 2 arrives at: 2024-08-29 07:17:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 07:17:00, new current location is ehvbst.
# Iteration 6: Current time 2024-08-29 07:17:00, Current location ehvbst
# Assigning ride at index 170 to bus 1.
# Ride at index 170 arrives at: 2024-08-29 07:40:00
# Ride ends at 2024-08-29 07:40:00, new current location is ehvapt.
# Iteration 7: Current time 2024-08-29 07:40:00, Current location ehvapt
# Assigning ride at index 6 to bus 1.
# Ride at index 6 arrives at: 2024-08-29 08:07:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 08:07:00, new current location is ehvbst.
# Iteration 8: Current time 2024-08-29 08:07:00, Current location ehvbst
# Assigning ride at index 175 to bus 1.
# Ride at index 175 arrives at: 2024-08-29 08:30:00
# Ride ends at 2024-08-29 08:30:00, new current location is ehvapt.
# Iteration 9: Current time 2024-08-29 08:30:00, Current location ehvapt
# Assigning ride at index 93 to bus 1.
# Ride at index 93 arrives at: 2024-08-29 08:55:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 08:55:00, new current location is ehvbst.
# Iteration 10: Current time 2024-08-29 08:55:00, Current location ehvbst
# Assigning ride at index 180 to bus 1.
# Ride at index 180 arrives at: 2024-08-29 09:20:00
# Ride ends at 2024-08-29 09:20:00, new current location is ehvapt.
# Iteration 11: Current time 2024-08-29 09:20:00, Current location ehvapt
# Assigning ride at index 16 to bus 1.
# Ride at index 16 arrives at: 2024-08-29 09:47:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2024-08-29 09:47:00, new current location is ehvbst.
# Iteration 12: Current time 2024-08-29 09:47:00, Current location ehvbst
# Assigning ride at index 185 to bus 1.
# Ride at index 185 arrives at: 2024-08-29 10:10:00
# Ride ends at 2024-08-29 10:10:00, new current location is ehvapt.
# Iteration 13: Current time 2024-08-29 10:10:00, Current location ehvapt
# Assigning ride at index 21 to bus 1.
# Ride at index 21 arrives at: 2024-08-29 10:37:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2024-08-29 10:37:00, new current location is ehvbst.
# Iteration 14: Current time 2024-08-29 10:37:00, Current location ehvbst
# Assigning ride at index 190 to bus 1.
# Ride at index 190 arrives at: 2024-08-29 11:00:00
# Ride ends at 2024-08-29 11:00:00, new current location is ehvapt.
# Iteration 15: Current time 2024-08-29 11:00:00, Current location ehvapt
# Assigning ride at index 108 to bus 1.
# Ride at index 108 arrives at: 2024-08-29 11:25:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2024-08-29 11:25:00, new current location is ehvbst.
# Iteration 16: Current time 2024-08-29 11:25:00, Current location ehvbst
# Assigning ride at index 195 to bus 1.
# Ride at index 195 arrives at: 2024-08-29 11:50:00
# Ride ends at 2024-08-29 11:50:00, new current location is ehvapt.
# Iteration 17: Current time 2024-08-29 11:50:00, Current location ehvapt
# Assigning ride at index 31 to bus 1.
# Ride at index 31 arrives at: 2024-08-29 12:17:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 12:17:00, new current location is ehvbst.
# Iteration 18: Current time 2024-08-29 13:17:00, Current location ehvbst
# Assigning ride at index 206 to bus 1.
# Ride at index 206 arrives at: 2024-08-29 13:40:00
# Ride ends at 2024-08-29 13:40:00, new current location is ehvapt.
# Iteration 19: Current time 2024-08-29 13:40:00, Current location ehvapt
# Assigning ride at index 42 to bus 1.
# Ride at index 42 arrives at: 2024-08-29 14:07:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 14:07:00, new current location is ehvbst.
# Iteration 20: Current time 2024-08-29 14:07:00, Current location ehvbst
# Assigning ride at index 211 to bus 1.
# Ride at index 211 arrives at: 2024-08-29 14:30:00
# Ride ends at 2024-08-29 14:30:00, new current location is ehvapt.
# Iteration 21: Current time 2024-08-29 14:30:00, Current location ehvapt
# Assigning ride at index 129 to bus 1.
# Ride at index 129 arrives at: 2024-08-29 14:55:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 14:55:00, new current location is ehvbst.
# Iteration 22: Current time 2024-08-29 14:55:00, Current location ehvbst
# Assigning ride at index 216 to bus 1.
# Ride at index 216 arrives at: 2024-08-29 15:20:00
# Ride ends at 2024-08-29 15:20:00, new current location is ehvapt.
# Iteration 23: Current time 2024-08-29 15:20:00, Current location ehvapt
# Assigning ride at index 52 to bus 1.
# Ride at index 52 arrives at: 2024-08-29 15:47:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 15:47:00, new current location is ehvbst.
# Iteration 24: Current time 2024-08-29 15:47:00, Current location ehvbst
# Assigning ride at index 221 to bus 1.
# Ride at index 221 arrives at: 2024-08-29 16:10:00
# Ride ends at 2024-08-29 16:10:00, new current location is ehvapt.
# Iteration 25: Current time 2024-08-29 16:10:00, Current location ehvapt
# Assigning ride at index 57 to bus 1.
# Ride at index 57 arrives at: 2024-08-29 16:37:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 16:37:00, new current location is ehvbst.
# Iteration 26: Current time 2024-08-29 16:37:00, Current location ehvbst
# Assigning ride at index 226 to bus 1.
# Ride at index 226 arrives at: 2024-08-29 17:00:00
# Ride ends at 2024-08-29 17:00:00, new current location is ehvapt.
# Iteration 27: Current time 2024-08-29 17:00:00, Current location ehvapt
# Assigning ride at index 144 to bus 1.
# Ride at index 144 arrives at: 2024-08-29 17:25:00
# Bus has now arrived at 'ehvbst' 5 times.
# Ride ends at 2024-08-29 17:25:00, new current location is ehvbst.
# Iteration 28: Current time 2024-08-29 17:25:00, Current location ehvbst
# Assigning ride at index 231 to bus 1.
# Ride at index 231 arrives at: 2024-08-29 17:50:00
# Ride ends at 2024-08-29 17:50:00, new current location is ehvapt.
# Iteration 29: Current time 2024-08-29 17:50:00, Current location ehvapt
# Assigning ride at index 67 to bus 1.
# Ride at index 67 arrives at: 2024-08-29 18:17:00
# Bus has now arrived at 'ehvbst' 6 times.
# Ride ends at 2024-08-29 18:17:00, new current location is ehvbst.
# Iteration 30: Current time 2024-08-29 18:17:00, Current location ehvbst
# Assigning ride at index 319 to bus 1.
# Ride at index 319 arrives at: 2024-08-29 18:43:00
# Ride ends at 2024-08-29 18:43:00, new current location is ehvapt.
# Iteration 31: Current time 2024-08-29 18:43:00, Current location ehvapt
# Assigning ride at index 154 to bus 1.
# Ride at index 154 arrives at: 2024-08-29 19:10:00
# Bus has now arrived at 'ehvbst' 7 times.
# Ride ends at 2024-08-29 19:10:00, new current location is ehvbst.
# Iteration 32: Current time 2024-08-29 19:10:00, Current location ehvbst
# Assigning ride at index 239 to bus 1.
# Ride at index 239 arrives at: 2024-08-29 19:35:00
# Ride ends at 2024-08-29 19:35:00, new current location is ehvapt.
# Iteration 33: Current time 2024-08-29 19:35:00, Current location ehvapt
# Assigning ride at index 75 to bus 1.
# Ride at index 75 arrives at: 2024-08-29 20:02:00
# Bus has now arrived at 'ehvbst' 8 times.
# Taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 20:02:00, new current location is ehvbst.
# Iteration 34: Current time 2024-08-29 21:02:00, Current location ehvbst
# Assigning ride at index 245 to bus 1.
# Ride at index 245 arrives at: 2024-08-29 21:28:00
# Ride ends at 2024-08-29 21:28:00, new current location is ehvapt.
# Iteration 35: Current time 2024-08-29 21:28:00, Current location ehvapt
# Assigning ride at index 80 to bus 1.
# Ride at index 80 arrives at: 2024-08-29 21:56:00
# Bus has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 21:56:00, new current location is ehvbst.
# Iteration 36: Current time 2024-08-29 21:56:00, Current location ehvbst
# Assigning ride at index 247 to bus 1.
# Ride at index 247 arrives at: 2024-08-29 22:28:00
# Ride ends at 2024-08-29 22:28:00, new current location is ehvapt.
# Iteration 37: Current time 2024-08-29 22:28:00, Current location ehvapt
# Assigning ride at index 82 to bus 1.
# Ride at index 82 arrives at: 2024-08-29 22:56:00
# Bus has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 22:56:00, new current location is ehvbst.
# Iteration 38: Current time 2024-08-29 22:56:00, Current location ehvbst
# Assigning ride at index 249 to bus 1.
# Ride at index 249 arrives at: 2024-08-29 23:28:00
# Ride ends at 2024-08-29 23:28:00, new current location is ehvapt.
# Iteration 39: Current time 2024-08-29 23:28:00, Current location ehvapt
# Assigning ride at index 84 to bus 1.
# Ride at index 84 arrives at: 2024-08-29 23:56:00
# Bus has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 23:56:00, new current location is ehvbst.
# Iteration 40: Current time 2024-08-29 23:56:00, Current location ehvbst
# Assigning ride at index 251 to bus 1.
# Ride at index 251 arrives at: 2024-08-30 00:30:00
# Ride ends at 2024-08-30 00:30:00, new current location is ehvapt.
# Iteration 41: Current time 2024-08-30 00:30:00, Current location ehvapt
# Assigning ride at index 86 to bus 1.
# Ride at index 86 arrives at: 2024-08-30 00:52:00
# Bus has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-30 00:52:00, new current location is ehvbst.
# Iteration 42: Current time 2024-08-30 00:52:00, Current location ehvbst
# No more rides available, terminating loop.
# Idle added from 2024-08-29 05:28:00 to 2024-08-29 06:04:00.
# Idle added from 2024-08-29 06:25:00 to 2024-08-29 06:31:00.
# Idle added from 2024-08-29 06:52:00 to 2024-08-29 06:56:00.
# Idle added from 2024-08-29 07:17:00 to 2024-08-29 07:19:00.
# Idle added from 2024-08-29 07:40:00 to 2024-08-29 07:46:00.
# Idle added from 2024-08-29 08:07:00 to 2024-08-29 08:09:00.
# Idle added from 2024-08-29 08:30:00 to 2024-08-29 08:34:00.
# Idle added from 2024-08-29 08:55:00 to 2024-08-29 08:59:00.
# Idle added from 2024-08-29 09:20:00 to 2024-08-29 09:26:00.
# Idle added from 2024-08-29 09:47:00 to 2024-08-29 09:49:00.
# Idle added from 2024-08-29 10:10:00 to 2024-08-29 10:16:00.
# Idle added from 2024-08-29 10:37:00 to 2024-08-29 10:39:00.
# Idle added from 2024-08-29 11:00:00 to 2024-08-29 11:04:00.
# Idle added from 2024-08-29 11:25:00 to 2024-08-29 11:29:00.
# Idle added from 2024-08-29 11:50:00 to 2024-08-29 11:56:00.
# Idle added from 2024-08-29 12:17:00 to 2024-08-29 13:19:00.
# Idle added from 2024-08-29 13:40:00 to 2024-08-29 13:46:00.
# Idle added from 2024-08-29 14:07:00 to 2024-08-29 14:09:00.
# Idle added from 2024-08-29 14:30:00 to 2024-08-29 14:34:00.
# Idle added from 2024-08-29 14:55:00 to 2024-08-29 14:59:00.
# Idle added from 2024-08-29 15:20:00 to 2024-08-29 15:26:00.
# Idle added from 2024-08-29 15:47:00 to 2024-08-29 15:49:00.
# Idle added from 2024-08-29 16:10:00 to 2024-08-29 16:16:00.
# Idle added from 2024-08-29 16:37:00 to 2024-08-29 16:39:00.
# Idle added from 2024-08-29 17:00:00 to 2024-08-29 17:04:00.
# Idle added from 2024-08-29 17:25:00 to 2024-08-29 17:29:00.
# Idle added from 2024-08-29 17:50:00 to 2024-08-29 17:56:00.
# Idle added from 2024-08-29 18:17:00 to 2024-08-29 18:22:00.
# Idle added from 2024-08-29 18:43:00 to 2024-08-29 18:49:00.
# Idle added from 2024-08-29 19:10:00 to 2024-08-29 19:14:00.
# Idle added from 2024-08-29 19:35:00 to 2024-08-29 19:41:00.
# Idle added from 2024-08-29 20:02:00 to 2024-08-29 21:07:00.
# Idle added from 2024-08-29 21:28:00 to 2024-08-29 21:35:00.
# Idle added from 2024-08-29 21:56:00 to 2024-08-29 22:07:00.
# Idle added from 2024-08-29 22:28:00 to 2024-08-29 22:35:00.
# Idle added from 2024-08-29 22:56:00 to 2024-08-29 23:07:00.
# Idle added from 2024-08-29 23:28:00 to 2024-08-29 23:35:00.
# Idle added from 2024-08-29 23:56:00 to 2024-08-30 00:09:00.
# Idle added from 2024-08-30 00:30:00 to 2024-08-30 00:31:00.
#    startlocatie vertrektijd eindlocatie buslijn    vertrek_datetime Omloop  \
# 0        ehvbst       05:07      ehvapt     401 2024-08-29 05:07:00      1
# 1        ehvapt         NaN      ehvapt         2024-08-29 05:28:00      1
# 2        ehvapt       06:04      ehvbst     401 2024-08-29 06:04:00      1
# 3        ehvbst         NaN      ehvbst         2024-08-29 06:25:00      1
# 4        ehvbst       06:31      ehvapt     401 2024-08-29 06:31:00      1
# ..          ...         ...         ...     ...                 ...    ...
# 74       ehvapt       23:35      ehvbst     401 2024-08-29 23:35:00      1
# 75       ehvbst         NaN      ehvbst         2024-08-29 23:56:00      1
# 76       ehvbst       00:09      ehvapt     401 2024-08-30 00:09:00      1
# 77       ehvapt         NaN      ehvapt         2024-08-30 00:30:00      1
# 78       ehvapt       00:31      ehvbst     401 2024-08-30 00:31:00      1
#
#            code_omloop   aankomst_datetime activiteit  afstand in meters  \
# 0    ehvbst_ehvapt_401 2024-08-29 05:28:00  dienstrit                NaN
# 1   ehvapt_ehvapt_Idle 2024-08-29 06:04:00       idle                0.0
# 2    ehvapt_ehvbst_401 2024-08-29 06:25:00  dienstrit                NaN
# 3   ehvbst_ehvbst_Idle 2024-08-29 06:31:00       idle                0.0
# 4    ehvbst_ehvapt_401 2024-08-29 06:52:00  dienstrit                NaN
# ..                 ...                 ...        ...                ...
# 74   ehvapt_ehvbst_401 2024-08-29 23:56:00  dienstrit                NaN
# 75  ehvbst_ehvbst_Idle 2024-08-30 00:09:00       idle                0.0
# 76   ehvbst_ehvapt_401 2024-08-30 00:30:00  dienstrit                NaN
# 77  ehvapt_ehvapt_Idle 2024-08-30 00:31:00       idle                0.0
# 78   ehvapt_ehvbst_401 2024-08-30 00:52:00  dienstrit                NaN
#
#     afstand in km  Batterijgebruik
# 0             NaN              NaN
# 1             0.0             0.01
# 2             NaN              NaN
# 3             0.0             0.01
# 4             NaN              NaN
# ..            ...              ...
# 74            NaN              NaN
# 75            0.0             0.01
# 76            NaN              NaN
# 77            0.0             0.01
# 78            NaN              NaN
#
# [79 rows x 12 columns]
#    startlocatie eindlocatie vertrektijd buslijn    vertrek_datetime  \
# 0        ehvbst      ehvapt       05:07     401 2024-08-29 05:07:00
# 1        ehvapt      ehvbst       06:04     401 2024-08-29 06:04:00
# 2        ehvbst      ehvapt       06:31     401 2024-08-29 06:31:00
# 3        ehvapt      ehvbst       06:56     401 2024-08-29 06:56:00
# 4        ehvbst      ehvapt       07:19     401 2024-08-29 07:19:00
# 5        ehvapt      ehvbst       07:46     401 2024-08-29 07:46:00
# 6        ehvbst      ehvapt       08:09     401 2024-08-29 08:09:00
# 7        ehvapt      ehvbst       08:34     400 2024-08-29 08:34:00
# 8        ehvbst      ehvapt       08:59     401 2024-08-29 08:59:00
# 9        ehvapt      ehvbst       09:26     401 2024-08-29 09:26:00
# 10       ehvbst      ehvapt       09:49     401 2024-08-29 09:49:00
# 11       ehvapt      ehvbst       10:16     401 2024-08-29 10:16:00
# 12       ehvbst      ehvapt       10:39     401 2024-08-29 10:39:00
# 13       ehvapt      ehvbst       11:04     400 2024-08-29 11:04:00
# 14       ehvbst      ehvapt       11:29     401 2024-08-29 11:29:00
# 15       ehvbst   ehvgarage       11:56     401 2024-08-29 12:17:00
# 16    ehvgarage   ehvgarage        None    None 2024-08-29 12:21:00
# 17    ehvgarage      ehvbst       11:56     401 2024-08-29 13:06:00
# 18       ehvbst      ehvapt       13:19     401 2024-08-29 13:19:00
# 19       ehvapt      ehvbst       13:46     401 2024-08-29 13:46:00
# 20       ehvbst      ehvapt       14:09     401 2024-08-29 14:09:00
# 21       ehvapt      ehvbst       14:34     400 2024-08-29 14:34:00
# 22       ehvbst      ehvapt       14:59     401 2024-08-29 14:59:00
# 23       ehvapt      ehvbst       15:26     401 2024-08-29 15:26:00
# 24       ehvbst      ehvapt       15:49     401 2024-08-29 15:49:00
# 25       ehvapt      ehvbst       16:16     401 2024-08-29 16:16:00
# 26       ehvbst      ehvapt       16:39     401 2024-08-29 16:39:00
# 27       ehvapt      ehvbst       17:04     400 2024-08-29 17:04:00
# 28       ehvbst      ehvapt       17:29     401 2024-08-29 17:29:00
# 29       ehvapt      ehvbst       17:56     401 2024-08-29 17:56:00
# 30       ehvbst      ehvapt       18:22     400 2024-08-29 18:22:00
# 31       ehvapt      ehvbst       18:49     400 2024-08-29 18:49:00
# 32       ehvbst      ehvapt       19:14     401 2024-08-29 19:14:00
# 33       ehvbst   ehvgarage       19:41     401 2024-08-29 20:02:00
# 34    ehvgarage   ehvgarage        None    None 2024-08-29 20:06:00
# 35    ehvgarage      ehvbst       19:41     401 2024-08-29 20:51:00
# 36       ehvbst      ehvapt       21:07     401 2024-08-29 21:07:00
# 37       ehvapt      ehvbst       21:35     401 2024-08-29 21:35:00
# 38       ehvbst      ehvapt       22:07     401 2024-08-29 22:07:00
# 39       ehvapt      ehvbst       22:35     401 2024-08-29 22:35:00
# 40       ehvbst      ehvapt       23:07     401 2024-08-29 23:07:00
# 41       ehvapt      ehvbst       23:35     401 2024-08-29 23:35:00
# 42       ehvbst      ehvapt       00:09     401 2024-08-30 00:09:00
# 43       ehvapt      ehvbst       00:31     401 2024-08-30 00:31:00
#
#      aankomst_datetime  Omloop        code_omloop    activiteit  \
# 0  2024-08-29 05:28:00       1  ehvbst_ehvapt_401     dienstrit
# 1  2024-08-29 06:25:00       1  ehvapt_ehvbst_401     dienstrit
# 2  2024-08-29 06:52:00       1  ehvbst_ehvapt_401     dienstrit
# 3  2024-08-29 07:17:00       1  ehvapt_ehvbst_401     dienstrit
# 4  2024-08-29 07:40:00       1  ehvbst_ehvapt_401     dienstrit
# 5  2024-08-29 08:07:00       1  ehvapt_ehvbst_401     dienstrit
# 6  2024-08-29 08:30:00       1  ehvbst_ehvapt_401     dienstrit
# 7  2024-08-29 08:55:00       1  ehvapt_ehvbst_400     dienstrit
# 8  2024-08-29 09:20:00       1  ehvbst_ehvapt_401     dienstrit
# 9  2024-08-29 09:47:00       1  ehvapt_ehvbst_401     dienstrit
# 10 2024-08-29 10:10:00       1  ehvbst_ehvapt_401     dienstrit
# 11 2024-08-29 10:37:00       1  ehvapt_ehvbst_401     dienstrit
# 12 2024-08-29 11:00:00       1  ehvbst_ehvapt_401     dienstrit
# 13 2024-08-29 11:25:00       1  ehvapt_ehvbst_400     dienstrit
# 14 2024-08-29 11:50:00       1  ehvbst_ehvapt_401     dienstrit
# 15 2024-08-29 12:21:00       1  ehvapt_ehvbst_401  materiaalrit
# 16 2024-08-29 13:06:00       1               None       opladen
# 17 2024-08-29 13:10:00       1  ehvapt_ehvbst_401  materiaalrit
# 18 2024-08-29 13:40:00       1  ehvbst_ehvapt_401     dienstrit
# 19 2024-08-29 14:07:00       1  ehvapt_ehvbst_401     dienstrit
# 20 2024-08-29 14:30:00       1  ehvbst_ehvapt_401     dienstrit
# 21 2024-08-29 14:55:00       1  ehvapt_ehvbst_400     dienstrit
# 22 2024-08-29 15:20:00       1  ehvbst_ehvapt_401     dienstrit
# 23 2024-08-29 15:47:00       1  ehvapt_ehvbst_401     dienstrit
# 24 2024-08-29 16:10:00       1  ehvbst_ehvapt_401     dienstrit
# 25 2024-08-29 16:37:00       1  ehvapt_ehvbst_401     dienstrit
# 26 2024-08-29 17:00:00       1  ehvbst_ehvapt_401     dienstrit
# 27 2024-08-29 17:25:00       1  ehvapt_ehvbst_400     dienstrit
# 28 2024-08-29 17:50:00       1  ehvbst_ehvapt_401     dienstrit
# 29 2024-08-29 18:17:00       1  ehvapt_ehvbst_401     dienstrit
# 30 2024-08-29 18:43:00       1  ehvbst_ehvapt_400     dienstrit
# 31 2024-08-29 19:10:00       1  ehvapt_ehvbst_400     dienstrit
# 32 2024-08-29 19:35:00       1  ehvbst_ehvapt_401     dienstrit
# 33 2024-08-29 20:06:00       1  ehvapt_ehvbst_401  materiaalrit
# 34 2024-08-29 20:51:00       1               None       opladen
# 35 2024-08-29 20:55:00       1  ehvapt_ehvbst_401  materiaalrit
# 36 2024-08-29 21:28:00       1  ehvbst_ehvapt_401     dienstrit
# 37 2024-08-29 21:56:00       1  ehvapt_ehvbst_401     dienstrit
# 38 2024-08-29 22:28:00       1  ehvbst_ehvapt_401     dienstrit
# 39 2024-08-29 22:56:00       1  ehvapt_ehvbst_401     dienstrit
# 40 2024-08-29 23:28:00       1  ehvbst_ehvapt_401     dienstrit
# 41 2024-08-29 23:56:00       1  ehvapt_ehvbst_401     dienstrit
# 42 2024-08-30 00:30:00       1  ehvbst_ehvapt_401     dienstrit
# 43 2024-08-30 00:52:00       1  ehvapt_ehvbst_401     dienstrit
#
#     afstand in km  Batterijgebruik       code_afstand  afstand in meters  \
# 0           9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 1           9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 2           9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 3           9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 4           9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 5           9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 6           9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 7          10.250          12.3000  ehvapt_ehvbst_400            10250.0
# 8           9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 9           9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 10          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 11          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 12          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 13         10.250          12.3000  ehvapt_ehvbst_400            10250.0
# 14          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 15          9.050           0.2000  ehvapt_ehvbst_401             9050.0
# 16            NaN        -165.5288               None                NaN
# 17          9.050           0.2000  ehvapt_ehvbst_401             9050.0
# 18          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 19          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 20          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 21         10.250          12.3000  ehvapt_ehvbst_400            10250.0
# 22          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 23          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 24          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 25          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 26          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 27         10.250          12.3000  ehvapt_ehvbst_400            10250.0
# 28          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 29          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 30         10.708          12.8496  ehvbst_ehvapt_400            10708.0
# 31         10.250          12.3000  ehvapt_ehvbst_400            10250.0
# 32          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 33          9.050           0.2000  ehvapt_ehvbst_401             9050.0
# 34            NaN        -169.2148               None                NaN
# 35          9.050           0.2000  ehvapt_ehvbst_401             9050.0
# 36          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 37          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 38          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 39          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 40          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 41          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 42          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 43          9.050          10.8600  ehvapt_ehvbst_401             9050.0
#
#     SOC_start  SOC_eind
# 0    243.0000  232.1964
# 1    232.1964  221.3364
# 2    221.3364  210.5328
# 3    210.5328  199.6728
# 4    199.6728  188.8692
# 5    188.8692  178.0092
# 6    178.0092  167.2056
# 7    167.2056  154.9056
# 8    154.9056  144.1020
# 9    144.1020  133.2420
# 10   133.2420  122.4384
# 11   122.4384  111.5784
# 12   111.5784  100.7748
# 13   100.7748   88.4748
# 14    88.4748   77.6712
# 15    77.6712   77.4712
# 16    77.4712  243.0000
# 17   243.0000  242.8000
# 18   242.8000  231.9964
# 19   231.9964  221.1364
# 20   221.1364  210.3328
# 21   210.3328  198.0328
# 22   198.0328  187.2292
# 23   187.2292  176.3692
# 24   176.3692  165.5656
# 25   165.5656  154.7056
# 26   154.7056  143.9020
# 27   143.9020  131.6020
# 28   131.6020  120.7984
# 29   120.7984  109.9384
# 30   109.9384   97.0888
# 31    97.0888   84.7888
# 32    84.7888   73.9852
# 33    73.9852   73.7852
# 34    73.7852  243.0000
# 35   243.0000  242.8000
# 36   242.8000  231.9964
# 37   231.9964  221.1364
# 38   221.1364  210.3328
# 39   210.3328  199.4728
# 40   199.4728  188.6692
# 41   188.6692  177.8092
# 42   177.8092  167.0056
# 43   167.0056  156.1456

# %% [markdown]
# ## Meerdere omloopnummers

# %% [markdown]
# ## Voorbereiden op controle

# %%
df_adjusted = df_adjusted.rename(columns={'vertrek_datetime': 'starttijd'})
df_adjusted = df_adjusted.rename(columns={'aankomst_datetime': 'eindtijd'})
df_adjusted = df_adjusted.rename(columns={'Batterijgebruik': 'energieverbruik'})
df_adjusted = df_adjusted.rename(columns={'Omloop': 'omloop nummer'})
df_adjusted['starttijd datum'] = df_adjusted['starttijd']
df_adjusted['eindtijd datum'] = df_adjusted['eindtijd']

df_adjusted_controle = df_adjusted[['startlocatie','eindlocatie','starttijd','eindtijd','activiteit','buslijn','energieverbruik','starttijd datum','eindtijd datum','omloop nummer']]

# %%
# Sorteer de DataFrame op 'vertrektijd'
df_dienstregeling_sorted = df_dienstregeling.sort_values(by='vertrektijd')

from datetime import datetime
df_dienstregeling_sorted['vertrektijd'] = df_dienstregeling_sorted['vertrektijd'].apply(
    lambda x: datetime.strptime(x, '%H:%M').time() if isinstance(x, str) else pd.NaT
)

# %% [markdown]
# ## Controle

# %%
import pandas as pd

# Zorg ervoor dat jouw dataframes zijn ingeladen
df_omloopplanning = df_adjusted_controle.copy()
df_dienstregeling = df_dienstregeling_sorted.copy()

# Controleer en converteer naar tijdformaat indien nodig
def ensure_time_format(column):
    # Alleen converteren als het van het type 'object' is
    if column.dtype == 'object':
        try:
            return pd.to_datetime(column).dt.time
        except Exception as e:
            print("Error converting column:", e)
            return column
    else:
        # Neem aan dat het al een timestamp is of van het juiste type
        try:
            return column.dt.time
        except AttributeError:
            # Als het al een datetime.time is, doe er niets mee
            return column

df_omloopplanning['starttijd'] = ensure_time_format(df_omloopplanning['starttijd'])
df_dienstregeling['vertrektijd'] = ensure_time_format(df_dienstregeling['vertrektijd'])

# Functie om rijen te vergelijken
def check_match(row):
    matches = df_dienstregeling[
        (df_dienstregeling['startlocatie'] == row['startlocatie']) &
        (df_dienstregeling['eindlocatie'] == row['eindlocatie']) &
        (df_dienstregeling['vertrektijd'] == row['starttijd'])
    ]
    return not matches.empty

# Nieuwe kolom creëren met True/False
df_omloopplanning['match'] = df_omloopplanning.apply(check_match, axis=1)

# display(df_omloopplanning)
# Out:
# Error converting column: <class 'datetime.time'> is not convertible to datetime, at position 0

# %%
# Tel aantal rijen waarbij activiteit == dienstrit en tel aantal rijen waarbij match == True in df_omloopplanning. Als dat verschil 0 is dan klopt het

dienstrit_count = df_omloopplanning[df_omloopplanning['activiteit'] == 'dienstrit'].shape[0]
match_true_count = df_omloopplanning[df_omloopplanning['match'] == True].shape[0]

if dienstrit_count == match_true_count:
  print("Het klopt: Aantal rijen met activiteit 'dienstrit' is gelijk aan aantal rijen met match 'True'")
else:
  print("Het klopt niet: Aantal rijen met activiteit 'dienstrit' is niet gelijk aan aantal rijen met match 'True'")
  print(f"Aantal dienstrit: {dienstrit_count}")
  print(f"Aantal match True: {match_true_count}")
# Out:
# Het klopt: Aantal rijen met activiteit 'dienstrit' is gelijk aan aantal rijen met match 'True'
