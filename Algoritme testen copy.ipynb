# %%
import pandas as pd
from datetime import timedelta

# Constante variabelen
ENERGIE_VERBRUIK_PER_KM = 1.2  # kWh per gereden kilometer
OPLAADKRACHT_PER_UUR = 450  # kWh per uur tot 90%
MAX_BATT_CAPA = 300  # kWh
SOC_START = 0.9  # factor
SOC_MIN = 0.1  # factor
BATTERIJ_SLIJTAGE = 0.9  # Factor
SOH = MAX_BATT_CAPA * BATTERIJ_SLIJTAGE

def load_data():
    """Functie om data in te laden."""
    df_omloopplanning = pd.read_excel('omloopplanning.xlsx', engine='openpyxl')
    df_dienstregeling = pd.read_excel('Connexxion data - 2024-2025.2.xlsx', engine='openpyxl')
    df_afstandsmatrix = pd.read_excel('Connexxion data - 2024-2025.2.xlsx', engine='openpyxl', sheet_name='Afstandsmatrix')
    return df_omloopplanning, df_dienstregeling, df_afstandsmatrix

def create_parameters_df():
    """Functie om een parameters DataFrame te maken."""
    soc_ochtend = SOH * SOC_START
    soc_minimum = SOH * SOC_MIN
    data = {
        'Parameter': ['Max Batterij Capaciteit', 'SOC Start', 'SOC Minimum', 'Batterij Slijtage', 'SOH', 'SOC Ochtend', 'SOC Minimum', 'Batterijverbuik', 'Oplaadsnelheid'],
        'Waarde': [MAX_BATT_CAPA, SOC_START, SOC_MIN, BATTERIJ_SLIJTAGE, SOH, soc_ochtend, soc_minimum, ENERGIE_VERBRUIK_PER_KM, OPLAADKRACHT_PER_UUR],
        'Eenheid': ['kWh', 'Factor', 'Factor', 'Factor', 'kW (MBC * BS)', 'kW (SOH * SOC S)', 'kW (SOH * SOC M)', 'kWh/km', 'kWh/uur']
    }
    return pd.DataFrame(data)

def convert_to_datetime(time_str):
    """Functie om tijden naar datetime om te zetten."""
    if pd.isna(time_str):
        # Als de tijd ontbreekt, retourneer een NaT Timestamp
        return pd.NaT

    try:
        time_obj = pd.to_datetime(time_str, format='%H:%M').time()
    except TypeError:
        # Fallback als time_str geen geschikt formaat heeft
        return pd.NaT

    upper_boundary = pd.to_datetime('23:59', format='%H:%M').time()
    lower_boundary = pd.to_datetime('04:00', format='%H:%M').time()
    
    if lower_boundary <= time_obj <= upper_boundary:
        return pd.Timestamp('2024-08-29') + pd.Timedelta(hours=time_obj.hour, minutes=time_obj.minute)
    else:
        return pd.Timestamp('2024-08-30') + pd.Timedelta(hours=time_obj.hour, minutes=time_obj.minute)

def process_schedule_data(df_dienstregeling):
    """Functie om de nieuwe dienstregeling te verwerken."""
    df = df_dienstregeling.copy()
    
    # Vervang NaN door een standaardwaarde voordat je de conversie uitvoert
    df['buslijn'] = df['buslijn'].fillna(0).astype(int).astype(str)

    df['vertrek_datetime'] = df['vertrektijd'].apply(convert_to_datetime)
    df['Omloop'] = 0
    df_sorted = df.sort_values(by=['vertrek_datetime', 'buslijn'])
    df_sorted['code_omloop'] = df_sorted['startlocatie'].str.strip().str.lower() + '_' + \
                               df_sorted['eindlocatie'].str.strip().str.lower() + '_' + \
                               df_sorted['buslijn']
    return df_sorted

def process_distance_matrix(df_afstandsmatrix):
    """Functie om de afstandsmatrix te verwerken."""
    df = df_afstandsmatrix.copy()
    df['buslijn'] = df['buslijn'].fillna(0).astype(int).astype(str)
    df['code_afstand'] = df['startlocatie'].str.strip().str.lower() + '_' + \
                         df['eindlocatie'].str.strip().str.lower() + '_' + \
                         df['buslijn']
    return df

def setUpDataframes(df_nieuwe_dienstregelingv2, df_afstandsmatrix):
    """Kopieer en bereid dataframes voor gebruik voor de inplanting."""
    df = df_nieuwe_dienstregelingv2.copy()
    df['vertrek_datetime'] = pd.to_datetime(df['vertrek_datetime'])
    df['aankomst_datetime'] = pd.NaT
    df['Omloop'] = pd.NA
    return df

def vindt_reistijd(df_afstandsmatrix, startlocatie, eindlocatie):
    """Vind de reistijd tussen start- en eindlocatie."""
    rij = df_afstandsmatrix[
        (df_afstandsmatrix['startlocatie'] == startlocatie) &
        (df_afstandsmatrix['eindlocatie'] == eindlocatie)
    ]
    if not rij.empty:
        return int(rij['min reistijd in min'].values[0])
    return None

def inplannen_busritten(df_ritten, df_afstandsmatrix, aantal_bussen = 17):
    """Functie om busritten in te plannen voor een gespecificeerd aantal bussen met een verplichte rusttijd na elke vijfde keer bij 'ehvbst'."""
    
    for bus_nr in range(1, aantal_bussen + 1):
        actuele_tijd = df_ritten.iloc[0]['vertrek_datetime'] - timedelta(minutes=4)  # Start bij de garage
        huidige_locatie = 'ehvgar'
        count_ehvbst = 0  # Tel hoe vaak de bus bij 'ehvbst' is aangekomen
        iteration_count = 0

        while True:
            iteration_count += 1
            print(f"Bus {bus_nr}, Iteration {iteration_count}: Current time {actuele_tijd}, Current location {huidige_locatie}")

            mogelijk_ritten = df_ritten[
                (df_ritten['Omloop'].isna()) & 
                (df_ritten['vertrek_datetime'] >= actuele_tijd) & 
                (df_ritten['startlocatie'] == huidige_locatie)
            ]

            if not mogelijk_ritten.empty:
                row = mogelijk_ritten.iloc[0]  # Kies de eerst mogelijke rit
                print(f"Assigning ride at index {row.name} to bus {bus_nr}.")
                df_ritten.at[row.name, 'Omloop'] = bus_nr

                rit_duur = vindt_reistijd(df_afstandsmatrix, row['startlocatie'], row['eindlocatie'])
                if rit_duur is not None:
                    aankomsttijd = row['vertrek_datetime'] + timedelta(minutes=rit_duur)
                    df_ritten.at[row.name, 'aankomst_datetime'] = aankomsttijd
                    print(f"Ride at index {row.name} arrives at: {aankomsttijd}")

                    actuele_tijd = aankomsttijd
                    huidige_locatie = row['eindlocatie']

                    # Bijhouden hoe vaak 'ehvbst' bereikt is
                    if huidige_locatie == 'ehvbst':
                        count_ehvbst += 1
                        print(f"Bus {bus_nr} has now arrived at 'ehvbst' {count_ehvbst} times.")
                        
                        # Bij elke 5e keer een pauze van een uur incasseren
                        if count_ehvbst == 5:
                            print(f"Bus {bus_nr} taking a break for 1 hour at 'ehvbst'.")
                            actuele_tijd += timedelta(minutes= 35)
                            count_ehvbst = 0  # Reset de teller
                    
                    print(f"Ride ends at {aankomsttijd}, new current location is {huidige_locatie}.")
                continue

            volgende_startlocaties = df_ritten[
                (df_ritten['Omloop'].isna()) & 
                (df_ritten['vertrek_datetime'] > actuele_tijd)
            ]

            if volgende_startlocaties.empty:
                print(f"No more rides available for bus {bus_nr}, terminating loop.")
                break

            next_location_found = False
            for _, row in volgende_startlocaties.iterrows():
                reistijd = vindt_reistijd(df_afstandsmatrix, huidige_locatie, row['startlocatie'])
                if reistijd is not None and (actuele_tijd + timedelta(minutes=reistijd)) <= row['vertrek_datetime']:
                    print(f"Bus {bus_nr} moving to new start location {row['startlocatie']} with travel time {reistijd} minutes.")
                    actuele_tijd += timedelta(minutes=reistijd)
                    huidige_locatie = row['startlocatie']
                    next_location_found = True
                    break

            if not next_location_found:
                print(f"Unable to find a valid next location for bus {bus_nr}, terminating loop.")
                break

    return df_ritten


def filter_and_calculate(df_ritten, df_afstandsmatrix):
    """Filter de DataFrame en bereken afstand en batterijverbruik voor alle omlopen."""
    omloop_df_list = []  # Lijst om DataFrames voor elke omloop op te slaan

    # Verkrijg unieke omloopnummers
    unieke_omlopen = df_ritten['Omloop'].unique()

    for omloop_nummer in unieke_omlopen:
        omloop_df = df_ritten[df_ritten['Omloop'] == omloop_nummer].copy()

        # Voeg de 'afstand in meters' toe uit de afstandsmatrix
        omloop_df = omloop_df.merge(
            df_afstandsmatrix[['code_afstand', 'afstand in meters']],
            left_on='code_omloop',
            right_on='code_afstand',
            how='left'
        )

        # Kies de juiste kolom na de merge
        omloop_df['afstand in meters'] = omloop_df['afstand in meters_y'].fillna(0)

        # Verwijder onnodige suffixed kolommen
        kolommen_verwijderen = ['afstand in meters_x', 'afstand in meters_y', 'code_afstand_x', 'code_afstand_y']
        bestaande_kolommen = [kolom for kolom in kolommen_verwijderen if kolom in omloop_df.columns]
        omloop_df.drop(columns=bestaande_kolommen, inplace=True)

        # Bereken de afstand in kilometers
        omloop_df['afstand in km'] = omloop_df['afstand in meters'] / 1000

        # Bereken batterijgebruik voor actieve activiteit
        omloop_df['Batterijgebruik'] = omloop_df['afstand in km'] * ENERGIE_VERBRUIK_PER_KM

        # Stel batterijgebruik in op 0.01 als de activiteit 'idle' is
        omloop_df.loc[omloop_df['activiteit'] == 'idle', 'Batterijgebruik'] = 0.01

        # Voeg de DataFrame voor deze omloop toe aan de lijst
        omloop_df_list.append(omloop_df)

    # Concateneer alle omloop DataFrames tot één DataFrame
    final_df = pd.concat(omloop_df_list, ignore_index=True)

    return final_df

def add_activiteit_column(df):
    """Voegt een 'activiteit' kolom toe gebaseerd op de aanwezigheid van een omloopnummer."""
    df['activiteit'] = df['Omloop'].apply(lambda x: 'dienstrit' if pd.notna(x) else 'geen dienst')
    return df

def add_idle_activity(df):
    """Voegt 'idle' activiteiten toe waar nodig voor elke omloop afzonderlijk."""
    rows_to_add = []

    # Zorg ervoor dat datetime kolommen daadwerkelijk van het type datetime zijn
    df['vertrek_datetime'] = pd.to_datetime(df['vertrek_datetime'])
    df['aankomst_datetime'] = pd.to_datetime(df['aankomst_datetime'])

    # Sorteer het DataFrame op Omloop en vertrektijd om omlopen afzonderlijk te verwerken
    df = df.sort_values(by=['Omloop', 'vertrek_datetime']).reset_index(drop=True)

    # Groepeer per omloop en voeg idle-activiteiten per omloop toe
    for omloop, omloop_df in df.groupby('Omloop'):
        omloop_df = omloop_df.reset_index(drop=True)
        
        for i in range(1, len(omloop_df)):
            vorige_rit = omloop_df.iloc[i - 1]
            huidige_rit = omloop_df.iloc[i]

            # Controleer of idle tijd kan worden toegevoegd
            if pd.notna(vorige_rit['aankomst_datetime']) and vorige_rit['aankomst_datetime'] < huidige_rit['vertrek_datetime']:
                idle_start = vorige_rit['aankomst_datetime']
                idle_end = huidige_rit['vertrek_datetime']

                # Voeg een rij toe voor de "idle" periode
                rows_to_add.append({
                    'startlocatie': vorige_rit['eindlocatie'],
                    'eindlocatie': vorige_rit['eindlocatie'],
                    'vertrek_datetime': idle_start,
                    'aankomst_datetime': idle_end,
                    'buslijn': '',
                    'Omloop': omloop,
                    'activiteit': 'idle',
                    'afstand in meters': 0,
                    'afstand in km': 0,
                    'Batterijgebruik': 0.01,
                    'code_omloop': f"{vorige_rit['eindlocatie']}_{vorige_rit['eindlocatie']}_Idle"
                })
                # Debug print om te zien welke idle rij toegevoegd is
                print(f"Idle added for Omloop {omloop} from {idle_start} to {idle_end}.")

    # Voeg de 'idle' rijen toe aan het originele DataFrame
    if rows_to_add:
        idle_df = pd.DataFrame(rows_to_add)
        df = pd.concat([df, idle_df], ignore_index=True)

    # Herverdeel de DataFrame op volgorde van Omloop en vertrek_datetime
    df = df.sort_values(by=['Omloop', 'vertrek_datetime']).reset_index(drop=True)
    return df


def calculate_soc(df, initial_soc=243):
    """Voegt SOC_start en SOC_eind kolommen toe aan de DataFrame."""
    # Sorteren is belangrijk om juiste volgorde te behouden
    df = df.sort_values(['Omloop', 'vertrek_datetime']).reset_index(drop=True)

    # Initialiseren van de SOC kolommen
    df['SOC_start'] = 0.0
    df['SOC_eind'] = 0.0
    
    for omloop in df['Omloop'].unique():
        omloop_data = df[df['Omloop'] == omloop]
        prev_soc_eind = initial_soc
        
        for index, row in omloop_data.iterrows():
            if index == omloop_data.index[0]:  # Eerste rit van Omloop
                soc_start = initial_soc
            else:
                soc_start = prev_soc_eind

            # Bereken de SOC_eind
            soc_eind = soc_start - row['Batterijgebruik']

            # Update DataFrame
            df.at[index, 'SOC_start'] = soc_start
            df.at[index, 'SOC_eind'] = soc_eind

            # Update previous SOC_eind for next iteration
            prev_soc_eind = soc_eind

    return df

def manage_battery_and_charging(df, target_soc=243, drive_time=timedelta(minutes=4), charge_duration=timedelta(minutes=25)):
    """Laad de bus op als er een uur idle tijd is tussen de aankomst en het vertrek van ritten."""
    df = df.sort_values(['Omloop', 'vertrek_datetime']).reset_index(drop=True)
    adjusted_rows = []
    prev_soc_eind = target_soc  # Begin met volle lading

    # Default structure for a row
    default_row = {
        'startlocatie': None,
        'eindlocatie': None,
        'vertrektijd': None,
        'buslijn': None,
        'vertrek_datetime': None,
        'aankomst_datetime': None,
        'Omloop': None,
        'code_omloop': None,
        'activiteit': None,
        'afstand in km': None,
        'Batterijgebruik': None,
        'code_afstand': None,
        'afstand in meters': None,
        'SOC_start': None,
        'SOC_eind': None,
    }

    for index, row in df.iterrows():
        soc_start = prev_soc_eind if index != 0 else target_soc
        soc_eind = soc_start - row['Batterijgebruik']

        # Voeg de huidige rit toe
        adjusted_rows.append({
            **default_row,
            **row.to_dict(),
            'SOC_start': soc_start,
            'SOC_eind': soc_eind,
        })
        prev_soc_eind = soc_eind

        # Check of er een uur idle tijd is na deze rit
        if index < len(df) - 1:
            next_row = df.iloc[index + 1]

            # Bereken de idle tijd tussen de huidige aankomst en de volgende vertrek
            idle_time = next_row['vertrek_datetime'] - row['aankomst_datetime']

            # Als er voldoende idle tijd is
            if idle_time >= timedelta(minutes = 33):
                # Voeg materiaalrit naar garage toe
                to_garage_end_time = row['aankomst_datetime'] + drive_time
                adjusted_rows.append({
                    **default_row,
                    'startlocatie': row['eindlocatie'],
                    'eindlocatie': 'ehvgarage',
                    'vertrek_datetime': row['aankomst_datetime'],
                    'aankomst_datetime': to_garage_end_time,
                    'activiteit': 'materiaalrit',
                    'Batterijgebruik': 0.2,
                    'SOC_start': soc_eind,
                    'SOC_eind': soc_eind - 0.2,
                    'Omloop': row['Omloop']
                })

                # Laad de bus op
                charge_time_start = to_garage_end_time
                soc_charged = target_soc  # Doel SOC

                charge_time_end = charge_time_start + charge_duration
                adjusted_rows.append({
                    **default_row,
                    'startlocatie': 'ehvgarage',
                    'eindlocatie': 'ehvgarage',
                    'vertrek_datetime': charge_time_start,
                    'aankomst_datetime': charge_time_end,
                    'activiteit': 'opladen',
                    'Batterijgebruik': (soc_eind - 0.2 - soc_charged),  # Negatief om opladen aan te geven
                    'SOC_start': soc_eind - 0.2,
                    'SOC_eind': soc_charged,
                    'Omloop': row['Omloop']
                })

                # Materiaal rit terug naar de oorspronkelijke eindlocatie
                return_time = charge_time_end + drive_time
                adjusted_rows.append({
                    **default_row,
                    'startlocatie': 'ehvgarage',
                    'eindlocatie': row['eindlocatie'],
                    'vertrek_datetime': charge_time_end,
                    'aankomst_datetime': return_time,
                    'activiteit': 'materiaalrit',
                    'Batterijgebruik': 0.2,
                    'SOC_start': soc_charged,
                    'SOC_eind': soc_charged - 0.2,
                    'Omloop': row['Omloop']
                })

                prev_soc_eind = soc_charged - 0.2

    adjusted_df = pd.DataFrame(adjusted_rows)
    adjusted_df = adjusted_df.sort_values(by='vertrek_datetime').reset_index(drop=True)
    return adjusted_df


# Inladen van data
df_omloopplanning, df_dienstregeling, df_afstandsmatrix = load_data()

# Maak de parameters DataFrame en laat deze zien
df_parameters = create_parameters_df()
display(df_parameters)

# Verwerk dienstregeling en afstandsmatrix data
df_nieuwe_dienstregelingv2 = process_schedule_data(df_dienstregeling)
df_afstandsmatrix = process_distance_matrix(df_afstandsmatrix)

# Setting up the dataframes
df_nieuwe_dienstregelingv1 = setUpDataframes(df_nieuwe_dienstregelingv2, df_afstandsmatrix)

# Plan de busritten
df_processed_ritten = inplannen_busritten(df_nieuwe_dienstregelingv1, df_afstandsmatrix)

# Voer de functie uit na het verwerken van ritten
df_processed_ritten = add_activiteit_column(df_processed_ritten)

# Voeg de idle activiteiten in de verwerkte ritten toe
# Voer een test uit en controleer op output
# Voeg de idle activiteiten in de verwerkte ritten toe zonder de filter

df_with_idle = add_idle_activity(df_processed_ritten)

# display(df_with_idle[df_with_idle['activiteit'] == 'idle'])
#display(df_with_idle[df_with_idle['Omloop']==12])
# Filter en bereken
omloop_df = filter_and_calculate(df_with_idle, df_afstandsmatrix)
#display(omloop_df[omloop_df['Omloop']==10])
# Toevoegen van SOC kolommen aan de DataFrame met ritten
df_with_soc = calculate_soc(omloop_df)
display(df_with_soc)
# Filter out rows with 'idle' activity and simulate battery charging and material trips
df_filtered = df_with_soc[df_with_soc['activiteit'] != 'idle']
#display(df_filtered[df_filtered['Omloop']==2])
df_adjusted = manage_battery_and_charging(df_filtered)
df_adjusted = add_idle_activity(df_adjusted)
# Weergeven van het resultaat
display(df_adjusted[df_adjusted['Omloop']==1])
# Out:
#                  Parameter  Waarde           Eenheid
# 0  Max Batterij Capaciteit   300.0               kWh
# 1                SOC Start     0.9            Factor
# 2              SOC Minimum     0.1            Factor
# 3        Batterij Slijtage     0.9            Factor
# 4                      SOH   270.0     kW (MBC * BS)
# 5              SOC Ochtend   243.0  kW (SOH * SOC S)
# 6              SOC Minimum    27.0  kW (SOH * SOC M)
# 7          Batterijverbuik     1.2            kWh/km
# 8           Oplaadsnelheid   450.0           kWh/uur
# Bus 1, Iteration 1: Current time 2024-08-29 05:03:00, Current location ehvgar
# Bus 1 moving to new start location ehvbst with travel time 4 minutes.
# Bus 1, Iteration 2: Current time 2024-08-29 05:07:00, Current location ehvbst
# Assigning ride at index 163 to bus 1.
# Ride at index 163 arrives at: 2024-08-29 05:28:00
# Ride ends at 2024-08-29 05:28:00, new current location is ehvapt.
# Bus 1, Iteration 3: Current time 2024-08-29 05:28:00, Current location ehvapt
# Assigning ride at index 0 to bus 1.
# Ride at index 0 arrives at: 2024-08-29 06:25:00
# Bus 1 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 06:25:00, new current location is ehvbst.
# Bus 1, Iteration 4: Current time 2024-08-29 06:25:00, Current location ehvbst
# Assigning ride at index 166 to bus 1.
# Ride at index 166 arrives at: 2024-08-29 06:52:00
# Ride ends at 2024-08-29 06:52:00, new current location is ehvapt.
# Bus 1, Iteration 5: Current time 2024-08-29 06:52:00, Current location ehvapt
# Assigning ride at index 2 to bus 1.
# Ride at index 2 arrives at: 2024-08-29 07:17:00
# Bus 1 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 07:17:00, new current location is ehvbst.
# Bus 1, Iteration 6: Current time 2024-08-29 07:17:00, Current location ehvbst
# Assigning ride at index 170 to bus 1.
# Ride at index 170 arrives at: 2024-08-29 07:40:00
# Ride ends at 2024-08-29 07:40:00, new current location is ehvapt.
# Bus 1, Iteration 7: Current time 2024-08-29 07:40:00, Current location ehvapt
# Assigning ride at index 6 to bus 1.
# Ride at index 6 arrives at: 2024-08-29 08:07:00
# Bus 1 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 08:07:00, new current location is ehvbst.
# Bus 1, Iteration 8: Current time 2024-08-29 08:07:00, Current location ehvbst
# Assigning ride at index 175 to bus 1.
# Ride at index 175 arrives at: 2024-08-29 08:30:00
# Ride ends at 2024-08-29 08:30:00, new current location is ehvapt.
# Bus 1, Iteration 9: Current time 2024-08-29 08:30:00, Current location ehvapt
# Assigning ride at index 93 to bus 1.
# Ride at index 93 arrives at: 2024-08-29 08:55:00
# Bus 1 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 08:55:00, new current location is ehvbst.
# Bus 1, Iteration 10: Current time 2024-08-29 08:55:00, Current location ehvbst
# Assigning ride at index 180 to bus 1.
# Ride at index 180 arrives at: 2024-08-29 09:20:00
# Ride ends at 2024-08-29 09:20:00, new current location is ehvapt.
# Bus 1, Iteration 11: Current time 2024-08-29 09:20:00, Current location ehvapt
# Assigning ride at index 16 to bus 1.
# Ride at index 16 arrives at: 2024-08-29 09:47:00
# Bus 1 has now arrived at 'ehvbst' 5 times.
# Bus 1 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 09:47:00, new current location is ehvbst.
# Bus 1, Iteration 12: Current time 2024-08-29 10:22:00, Current location ehvbst
# Assigning ride at index 272 to bus 1.
# Ride at index 272 arrives at: 2024-08-29 10:45:00
# Ride ends at 2024-08-29 10:45:00, new current location is ehvapt.
# Bus 1, Iteration 13: Current time 2024-08-29 10:45:00, Current location ehvapt
# Assigning ride at index 24 to bus 1.
# Ride at index 24 arrives at: 2024-08-29 11:07:00
# Bus 1 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 11:07:00, new current location is ehvbst.
# Bus 1, Iteration 14: Current time 2024-08-29 11:07:00, Current location ehvbst
# Assigning ride at index 193 to bus 1.
# Ride at index 193 arrives at: 2024-08-29 11:30:00
# Ride ends at 2024-08-29 11:30:00, new current location is ehvapt.
# Bus 1, Iteration 15: Current time 2024-08-29 11:30:00, Current location ehvapt
# Assigning ride at index 111 to bus 1.
# Ride at index 111 arrives at: 2024-08-29 11:55:00
# Bus 1 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 11:55:00, new current location is ehvbst.
# Bus 1, Iteration 16: Current time 2024-08-29 11:55:00, Current location ehvbst
# Assigning ride at index 198 to bus 1.
# Ride at index 198 arrives at: 2024-08-29 12:20:00
# Ride ends at 2024-08-29 12:20:00, new current location is ehvapt.
# Bus 1, Iteration 17: Current time 2024-08-29 12:20:00, Current location ehvapt
# Assigning ride at index 34 to bus 1.
# Ride at index 34 arrives at: 2024-08-29 12:47:00
# Bus 1 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 12:47:00, new current location is ehvbst.
# Bus 1, Iteration 18: Current time 2024-08-29 12:47:00, Current location ehvbst
# Assigning ride at index 203 to bus 1.
# Ride at index 203 arrives at: 2024-08-29 13:10:00
# Ride ends at 2024-08-29 13:10:00, new current location is ehvapt.
# Bus 1, Iteration 19: Current time 2024-08-29 13:10:00, Current location ehvapt
# Assigning ride at index 39 to bus 1.
# Ride at index 39 arrives at: 2024-08-29 13:37:00
# Bus 1 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 13:37:00, new current location is ehvbst.
# Bus 1, Iteration 20: Current time 2024-08-29 13:37:00, Current location ehvbst
# Assigning ride at index 208 to bus 1.
# Ride at index 208 arrives at: 2024-08-29 14:00:00
# Ride ends at 2024-08-29 14:00:00, new current location is ehvapt.
# Bus 1, Iteration 21: Current time 2024-08-29 14:00:00, Current location ehvapt
# Assigning ride at index 126 to bus 1.
# Ride at index 126 arrives at: 2024-08-29 14:25:00
# Bus 1 has now arrived at 'ehvbst' 5 times.
# Bus 1 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 14:25:00, new current location is ehvbst.
# Bus 1, Iteration 22: Current time 2024-08-29 15:00:00, Current location ehvbst
# Assigning ride at index 300 to bus 1.
# Ride at index 300 arrives at: 2024-08-29 15:27:00
# Ride ends at 2024-08-29 15:27:00, new current location is ehvapt.
# Bus 1, Iteration 23: Current time 2024-08-29 15:27:00, Current location ehvapt
# Assigning ride at index 134 to bus 1.
# Ride at index 134 arrives at: 2024-08-29 15:48:00
# Bus 1 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 15:48:00, new current location is ehvbst.
# Bus 1, Iteration 24: Current time 2024-08-29 15:48:00, Current location ehvbst
# Assigning ride at index 221 to bus 1.
# Ride at index 221 arrives at: 2024-08-29 16:10:00
# Ride ends at 2024-08-29 16:10:00, new current location is ehvapt.
# Bus 1, Iteration 25: Current time 2024-08-29 16:10:00, Current location ehvapt
# Assigning ride at index 57 to bus 1.
# Ride at index 57 arrives at: 2024-08-29 16:37:00
# Bus 1 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 16:37:00, new current location is ehvbst.
# Bus 1, Iteration 26: Current time 2024-08-29 16:37:00, Current location ehvbst
# Assigning ride at index 226 to bus 1.
# Ride at index 226 arrives at: 2024-08-29 17:00:00
# Ride ends at 2024-08-29 17:00:00, new current location is ehvapt.
# Bus 1, Iteration 27: Current time 2024-08-29 17:00:00, Current location ehvapt
# Assigning ride at index 144 to bus 1.
# Ride at index 144 arrives at: 2024-08-29 17:25:00
# Bus 1 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 17:25:00, new current location is ehvbst.
# Bus 1, Iteration 28: Current time 2024-08-29 17:25:00, Current location ehvbst
# Assigning ride at index 231 to bus 1.
# Ride at index 231 arrives at: 2024-08-29 17:50:00
# Ride ends at 2024-08-29 17:50:00, new current location is ehvapt.
# Bus 1, Iteration 29: Current time 2024-08-29 17:50:00, Current location ehvapt
# Assigning ride at index 67 to bus 1.
# Ride at index 67 arrives at: 2024-08-29 18:17:00
# Bus 1 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 18:17:00, new current location is ehvbst.
# Bus 1, Iteration 30: Current time 2024-08-29 18:17:00, Current location ehvbst
# Assigning ride at index 319 to bus 1.
# Ride at index 319 arrives at: 2024-08-29 18:43:00
# Ride ends at 2024-08-29 18:43:00, new current location is ehvapt.
# Bus 1, Iteration 31: Current time 2024-08-29 18:43:00, Current location ehvapt
# Assigning ride at index 154 to bus 1.
# Ride at index 154 arrives at: 2024-08-29 19:10:00
# Bus 1 has now arrived at 'ehvbst' 5 times.
# Bus 1 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 19:10:00, new current location is ehvbst.
# Bus 1, Iteration 32: Current time 2024-08-29 19:45:00, Current location ehvbst
# Assigning ride at index 242 to bus 1.
# Ride at index 242 arrives at: 2024-08-29 20:28:00
# Ride ends at 2024-08-29 20:28:00, new current location is ehvapt.
# Bus 1, Iteration 33: Current time 2024-08-29 20:28:00, Current location ehvapt
# Assigning ride at index 78 to bus 1.
# Ride at index 78 arrives at: 2024-08-29 20:56:00
# Bus 1 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 20:56:00, new current location is ehvbst.
# Bus 1, Iteration 34: Current time 2024-08-29 20:56:00, Current location ehvbst
# Assigning ride at index 245 to bus 1.
# Ride at index 245 arrives at: 2024-08-29 21:28:00
# Ride ends at 2024-08-29 21:28:00, new current location is ehvapt.
# Bus 1, Iteration 35: Current time 2024-08-29 21:28:00, Current location ehvapt
# Assigning ride at index 80 to bus 1.
# Ride at index 80 arrives at: 2024-08-29 21:56:00
# Bus 1 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 21:56:00, new current location is ehvbst.
# Bus 1, Iteration 36: Current time 2024-08-29 21:56:00, Current location ehvbst
# Assigning ride at index 247 to bus 1.
# Ride at index 247 arrives at: 2024-08-29 22:28:00
# Ride ends at 2024-08-29 22:28:00, new current location is ehvapt.
# Bus 1, Iteration 37: Current time 2024-08-29 22:28:00, Current location ehvapt
# Assigning ride at index 82 to bus 1.
# Ride at index 82 arrives at: 2024-08-29 22:56:00
# Bus 1 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 22:56:00, new current location is ehvbst.
# Bus 1, Iteration 38: Current time 2024-08-29 22:56:00, Current location ehvbst
# Assigning ride at index 249 to bus 1.
# Ride at index 249 arrives at: 2024-08-29 23:28:00
# Ride ends at 2024-08-29 23:28:00, new current location is ehvapt.
# Bus 1, Iteration 39: Current time 2024-08-29 23:28:00, Current location ehvapt
# Assigning ride at index 84 to bus 1.
# Ride at index 84 arrives at: 2024-08-29 23:56:00
# Bus 1 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 23:56:00, new current location is ehvbst.
# Bus 1, Iteration 40: Current time 2024-08-29 23:56:00, Current location ehvbst
# Assigning ride at index 251 to bus 1.
# Ride at index 251 arrives at: 2024-08-30 00:30:00
# Ride ends at 2024-08-30 00:30:00, new current location is ehvapt.
# Bus 1, Iteration 41: Current time 2024-08-30 00:30:00, Current location ehvapt
# Assigning ride at index 86 to bus 1.
# Ride at index 86 arrives at: 2024-08-30 00:52:00
# Bus 1 has now arrived at 'ehvbst' 5 times.
# Bus 1 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-30 00:52:00, new current location is ehvbst.
# Bus 1, Iteration 42: Current time 2024-08-30 01:27:00, Current location ehvbst
# No more rides available for bus 1, terminating loop.
# Bus 2, Iteration 1: Current time 2024-08-29 05:03:00, Current location ehvgar
# Bus 2 moving to new start location ehvbst with travel time 4 minutes.
# Bus 2, Iteration 2: Current time 2024-08-29 05:07:00, Current location ehvbst
# Assigning ride at index 164 to bus 2.
# Ride at index 164 arrives at: 2024-08-29 05:58:00
# Ride ends at 2024-08-29 05:58:00, new current location is ehvapt.
# Bus 2, Iteration 3: Current time 2024-08-29 05:58:00, Current location ehvapt
# Assigning ride at index 1 to bus 2.
# Ride at index 1 arrives at: 2024-08-29 06:55:00
# Bus 2 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 06:55:00, new current location is ehvbst.
# Bus 2, Iteration 4: Current time 2024-08-29 06:55:00, Current location ehvbst
# Assigning ride at index 168 to bus 2.
# Ride at index 168 arrives at: 2024-08-29 07:20:00
# Ride ends at 2024-08-29 07:20:00, new current location is ehvapt.
# Bus 2, Iteration 5: Current time 2024-08-29 07:20:00, Current location ehvapt
# Assigning ride at index 4 to bus 2.
# Ride at index 4 arrives at: 2024-08-29 07:47:00
# Bus 2 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 07:47:00, new current location is ehvbst.
# Bus 2, Iteration 6: Current time 2024-08-29 07:47:00, Current location ehvbst
# Assigning ride at index 173 to bus 2.
# Ride at index 173 arrives at: 2024-08-29 08:10:00
# Ride ends at 2024-08-29 08:10:00, new current location is ehvapt.
# Bus 2, Iteration 7: Current time 2024-08-29 08:10:00, Current location ehvapt
# Assigning ride at index 9 to bus 2.
# Ride at index 9 arrives at: 2024-08-29 08:37:00
# Bus 2 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 08:37:00, new current location is ehvbst.
# Bus 2, Iteration 8: Current time 2024-08-29 08:37:00, Current location ehvbst
# Assigning ride at index 178 to bus 2.
# Ride at index 178 arrives at: 2024-08-29 09:00:00
# Ride ends at 2024-08-29 09:00:00, new current location is ehvapt.
# Bus 2, Iteration 9: Current time 2024-08-29 09:00:00, Current location ehvapt
# Assigning ride at index 96 to bus 2.
# Ride at index 96 arrives at: 2024-08-29 09:25:00
# Bus 2 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 09:25:00, new current location is ehvbst.
# Bus 2, Iteration 10: Current time 2024-08-29 09:25:00, Current location ehvbst
# Assigning ride at index 183 to bus 2.
# Ride at index 183 arrives at: 2024-08-29 09:50:00
# Ride ends at 2024-08-29 09:50:00, new current location is ehvapt.
# Bus 2, Iteration 11: Current time 2024-08-29 09:50:00, Current location ehvapt
# Assigning ride at index 19 to bus 2.
# Ride at index 19 arrives at: 2024-08-29 10:17:00
# Bus 2 has now arrived at 'ehvbst' 5 times.
# Bus 2 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 10:17:00, new current location is ehvbst.
# Bus 2, Iteration 12: Current time 2024-08-29 10:52:00, Current location ehvbst
# Assigning ride at index 275 to bus 2.
# Ride at index 275 arrives at: 2024-08-29 11:15:00
# Ride ends at 2024-08-29 11:15:00, new current location is ehvapt.
# Bus 2, Iteration 13: Current time 2024-08-29 11:15:00, Current location ehvapt
# Assigning ride at index 27 to bus 2.
# Ride at index 27 arrives at: 2024-08-29 11:37:00
# Bus 2 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 11:37:00, new current location is ehvbst.
# Bus 2, Iteration 14: Current time 2024-08-29 11:37:00, Current location ehvbst
# Assigning ride at index 196 to bus 2.
# Ride at index 196 arrives at: 2024-08-29 12:00:00
# Ride ends at 2024-08-29 12:00:00, new current location is ehvapt.
# Bus 2, Iteration 15: Current time 2024-08-29 12:00:00, Current location ehvapt
# Assigning ride at index 114 to bus 2.
# Ride at index 114 arrives at: 2024-08-29 12:25:00
# Bus 2 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 12:25:00, new current location is ehvbst.
# Bus 2, Iteration 16: Current time 2024-08-29 12:25:00, Current location ehvbst
# Assigning ride at index 201 to bus 2.
# Ride at index 201 arrives at: 2024-08-29 12:50:00
# Ride ends at 2024-08-29 12:50:00, new current location is ehvapt.
# Bus 2, Iteration 17: Current time 2024-08-29 12:50:00, Current location ehvapt
# Assigning ride at index 37 to bus 2.
# Ride at index 37 arrives at: 2024-08-29 13:17:00
# Bus 2 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 13:17:00, new current location is ehvbst.
# Bus 2, Iteration 18: Current time 2024-08-29 13:17:00, Current location ehvbst
# Assigning ride at index 206 to bus 2.
# Ride at index 206 arrives at: 2024-08-29 13:40:00
# Ride ends at 2024-08-29 13:40:00, new current location is ehvapt.
# Bus 2, Iteration 19: Current time 2024-08-29 13:40:00, Current location ehvapt
# Assigning ride at index 42 to bus 2.
# Ride at index 42 arrives at: 2024-08-29 14:07:00
# Bus 2 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 14:07:00, new current location is ehvbst.
# Bus 2, Iteration 20: Current time 2024-08-29 14:07:00, Current location ehvbst
# Assigning ride at index 211 to bus 2.
# Ride at index 211 arrives at: 2024-08-29 14:30:00
# Ride ends at 2024-08-29 14:30:00, new current location is ehvapt.
# Bus 2, Iteration 21: Current time 2024-08-29 14:30:00, Current location ehvapt
# Assigning ride at index 129 to bus 2.
# Ride at index 129 arrives at: 2024-08-29 14:55:00
# Bus 2 has now arrived at 'ehvbst' 5 times.
# Bus 2 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 14:55:00, new current location is ehvbst.
# Bus 2, Iteration 22: Current time 2024-08-29 15:30:00, Current location ehvbst
# Assigning ride at index 303 to bus 2.
# Ride at index 303 arrives at: 2024-08-29 15:57:00
# Ride ends at 2024-08-29 15:57:00, new current location is ehvapt.
# Bus 2, Iteration 23: Current time 2024-08-29 15:57:00, Current location ehvapt
# Assigning ride at index 137 to bus 2.
# Ride at index 137 arrives at: 2024-08-29 16:18:00
# Bus 2 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 16:18:00, new current location is ehvbst.
# Bus 2, Iteration 24: Current time 2024-08-29 16:18:00, Current location ehvbst
# Assigning ride at index 224 to bus 2.
# Ride at index 224 arrives at: 2024-08-29 16:40:00
# Ride ends at 2024-08-29 16:40:00, new current location is ehvapt.
# Bus 2, Iteration 25: Current time 2024-08-29 16:40:00, Current location ehvapt
# Assigning ride at index 60 to bus 2.
# Ride at index 60 arrives at: 2024-08-29 17:07:00
# Bus 2 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 17:07:00, new current location is ehvbst.
# Bus 2, Iteration 26: Current time 2024-08-29 17:07:00, Current location ehvbst
# Assigning ride at index 229 to bus 2.
# Ride at index 229 arrives at: 2024-08-29 17:30:00
# Ride ends at 2024-08-29 17:30:00, new current location is ehvapt.
# Bus 2, Iteration 27: Current time 2024-08-29 17:30:00, Current location ehvapt
# Assigning ride at index 147 to bus 2.
# Ride at index 147 arrives at: 2024-08-29 17:55:00
# Bus 2 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 17:55:00, new current location is ehvbst.
# Bus 2, Iteration 28: Current time 2024-08-29 17:55:00, Current location ehvbst
# Assigning ride at index 234 to bus 2.
# Ride at index 234 arrives at: 2024-08-29 18:20:00
# Ride ends at 2024-08-29 18:20:00, new current location is ehvapt.
# Bus 2, Iteration 29: Current time 2024-08-29 18:20:00, Current location ehvapt
# Assigning ride at index 70 to bus 2.
# Ride at index 70 arrives at: 2024-08-29 18:47:00
# Bus 2 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 18:47:00, new current location is ehvbst.
# Bus 2, Iteration 30: Current time 2024-08-29 18:47:00, Current location ehvbst
# Assigning ride at index 322 to bus 2.
# Ride at index 322 arrives at: 2024-08-29 19:13:00
# Ride ends at 2024-08-29 19:13:00, new current location is ehvapt.
# Bus 2, Iteration 31: Current time 2024-08-29 19:13:00, Current location ehvapt
# Assigning ride at index 157 to bus 2.
# Ride at index 157 arrives at: 2024-08-29 19:40:00
# Bus 2 has now arrived at 'ehvbst' 5 times.
# Bus 2 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 19:40:00, new current location is ehvbst.
# Bus 2, Iteration 32: Current time 2024-08-29 20:15:00, Current location ehvbst
# Assigning ride at index 243 to bus 2.
# Ride at index 243 arrives at: 2024-08-29 20:43:00
# Ride ends at 2024-08-29 20:43:00, new current location is ehvapt.
# Bus 2, Iteration 33: Current time 2024-08-29 20:43:00, Current location ehvapt
# Assigning ride at index 162 to bus 2.
# Ride at index 162 arrives at: 2024-08-29 21:07:00
# Bus 2 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 21:07:00, new current location is ehvbst.
# Bus 2, Iteration 34: Current time 2024-08-29 21:07:00, Current location ehvbst
# Assigning ride at index 246 to bus 2.
# Ride at index 246 arrives at: 2024-08-29 21:58:00
# Ride ends at 2024-08-29 21:58:00, new current location is ehvapt.
# Bus 2, Iteration 35: Current time 2024-08-29 21:58:00, Current location ehvapt
# Assigning ride at index 81 to bus 2.
# Ride at index 81 arrives at: 2024-08-29 22:26:00
# Bus 2 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 22:26:00, new current location is ehvbst.
# Bus 2, Iteration 36: Current time 2024-08-29 22:26:00, Current location ehvbst
# Assigning ride at index 248 to bus 2.
# Ride at index 248 arrives at: 2024-08-29 22:58:00
# Ride ends at 2024-08-29 22:58:00, new current location is ehvapt.
# Bus 2, Iteration 37: Current time 2024-08-29 22:58:00, Current location ehvapt
# Assigning ride at index 83 to bus 2.
# Ride at index 83 arrives at: 2024-08-29 23:26:00
# Bus 2 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 23:26:00, new current location is ehvbst.
# Bus 2, Iteration 38: Current time 2024-08-29 23:26:00, Current location ehvbst
# Assigning ride at index 250 to bus 2.
# Ride at index 250 arrives at: 2024-08-29 23:58:00
# Ride ends at 2024-08-29 23:58:00, new current location is ehvapt.
# Bus 2, Iteration 39: Current time 2024-08-29 23:58:00, Current location ehvapt
# Assigning ride at index 85 to bus 2.
# Ride at index 85 arrives at: 2024-08-30 00:22:00
# Bus 2 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-30 00:22:00, new current location is ehvbst.
# Bus 2, Iteration 40: Current time 2024-08-30 00:22:00, Current location ehvbst
# No more rides available for bus 2, terminating loop.
# Bus 3, Iteration 1: Current time 2024-08-29 05:03:00, Current location ehvgar
# Bus 3 moving to new start location ehvbst with travel time 4 minutes.
# Bus 3, Iteration 2: Current time 2024-08-29 05:07:00, Current location ehvbst
# Assigning ride at index 165 to bus 3.
# Ride at index 165 arrives at: 2024-08-29 06:28:00
# Ride ends at 2024-08-29 06:28:00, new current location is ehvapt.
# Bus 3, Iteration 3: Current time 2024-08-29 06:28:00, Current location ehvapt
# Assigning ride at index 3 to bus 3.
# Ride at index 3 arrives at: 2024-08-29 07:32:00
# Bus 3 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 07:32:00, new current location is ehvbst.
# Bus 3, Iteration 4: Current time 2024-08-29 07:32:00, Current location ehvbst
# Assigning ride at index 255 to bus 3.
# Ride at index 255 arrives at: 2024-08-29 07:57:00
# Ride ends at 2024-08-29 07:57:00, new current location is ehvapt.
# Bus 3, Iteration 5: Current time 2024-08-29 07:57:00, Current location ehvapt
# Assigning ride at index 90 to bus 3.
# Ride at index 90 arrives at: 2024-08-29 08:25:00
# Bus 3 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 08:25:00, new current location is ehvbst.
# Bus 3, Iteration 6: Current time 2024-08-29 08:25:00, Current location ehvbst
# Assigning ride at index 177 to bus 3.
# Ride at index 177 arrives at: 2024-08-29 08:50:00
# Ride ends at 2024-08-29 08:50:00, new current location is ehvapt.
# Bus 3, Iteration 7: Current time 2024-08-29 08:50:00, Current location ehvapt
# Assigning ride at index 13 to bus 3.
# Ride at index 13 arrives at: 2024-08-29 09:17:00
# Bus 3 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 09:17:00, new current location is ehvbst.
# Bus 3, Iteration 8: Current time 2024-08-29 09:17:00, Current location ehvbst
# Assigning ride at index 182 to bus 3.
# Ride at index 182 arrives at: 2024-08-29 09:40:00
# Ride ends at 2024-08-29 09:40:00, new current location is ehvapt.
# Bus 3, Iteration 9: Current time 2024-08-29 09:40:00, Current location ehvapt
# Assigning ride at index 18 to bus 3.
# Ride at index 18 arrives at: 2024-08-29 10:07:00
# Bus 3 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 10:07:00, new current location is ehvbst.
# Bus 3, Iteration 10: Current time 2024-08-29 10:07:00, Current location ehvbst
# Assigning ride at index 187 to bus 3.
# Ride at index 187 arrives at: 2024-08-29 10:30:00
# Ride ends at 2024-08-29 10:30:00, new current location is ehvapt.
# Bus 3, Iteration 11: Current time 2024-08-29 10:30:00, Current location ehvapt
# Assigning ride at index 105 to bus 3.
# Ride at index 105 arrives at: 2024-08-29 10:55:00
# Bus 3 has now arrived at 'ehvbst' 5 times.
# Bus 3 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 10:55:00, new current location is ehvbst.
# Bus 3, Iteration 12: Current time 2024-08-29 11:30:00, Current location ehvbst
# Assigning ride at index 279 to bus 3.
# Ride at index 279 arrives at: 2024-08-29 11:57:00
# Ride ends at 2024-08-29 11:57:00, new current location is ehvapt.
# Bus 3, Iteration 13: Current time 2024-08-29 11:57:00, Current location ehvapt
# Assigning ride at index 113 to bus 3.
# Ride at index 113 arrives at: 2024-08-29 12:18:00
# Bus 3 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 12:18:00, new current location is ehvbst.
# Bus 3, Iteration 14: Current time 2024-08-29 12:18:00, Current location ehvbst
# Assigning ride at index 200 to bus 3.
# Ride at index 200 arrives at: 2024-08-29 12:40:00
# Ride ends at 2024-08-29 12:40:00, new current location is ehvapt.
# Bus 3, Iteration 15: Current time 2024-08-29 12:40:00, Current location ehvapt
# Assigning ride at index 36 to bus 3.
# Ride at index 36 arrives at: 2024-08-29 13:07:00
# Bus 3 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 13:07:00, new current location is ehvbst.
# Bus 3, Iteration 16: Current time 2024-08-29 13:07:00, Current location ehvbst
# Assigning ride at index 205 to bus 3.
# Ride at index 205 arrives at: 2024-08-29 13:30:00
# Ride ends at 2024-08-29 13:30:00, new current location is ehvapt.
# Bus 3, Iteration 17: Current time 2024-08-29 13:30:00, Current location ehvapt
# Assigning ride at index 123 to bus 3.
# Ride at index 123 arrives at: 2024-08-29 13:55:00
# Bus 3 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 13:55:00, new current location is ehvbst.
# Bus 3, Iteration 18: Current time 2024-08-29 13:55:00, Current location ehvbst
# Assigning ride at index 210 to bus 3.
# Ride at index 210 arrives at: 2024-08-29 14:20:00
# Ride ends at 2024-08-29 14:20:00, new current location is ehvapt.
# Bus 3, Iteration 19: Current time 2024-08-29 14:20:00, Current location ehvapt
# Assigning ride at index 46 to bus 3.
# Ride at index 46 arrives at: 2024-08-29 14:47:00
# Bus 3 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 14:47:00, new current location is ehvbst.
# Bus 3, Iteration 20: Current time 2024-08-29 14:47:00, Current location ehvbst
# Assigning ride at index 215 to bus 3.
# Ride at index 215 arrives at: 2024-08-29 15:10:00
# Ride ends at 2024-08-29 15:10:00, new current location is ehvapt.
# Bus 3, Iteration 21: Current time 2024-08-29 15:10:00, Current location ehvapt
# Assigning ride at index 51 to bus 3.
# Ride at index 51 arrives at: 2024-08-29 15:37:00
# Bus 3 has now arrived at 'ehvbst' 5 times.
# Bus 3 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 15:37:00, new current location is ehvbst.
# Bus 3, Iteration 22: Current time 2024-08-29 16:12:00, Current location ehvbst
# Assigning ride at index 307 to bus 3.
# Ride at index 307 arrives at: 2024-08-29 16:42:00
# Ride ends at 2024-08-29 16:42:00, new current location is ehvapt.
# Bus 3, Iteration 23: Current time 2024-08-29 16:42:00, Current location ehvapt
# Assigning ride at index 142 to bus 3.
# Ride at index 142 arrives at: 2024-08-29 17:10:00
# Bus 3 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 17:10:00, new current location is ehvbst.
# Bus 3, Iteration 24: Current time 2024-08-29 17:10:00, Current location ehvbst
# Assigning ride at index 230 to bus 3.
# Ride at index 230 arrives at: 2024-08-29 17:40:00
# Ride ends at 2024-08-29 17:40:00, new current location is ehvapt.
# Bus 3, Iteration 25: Current time 2024-08-29 17:40:00, Current location ehvapt
# Assigning ride at index 66 to bus 3.
# Ride at index 66 arrives at: 2024-08-29 18:07:00
# Bus 3 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 18:07:00, new current location is ehvbst.
# Bus 3, Iteration 26: Current time 2024-08-29 18:07:00, Current location ehvbst
# Assigning ride at index 318 to bus 3.
# Ride at index 318 arrives at: 2024-08-29 18:28:00
# Ride ends at 2024-08-29 18:28:00, new current location is ehvapt.
# Bus 3, Iteration 27: Current time 2024-08-29 18:28:00, Current location ehvapt
# Assigning ride at index 153 to bus 3.
# Ride at index 153 arrives at: 2024-08-29 18:55:00
# Bus 3 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 18:55:00, new current location is ehvbst.
# Bus 3, Iteration 28: Current time 2024-08-29 18:55:00, Current location ehvbst
# Assigning ride at index 238 to bus 3.
# Ride at index 238 arrives at: 2024-08-29 19:20:00
# Ride ends at 2024-08-29 19:20:00, new current location is ehvapt.
# Bus 3, Iteration 29: Current time 2024-08-29 19:20:00, Current location ehvapt
# Assigning ride at index 74 to bus 3.
# Ride at index 74 arrives at: 2024-08-29 19:47:00
# Bus 3 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 19:47:00, new current location is ehvbst.
# Bus 3, Iteration 30: Current time 2024-08-29 19:47:00, Current location ehvbst
# Assigning ride at index 244 to bus 3.
# Ride at index 244 arrives at: 2024-08-29 20:58:00
# Ride ends at 2024-08-29 20:58:00, new current location is ehvapt.
# Bus 3, Iteration 31: Current time 2024-08-29 20:58:00, Current location ehvapt
# Assigning ride at index 79 to bus 3.
# Ride at index 79 arrives at: 2024-08-29 21:26:00
# Bus 3 has now arrived at 'ehvbst' 5 times.
# Bus 3 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 21:26:00, new current location is ehvbst.
# Bus 3, Iteration 32: Current time 2024-08-29 22:01:00, Current location ehvbst
# No more rides available for bus 3, terminating loop.
# Bus 4, Iteration 1: Current time 2024-08-29 05:03:00, Current location ehvgar
# Bus 4 moving to new start location ehvbst with travel time 4 minutes.
# Bus 4, Iteration 2: Current time 2024-08-29 05:07:00, Current location ehvbst
# Assigning ride at index 167 to bus 4.
# Ride at index 167 arrives at: 2024-08-29 07:07:00
# Ride ends at 2024-08-29 07:07:00, new current location is ehvapt.
# Bus 4, Iteration 3: Current time 2024-08-29 07:07:00, Current location ehvapt
# Assigning ride at index 87 to bus 4.
# Ride at index 87 arrives at: 2024-08-29 07:40:00
# Bus 4 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 07:40:00, new current location is ehvbst.
# Bus 4, Iteration 4: Current time 2024-08-29 07:40:00, Current location ehvbst
# Assigning ride at index 256 to bus 4.
# Ride at index 256 arrives at: 2024-08-29 08:12:00
# Ride ends at 2024-08-29 08:12:00, new current location is ehvapt.
# Bus 4, Iteration 5: Current time 2024-08-29 08:12:00, Current location ehvapt
# Assigning ride at index 91 to bus 4.
# Ride at index 91 arrives at: 2024-08-29 08:40:00
# Bus 4 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 08:40:00, new current location is ehvbst.
# Bus 4, Iteration 6: Current time 2024-08-29 08:40:00, Current location ehvbst
# Assigning ride at index 179 to bus 4.
# Ride at index 179 arrives at: 2024-08-29 09:10:00
# Ride ends at 2024-08-29 09:10:00, new current location is ehvapt.
# Bus 4, Iteration 7: Current time 2024-08-29 09:10:00, Current location ehvapt
# Assigning ride at index 15 to bus 4.
# Ride at index 15 arrives at: 2024-08-29 09:37:00
# Bus 4 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 09:37:00, new current location is ehvbst.
# Bus 4, Iteration 8: Current time 2024-08-29 09:37:00, Current location ehvbst
# Assigning ride at index 184 to bus 4.
# Ride at index 184 arrives at: 2024-08-29 10:00:00
# Ride ends at 2024-08-29 10:00:00, new current location is ehvapt.
# Bus 4, Iteration 9: Current time 2024-08-29 10:00:00, Current location ehvapt
# Assigning ride at index 102 to bus 4.
# Ride at index 102 arrives at: 2024-08-29 10:25:00
# Bus 4 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 10:25:00, new current location is ehvbst.
# Bus 4, Iteration 10: Current time 2024-08-29 10:25:00, Current location ehvbst
# Assigning ride at index 189 to bus 4.
# Ride at index 189 arrives at: 2024-08-29 10:50:00
# Ride ends at 2024-08-29 10:50:00, new current location is ehvapt.
# Bus 4, Iteration 11: Current time 2024-08-29 10:50:00, Current location ehvapt
# Assigning ride at index 25 to bus 4.
# Ride at index 25 arrives at: 2024-08-29 11:17:00
# Bus 4 has now arrived at 'ehvbst' 5 times.
# Bus 4 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 11:17:00, new current location is ehvbst.
# Bus 4, Iteration 12: Current time 2024-08-29 11:52:00, Current location ehvbst
# Assigning ride at index 281 to bus 4.
# Ride at index 281 arrives at: 2024-08-29 12:15:00
# Ride ends at 2024-08-29 12:15:00, new current location is ehvapt.
# Bus 4, Iteration 13: Current time 2024-08-29 12:15:00, Current location ehvapt
# Assigning ride at index 33 to bus 4.
# Ride at index 33 arrives at: 2024-08-29 12:37:00
# Bus 4 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 12:37:00, new current location is ehvbst.
# Bus 4, Iteration 14: Current time 2024-08-29 12:37:00, Current location ehvbst
# Assigning ride at index 202 to bus 4.
# Ride at index 202 arrives at: 2024-08-29 13:00:00
# Ride ends at 2024-08-29 13:00:00, new current location is ehvapt.
# Bus 4, Iteration 15: Current time 2024-08-29 13:00:00, Current location ehvapt
# Assigning ride at index 120 to bus 4.
# Ride at index 120 arrives at: 2024-08-29 13:25:00
# Bus 4 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 13:25:00, new current location is ehvbst.
# Bus 4, Iteration 16: Current time 2024-08-29 13:25:00, Current location ehvbst
# Assigning ride at index 207 to bus 4.
# Ride at index 207 arrives at: 2024-08-29 13:50:00
# Ride ends at 2024-08-29 13:50:00, new current location is ehvapt.
# Bus 4, Iteration 17: Current time 2024-08-29 13:50:00, Current location ehvapt
# Assigning ride at index 43 to bus 4.
# Ride at index 43 arrives at: 2024-08-29 14:17:00
# Bus 4 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 14:17:00, new current location is ehvbst.
# Bus 4, Iteration 18: Current time 2024-08-29 14:17:00, Current location ehvbst
# Assigning ride at index 212 to bus 4.
# Ride at index 212 arrives at: 2024-08-29 14:40:00
# Ride ends at 2024-08-29 14:40:00, new current location is ehvapt.
# Bus 4, Iteration 19: Current time 2024-08-29 14:40:00, Current location ehvapt
# Assigning ride at index 48 to bus 4.
# Ride at index 48 arrives at: 2024-08-29 15:07:00
# Bus 4 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 15:07:00, new current location is ehvbst.
# Bus 4, Iteration 20: Current time 2024-08-29 15:07:00, Current location ehvbst
# Assigning ride at index 217 to bus 4.
# Ride at index 217 arrives at: 2024-08-29 15:30:00
# Ride ends at 2024-08-29 15:30:00, new current location is ehvapt.
# Bus 4, Iteration 21: Current time 2024-08-29 15:30:00, Current location ehvapt
# Assigning ride at index 135 to bus 4.
# Ride at index 135 arrives at: 2024-08-29 15:55:00
# Bus 4 has now arrived at 'ehvbst' 5 times.
# Bus 4 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 15:55:00, new current location is ehvbst.
# Bus 4, Iteration 22: Current time 2024-08-29 16:30:00, Current location ehvbst
# Assigning ride at index 309 to bus 4.
# Ride at index 309 arrives at: 2024-08-29 16:57:00
# Ride ends at 2024-08-29 16:57:00, new current location is ehvapt.
# Bus 4, Iteration 23: Current time 2024-08-29 16:57:00, Current location ehvapt
# Assigning ride at index 143 to bus 4.
# Ride at index 143 arrives at: 2024-08-29 17:18:00
# Bus 4 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 17:18:00, new current location is ehvbst.
# Bus 4, Iteration 24: Current time 2024-08-29 17:18:00, Current location ehvbst
# Assigning ride at index 313 to bus 4.
# Ride at index 313 arrives at: 2024-08-29 17:42:00
# Ride ends at 2024-08-29 17:42:00, new current location is ehvapt.
# Bus 4, Iteration 25: Current time 2024-08-29 17:42:00, Current location ehvapt
# Assigning ride at index 148 to bus 4.
# Ride at index 148 arrives at: 2024-08-29 18:10:00
# Bus 4 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 18:10:00, new current location is ehvbst.
# Bus 4, Iteration 26: Current time 2024-08-29 18:10:00, Current location ehvbst
# Assigning ride at index 235 to bus 4.
# Ride at index 235 arrives at: 2024-08-29 18:35:00
# Ride ends at 2024-08-29 18:35:00, new current location is ehvapt.
# Bus 4, Iteration 27: Current time 2024-08-29 18:35:00, Current location ehvapt
# Assigning ride at index 71 to bus 4.
# Ride at index 71 arrives at: 2024-08-29 19:02:00
# Bus 4 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 19:02:00, new current location is ehvbst.
# Bus 4, Iteration 28: Current time 2024-08-29 19:02:00, Current location ehvbst
# Assigning ride at index 324 to bus 4.
# Ride at index 324 arrives at: 2024-08-29 19:28:00
# Ride ends at 2024-08-29 19:28:00, new current location is ehvapt.
# Bus 4, Iteration 29: Current time 2024-08-29 19:28:00, Current location ehvapt
# Assigning ride at index 159 to bus 4.
# Ride at index 159 arrives at: 2024-08-29 19:55:00
# Bus 4 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 19:55:00, new current location is ehvbst.
# Bus 4, Iteration 30: Current time 2024-08-29 19:55:00, Current location ehvbst
# Unable to find a valid next location for bus 4, terminating loop.
# Bus 5, Iteration 1: Current time 2024-08-29 05:03:00, Current location ehvgar
# Bus 5 moving to new start location ehvbst with travel time 4 minutes.
# Bus 5, Iteration 2: Current time 2024-08-29 05:07:00, Current location ehvbst
# Assigning ride at index 252 to bus 5.
# Ride at index 252 arrives at: 2024-08-29 07:13:00
# Ride ends at 2024-08-29 07:13:00, new current location is ehvapt.
# Bus 5, Iteration 3: Current time 2024-08-29 07:13:00, Current location ehvapt
# Assigning ride at index 88 to bus 5.
# Ride at index 88 arrives at: 2024-08-29 07:55:00
# Bus 5 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 07:55:00, new current location is ehvbst.
# Bus 5, Iteration 4: Current time 2024-08-29 07:55:00, Current location ehvbst
# Assigning ride at index 174 to bus 5.
# Ride at index 174 arrives at: 2024-08-29 08:20:00
# Ride ends at 2024-08-29 08:20:00, new current location is ehvapt.
# Bus 5, Iteration 5: Current time 2024-08-29 08:20:00, Current location ehvapt
# Assigning ride at index 10 to bus 5.
# Ride at index 10 arrives at: 2024-08-29 08:47:00
# Bus 5 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 08:47:00, new current location is ehvbst.
# Bus 5, Iteration 6: Current time 2024-08-29 08:47:00, Current location ehvbst
# Assigning ride at index 262 to bus 5.
# Ride at index 262 arrives at: 2024-08-29 09:12:00
# Ride ends at 2024-08-29 09:12:00, new current location is ehvapt.
# Bus 5, Iteration 7: Current time 2024-08-29 09:12:00, Current location ehvapt
# Assigning ride at index 97 to bus 5.
# Ride at index 97 arrives at: 2024-08-29 09:40:00
# Bus 5 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 09:40:00, new current location is ehvbst.
# Bus 5, Iteration 8: Current time 2024-08-29 09:40:00, Current location ehvbst
# Assigning ride at index 185 to bus 5.
# Ride at index 185 arrives at: 2024-08-29 10:10:00
# Ride ends at 2024-08-29 10:10:00, new current location is ehvapt.
# Bus 5, Iteration 9: Current time 2024-08-29 10:10:00, Current location ehvapt
# Assigning ride at index 21 to bus 5.
# Ride at index 21 arrives at: 2024-08-29 10:37:00
# Bus 5 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 10:37:00, new current location is ehvbst.
# Bus 5, Iteration 10: Current time 2024-08-29 10:37:00, Current location ehvbst
# Assigning ride at index 190 to bus 5.
# Ride at index 190 arrives at: 2024-08-29 11:00:00
# Ride ends at 2024-08-29 11:00:00, new current location is ehvapt.
# Bus 5, Iteration 11: Current time 2024-08-29 11:00:00, Current location ehvapt
# Assigning ride at index 108 to bus 5.
# Ride at index 108 arrives at: 2024-08-29 11:25:00
# Bus 5 has now arrived at 'ehvbst' 5 times.
# Bus 5 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 11:25:00, new current location is ehvbst.
# Bus 5, Iteration 12: Current time 2024-08-29 12:00:00, Current location ehvbst
# Assigning ride at index 282 to bus 5.
# Ride at index 282 arrives at: 2024-08-29 12:27:00
# Ride ends at 2024-08-29 12:27:00, new current location is ehvapt.
# Bus 5, Iteration 13: Current time 2024-08-29 12:27:00, Current location ehvapt
# Assigning ride at index 116 to bus 5.
# Ride at index 116 arrives at: 2024-08-29 12:48:00
# Bus 5 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 12:48:00, new current location is ehvbst.
# Bus 5, Iteration 14: Current time 2024-08-29 12:48:00, Current location ehvbst
# Assigning ride at index 286 to bus 5.
# Ride at index 286 arrives at: 2024-08-29 13:12:00
# Ride ends at 2024-08-29 13:12:00, new current location is ehvapt.
# Bus 5, Iteration 15: Current time 2024-08-29 13:12:00, Current location ehvapt
# Assigning ride at index 121 to bus 5.
# Ride at index 121 arrives at: 2024-08-29 13:40:00
# Bus 5 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 13:40:00, new current location is ehvbst.
# Bus 5, Iteration 16: Current time 2024-08-29 13:40:00, Current location ehvbst
# Assigning ride at index 209 to bus 5.
# Ride at index 209 arrives at: 2024-08-29 14:10:00
# Ride ends at 2024-08-29 14:10:00, new current location is ehvapt.
# Bus 5, Iteration 17: Current time 2024-08-29 14:10:00, Current location ehvapt
# Assigning ride at index 45 to bus 5.
# Ride at index 45 arrives at: 2024-08-29 14:37:00
# Bus 5 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 14:37:00, new current location is ehvbst.
# Bus 5, Iteration 18: Current time 2024-08-29 14:37:00, Current location ehvbst
# Assigning ride at index 214 to bus 5.
# Ride at index 214 arrives at: 2024-08-29 15:00:00
# Ride ends at 2024-08-29 15:00:00, new current location is ehvapt.
# Bus 5, Iteration 19: Current time 2024-08-29 15:00:00, Current location ehvapt
# Assigning ride at index 132 to bus 5.
# Ride at index 132 arrives at: 2024-08-29 15:25:00
# Bus 5 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 15:25:00, new current location is ehvbst.
# Bus 5, Iteration 20: Current time 2024-08-29 15:25:00, Current location ehvbst
# Assigning ride at index 219 to bus 5.
# Ride at index 219 arrives at: 2024-08-29 15:50:00
# Ride ends at 2024-08-29 15:50:00, new current location is ehvapt.
# Bus 5, Iteration 21: Current time 2024-08-29 15:50:00, Current location ehvapt
# Assigning ride at index 55 to bus 5.
# Ride at index 55 arrives at: 2024-08-29 16:17:00
# Bus 5 has now arrived at 'ehvbst' 5 times.
# Bus 5 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 16:17:00, new current location is ehvbst.
# Bus 5, Iteration 22: Current time 2024-08-29 16:52:00, Current location ehvbst
# Assigning ride at index 311 to bus 5.
# Ride at index 311 arrives at: 2024-08-29 17:15:00
# Ride ends at 2024-08-29 17:15:00, new current location is ehvapt.
# Bus 5, Iteration 23: Current time 2024-08-29 17:15:00, Current location ehvapt
# Assigning ride at index 63 to bus 5.
# Ride at index 63 arrives at: 2024-08-29 17:37:00
# Bus 5 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 17:37:00, new current location is ehvbst.
# Bus 5, Iteration 24: Current time 2024-08-29 17:37:00, Current location ehvbst
# Assigning ride at index 232 to bus 5.
# Ride at index 232 arrives at: 2024-08-29 18:00:00
# Ride ends at 2024-08-29 18:00:00, new current location is ehvapt.
# Bus 5, Iteration 25: Current time 2024-08-29 18:00:00, Current location ehvapt
# Assigning ride at index 150 to bus 5.
# Ride at index 150 arrives at: 2024-08-29 18:25:00
# Bus 5 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 18:25:00, new current location is ehvbst.
# Bus 5, Iteration 26: Current time 2024-08-29 18:25:00, Current location ehvbst
# Assigning ride at index 236 to bus 5.
# Ride at index 236 arrives at: 2024-08-29 18:50:00
# Ride ends at 2024-08-29 18:50:00, new current location is ehvapt.
# Bus 5, Iteration 27: Current time 2024-08-29 18:50:00, Current location ehvapt
# Assigning ride at index 72 to bus 5.
# Ride at index 72 arrives at: 2024-08-29 19:17:00
# Bus 5 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 19:17:00, new current location is ehvbst.
# Bus 5, Iteration 28: Current time 2024-08-29 19:17:00, Current location ehvbst
# Assigning ride at index 325 to bus 5.
# Ride at index 325 arrives at: 2024-08-29 19:43:00
# Ride ends at 2024-08-29 19:43:00, new current location is ehvapt.
# Bus 5, Iteration 29: Current time 2024-08-29 19:43:00, Current location ehvapt
# Assigning ride at index 160 to bus 5.
# Ride at index 160 arrives at: 2024-08-29 20:10:00
# Bus 5 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 20:10:00, new current location is ehvbst.
# Bus 5, Iteration 30: Current time 2024-08-29 20:10:00, Current location ehvbst
# Unable to find a valid next location for bus 5, terminating loop.
# Bus 6, Iteration 1: Current time 2024-08-29 05:03:00, Current location ehvgar
# Bus 6 moving to new start location ehvbst with travel time 4 minutes.
# Bus 6, Iteration 2: Current time 2024-08-29 05:07:00, Current location ehvbst
# Assigning ride at index 253 to bus 6.
# Ride at index 253 arrives at: 2024-08-29 07:27:00
# Ride ends at 2024-08-29 07:27:00, new current location is ehvapt.
# Bus 6, Iteration 3: Current time 2024-08-29 07:27:00, Current location ehvapt
# Assigning ride at index 5 to bus 6.
# Ride at index 5 arrives at: 2024-08-29 07:57:00
# Bus 6 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 07:57:00, new current location is ehvbst.
# Bus 6, Iteration 4: Current time 2024-08-29 07:57:00, Current location ehvbst
# Assigning ride at index 258 to bus 6.
# Ride at index 258 arrives at: 2024-08-29 08:27:00
# Ride ends at 2024-08-29 08:27:00, new current location is ehvapt.
# Bus 6, Iteration 5: Current time 2024-08-29 08:27:00, Current location ehvapt
# Assigning ride at index 92 to bus 6.
# Ride at index 92 arrives at: 2024-08-29 08:48:00
# Bus 6 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 08:48:00, new current location is ehvbst.
# Bus 6, Iteration 6: Current time 2024-08-29 08:48:00, Current location ehvbst
# Assigning ride at index 263 to bus 6.
# Ride at index 263 arrives at: 2024-08-29 09:15:00
# Ride ends at 2024-08-29 09:15:00, new current location is ehvapt.
# Bus 6, Iteration 7: Current time 2024-08-29 09:15:00, Current location ehvapt
# Assigning ride at index 98 to bus 6.
# Ride at index 98 arrives at: 2024-08-29 09:48:00
# Bus 6 has now arrived at 'ehvbst' 3 times.
# Ride ends at 2024-08-29 09:48:00, new current location is ehvbst.
# Bus 6, Iteration 8: Current time 2024-08-29 09:48:00, Current location ehvbst
# Assigning ride at index 268 to bus 6.
# Ride at index 268 arrives at: 2024-08-29 10:12:00
# Ride ends at 2024-08-29 10:12:00, new current location is ehvapt.
# Bus 6, Iteration 9: Current time 2024-08-29 10:12:00, Current location ehvapt
# Assigning ride at index 103 to bus 6.
# Ride at index 103 arrives at: 2024-08-29 10:40:00
# Bus 6 has now arrived at 'ehvbst' 4 times.
# Ride ends at 2024-08-29 10:40:00, new current location is ehvbst.
# Bus 6, Iteration 10: Current time 2024-08-29 10:40:00, Current location ehvbst
# Assigning ride at index 191 to bus 6.
# Ride at index 191 arrives at: 2024-08-29 11:10:00
# Ride ends at 2024-08-29 11:10:00, new current location is ehvapt.
# Bus 6, Iteration 11: Current time 2024-08-29 11:10:00, Current location ehvapt
# Assigning ride at index 109 to bus 6.
# Ride at index 109 arrives at: 2024-08-29 11:40:00
# Bus 6 has now arrived at 'ehvbst' 5 times.
# Bus 6 taking a break for 1 hour at 'ehvbst'.
# Ride ends at 2024-08-29 11:40:00, new current location is ehvbst.
# Bus 6, Iteration 12: Current time 2024-08-29 12:15:00, Current location ehvbst
# Assigning ride at index 283 to bus 6.
# Ride at index 283 arrives at: 2024-08-29 12:42:00
# Ride ends at 2024-08-29 12:42:00, new current location is ehvapt.
# Bus 6, Iteration 13: Current time 2024-08-29 12:42:00, Current location ehvapt
# Assigning ride at index 118 to bus 6.
# Ride at index 118 arrives at: 2024-08-29 13:10:00
# Bus 6 has now arrived at 'ehvbst' 1 times.
# Ride ends at 2024-08-29 13:10:00, new current location is ehvbst.
# Bus 6, Iteration 14: Current time 2024-08-29 13:10:00, Current location ehvbst
# Assigning ride at index 289 to bus 6.
# Ride at index 289 arrives at: 2024-08-29 13:42:00
# Ride ends at 2024-08-29 13:42:00, new current location is ehvapt.
# Bus 6, Iteration 15: Current time 2024-08-29 13:42:00, Current location ehvapt
# Assigning ride at index 124 to bus 6.
# Ride at index 124 arrives at: 2024-08-29 14:10:00
# Bus 6 has now arrived at 'ehvbst' 2 times.
# Ride ends at 2024-08-29 14:10:00, new current location is ehvbst.
# Bus 6, Iteration 16: Current time 2024-08-29 14:10:00, Current location ehvbst
# ...
# Idle added for Omloop 4 from 2024-08-29 18:10:00 to 2024-08-29 18:14:00.
# Idle added for Omloop 4 from 2024-08-29 18:35:00 to 2024-08-29 18:41:00.
# Idle added for Omloop 4 from 2024-08-29 19:02:00 to 2024-08-29 19:07:00.
# Idle added for Omloop 4 from 2024-08-29 19:28:00 to 2024-08-29 19:34:00.
# Idle added for Omloop 5 from 2024-08-29 07:13:00 to 2024-08-29 07:34:00.
# Idle added for Omloop 5 from 2024-08-29 07:55:00 to 2024-08-29 07:59:00.
# Idle added for Omloop 5 from 2024-08-29 08:20:00 to 2024-08-29 08:26:00.
# Idle added for Omloop 5 from 2024-08-29 08:47:00 to 2024-08-29 08:51:00.
# Idle added for Omloop 5 from 2024-08-29 09:12:00 to 2024-08-29 09:19:00.
# Idle added for Omloop 5 from 2024-08-29 09:40:00 to 2024-08-29 09:49:00.
# Idle added for Omloop 5 from 2024-08-29 10:10:00 to 2024-08-29 10:16:00.
# Idle added for Omloop 5 from 2024-08-29 10:37:00 to 2024-08-29 10:39:00.
# Idle added for Omloop 5 from 2024-08-29 11:00:00 to 2024-08-29 11:04:00.
# Idle added for Omloop 5 from 2024-08-29 11:58:00 to 2024-08-29 12:06:00.
# Idle added for Omloop 5 from 2024-08-29 12:48:00 to 2024-08-29 12:51:00.
# Idle added for Omloop 5 from 2024-08-29 13:12:00 to 2024-08-29 13:19:00.
# Idle added for Omloop 5 from 2024-08-29 13:40:00 to 2024-08-29 13:49:00.
# Idle added for Omloop 5 from 2024-08-29 14:10:00 to 2024-08-29 14:16:00.
# Idle added for Omloop 5 from 2024-08-29 14:37:00 to 2024-08-29 14:39:00.
# Idle added for Omloop 5 from 2024-08-29 15:00:00 to 2024-08-29 15:04:00.
# Idle added for Omloop 5 from 2024-08-29 15:25:00 to 2024-08-29 15:29:00.
# Idle added for Omloop 5 from 2024-08-29 15:50:00 to 2024-08-29 15:56:00.
# Idle added for Omloop 5 from 2024-08-29 16:50:00 to 2024-08-29 16:54:00.
# Idle added for Omloop 5 from 2024-08-29 17:15:00 to 2024-08-29 17:16:00.
# Idle added for Omloop 5 from 2024-08-29 17:37:00 to 2024-08-29 17:39:00.
# Idle added for Omloop 5 from 2024-08-29 18:00:00 to 2024-08-29 18:04:00.
# Idle added for Omloop 5 from 2024-08-29 18:25:00 to 2024-08-29 18:29:00.
# Idle added for Omloop 5 from 2024-08-29 18:50:00 to 2024-08-29 18:56:00.
# Idle added for Omloop 5 from 2024-08-29 19:17:00 to 2024-08-29 19:22:00.
# Idle added for Omloop 5 from 2024-08-29 19:43:00 to 2024-08-29 19:49:00.
# Idle added for Omloop 6 from 2024-08-29 07:27:00 to 2024-08-29 07:36:00.
# Idle added for Omloop 6 from 2024-08-29 07:57:00 to 2024-08-29 08:06:00.
# Idle added for Omloop 6 from 2024-08-29 08:48:00 to 2024-08-29 08:54:00.
# Idle added for Omloop 6 from 2024-08-29 09:15:00 to 2024-08-29 09:27:00.
# Idle added for Omloop 6 from 2024-08-29 09:48:00 to 2024-08-29 09:51:00.
# Idle added for Omloop 6 from 2024-08-29 10:12:00 to 2024-08-29 10:19:00.
# Idle added for Omloop 6 from 2024-08-29 10:40:00 to 2024-08-29 10:49:00.
# Idle added for Omloop 6 from 2024-08-29 11:10:00 to 2024-08-29 11:19:00.
# Idle added for Omloop 6 from 2024-08-29 12:13:00 to 2024-08-29 12:21:00.
# Idle added for Omloop 6 from 2024-08-29 12:42:00 to 2024-08-29 12:49:00.
# Idle added for Omloop 6 from 2024-08-29 13:10:00 to 2024-08-29 13:21:00.
# Idle added for Omloop 6 from 2024-08-29 13:42:00 to 2024-08-29 13:49:00.
# Idle added for Omloop 6 from 2024-08-29 14:10:00 to 2024-08-29 14:21:00.
# Idle added for Omloop 6 from 2024-08-29 14:42:00 to 2024-08-29 14:49:00.
# Idle added for Omloop 6 from 2024-08-29 15:10:00 to 2024-08-29 15:19:00.
# Idle added for Omloop 6 from 2024-08-29 15:40:00 to 2024-08-29 15:46:00.
# Idle added for Omloop 6 from 2024-08-29 16:07:00 to 2024-08-29 16:09:00.
# Idle added for Omloop 6 from 2024-08-29 16:30:00 to 2024-08-29 16:34:00.
# Idle added for Omloop 6 from 2024-08-29 17:28:00 to 2024-08-29 17:36:00.
# Idle added for Omloop 6 from 2024-08-29 18:18:00 to 2024-08-29 18:24:00.
# Idle added for Omloop 6 from 2024-08-29 18:45:00 to 2024-08-29 18:57:00.
# Idle added for Omloop 6 from 2024-08-29 19:18:00 to 2024-08-29 19:29:00.
# Idle added for Omloop 6 from 2024-08-29 19:50:00 to 2024-08-29 19:56:00.
# Idle added for Omloop 7 from 2024-08-29 07:30:00 to 2024-08-29 07:49:00.
# Idle added for Omloop 7 from 2024-08-29 08:10:00 to 2024-08-29 08:19:00.
# Idle added for Omloop 7 from 2024-08-29 08:40:00 to 2024-08-29 08:46:00.
# Idle added for Omloop 7 from 2024-08-29 09:07:00 to 2024-08-29 09:09:00.
# Idle added for Omloop 7 from 2024-08-29 09:30:00 to 2024-08-29 09:34:00.
# Idle added for Omloop 7 from 2024-08-29 09:55:00 to 2024-08-29 09:59:00.
# Idle added for Omloop 7 from 2024-08-29 10:20:00 to 2024-08-29 10:26:00.
# Idle added for Omloop 7 from 2024-08-29 10:47:00 to 2024-08-29 10:51:00.
# Idle added for Omloop 7 from 2024-08-29 11:12:00 to 2024-08-29 11:26:00.
# Idle added for Omloop 7 from 2024-08-29 12:20:00 to 2024-08-29 12:24:00.
# Idle added for Omloop 7 from 2024-08-29 12:45:00 to 2024-08-29 12:57:00.
# Idle added for Omloop 7 from 2024-08-29 13:18:00 to 2024-08-29 13:24:00.
# Idle added for Omloop 7 from 2024-08-29 13:45:00 to 2024-08-29 13:57:00.
# Idle added for Omloop 7 from 2024-08-29 14:18:00 to 2024-08-29 14:24:00.
# Idle added for Omloop 7 from 2024-08-29 14:45:00 to 2024-08-29 14:56:00.
# Idle added for Omloop 7 from 2024-08-29 15:17:00 to 2024-08-29 15:21:00.
# Idle added for Omloop 7 from 2024-08-29 15:42:00 to 2024-08-29 15:49:00.
# Idle added for Omloop 7 from 2024-08-29 16:10:00 to 2024-08-29 16:24:00.
# Idle added for Omloop 7 from 2024-08-29 16:45:00 to 2024-08-29 16:56:00.
# Idle added for Omloop 7 from 2024-08-29 17:50:00 to 2024-08-29 17:54:00.
# Idle added for Omloop 7 from 2024-08-29 18:15:00 to 2024-08-29 18:16:00.
# Idle added for Omloop 7 from 2024-08-29 18:58:00 to 2024-08-29 19:04:00.
# Idle added for Omloop 7 from 2024-08-29 19:25:00 to 2024-08-29 19:37:00.
# Idle added for Omloop 7 from 2024-08-29 19:58:00 to 2024-08-29 20:04:00.
# Idle added for Omloop 8 from 2024-08-29 07:42:00 to 2024-08-29 07:56:00.
# Idle added for Omloop 8 from 2024-08-29 08:17:00 to 2024-08-29 08:21:00.
# Idle added for Omloop 8 from 2024-08-29 08:42:00 to 2024-08-29 08:49:00.
# Idle added for Omloop 8 from 2024-08-29 09:10:00 to 2024-08-29 09:21:00.
# Idle added for Omloop 8 from 2024-08-29 09:42:00 to 2024-08-29 09:49:00.
# Idle added for Omloop 8 from 2024-08-29 10:10:00 to 2024-08-29 10:19:00.
# Idle added for Omloop 8 from 2024-08-29 10:40:00 to 2024-08-29 10:49:00.
# Idle added for Omloop 8 from 2024-08-29 11:10:00 to 2024-08-29 11:19:00.
# Idle added for Omloop 8 from 2024-08-29 11:40:00 to 2024-08-29 11:46:00.
# Idle added for Omloop 8 from 2024-08-29 12:40:00 to 2024-08-29 12:54:00.
# Idle added for Omloop 8 from 2024-08-29 13:15:00 to 2024-08-29 13:26:00.
# Idle added for Omloop 8 from 2024-08-29 13:47:00 to 2024-08-29 13:51:00.
# Idle added for Omloop 8 from 2024-08-29 14:12:00 to 2024-08-29 14:19:00.
# Idle added for Omloop 8 from 2024-08-29 14:40:00 to 2024-08-29 14:51:00.
# Idle added for Omloop 8 from 2024-08-29 15:12:00 to 2024-08-29 15:19:00.
# Idle added for Omloop 8 from 2024-08-29 15:40:00 to 2024-08-29 15:51:00.
# Idle added for Omloop 8 from 2024-08-29 16:12:00 to 2024-08-29 16:19:00.
# Idle added for Omloop 8 from 2024-08-29 16:40:00 to 2024-08-29 16:49:00.
# Idle added for Omloop 8 from 2024-08-29 17:10:00 to 2024-08-29 17:19:00.
# Idle added for Omloop 8 from 2024-08-29 18:13:00 to 2024-08-29 18:44:00.
# Idle added for Omloop 8 from 2024-08-29 19:05:00 to 2024-08-29 19:11:00.
# Idle added for Omloop 8 from 2024-08-29 19:32:00 to 2024-08-29 19:44:00.
# Idle added for Omloop 8 from 2024-08-29 20:05:00 to 2024-08-29 20:11:00.
# Idle added for Omloop 9 from 2024-08-29 07:50:00 to 2024-08-29 08:06:00.
# Idle added for Omloop 9 from 2024-08-29 08:27:00 to 2024-08-29 08:36:00.
# Idle added for Omloop 9 from 2024-08-29 09:18:00 to 2024-08-29 09:24:00.
# Idle added for Omloop 9 from 2024-08-29 09:45:00 to 2024-08-29 09:57:00.
# Idle added for Omloop 9 from 2024-08-29 10:18:00 to 2024-08-29 10:21:00.
# Idle added for Omloop 9 from 2024-08-29 10:42:00 to 2024-08-29 10:57:00.
# Idle added for Omloop 9 from 2024-08-29 11:18:00 to 2024-08-29 11:21:00.
# Idle added for Omloop 9 from 2024-08-29 11:42:00 to 2024-08-29 11:49:00.
# Idle added for Omloop 9 from 2024-08-29 12:43:00 to 2024-08-29 12:59:00.
# Idle added for Omloop 9 from 2024-08-29 13:20:00 to 2024-08-29 13:27:00.
# Idle added for Omloop 9 from 2024-08-29 13:48:00 to 2024-08-29 13:54:00.
# Idle added for Omloop 9 from 2024-08-29 14:15:00 to 2024-08-29 14:27:00.
# Idle added for Omloop 9 from 2024-08-29 14:48:00 to 2024-08-29 14:54:00.
# Idle added for Omloop 9 from 2024-08-29 15:15:00 to 2024-08-29 15:26:00.
# Idle added for Omloop 9 from 2024-08-29 15:47:00 to 2024-08-29 15:54:00.
# Idle added for Omloop 9 from 2024-08-29 16:15:00 to 2024-08-29 16:26:00.
# Idle added for Omloop 9 from 2024-08-29 16:47:00 to 2024-08-29 16:51:00.
# Idle added for Omloop 9 from 2024-08-29 17:12:00 to 2024-08-29 17:26:00.
# Idle added for Omloop 9 from 2024-08-29 18:20:00 to 2024-08-29 18:54:00.
# Idle added for Omloop 9 from 2024-08-29 19:15:00 to 2024-08-29 19:27:00.
# Idle added for Omloop 10 from 2024-08-29 08:33:00 to 2024-08-29 08:36:00.
# Idle added for Omloop 10 from 2024-08-29 08:57:00 to 2024-08-29 09:06:00.
# Idle added for Omloop 10 from 2024-08-29 09:27:00 to 2024-08-29 09:36:00.
# Idle added for Omloop 10 from 2024-08-29 09:57:00 to 2024-08-29 10:06:00.
# Idle added for Omloop 10 from 2024-08-29 10:48:00 to 2024-08-29 10:59:00.
# Idle added for Omloop 10 from 2024-08-29 11:20:00 to 2024-08-29 11:27:00.
# Idle added for Omloop 10 from 2024-08-29 11:48:00 to 2024-08-29 11:49:00.
# Idle added for Omloop 10 from 2024-08-29 12:10:00 to 2024-08-29 12:19:00.
# Idle added for Omloop 10 from 2024-08-29 13:13:00 to 2024-08-29 13:36:00.
# Idle added for Omloop 10 from 2024-08-29 13:57:00 to 2024-08-29 14:06:00.
# Idle added for Omloop 10 from 2024-08-29 14:27:00 to 2024-08-29 14:29:00.
# Idle added for Omloop 10 from 2024-08-29 14:50:00 to 2024-08-29 14:57:00.
# Idle added for Omloop 10 from 2024-08-29 15:18:00 to 2024-08-29 15:24:00.
# Idle added for Omloop 10 from 2024-08-29 15:45:00 to 2024-08-29 16:04:00.
# Idle added for Omloop 10 from 2024-08-29 16:25:00 to 2024-08-29 16:29:00.
# Idle added for Omloop 10 from 2024-08-29 16:50:00 to 2024-08-29 17:06:00.
# Idle added for Omloop 10 from 2024-08-29 17:27:00 to 2024-08-29 17:49:00.
# Idle added for Omloop 10 from 2024-08-29 18:10:00 to 2024-08-29 18:19:00.
# Idle added for Omloop 10 from 2024-08-29 19:13:00 to 2024-08-29 19:41:00.
# Idle added for Omloop 11 from 2024-08-29 08:48:00 to 2024-08-29 09:06:00.
# Idle added for Omloop 11 from 2024-08-29 09:27:00 to 2024-08-29 09:36:00.
# Idle added for Omloop 11 from 2024-08-29 09:57:00 to 2024-08-29 10:06:00.
# Idle added for Omloop 11 from 2024-08-29 10:27:00 to 2024-08-29 10:36:00.
# Idle added for Omloop 11 from 2024-08-29 10:57:00 to 2024-08-29 11:06:00.
# Idle added for Omloop 11 from 2024-08-29 11:27:00 to 2024-08-29 11:29:00.
# Idle added for Omloop 11 from 2024-08-29 11:50:00 to 2024-08-29 11:56:00.
# Idle added for Omloop 11 from 2024-08-29 12:17:00 to 2024-08-29 12:36:00.
# Idle added for Omloop 11 from 2024-08-29 12:57:00 to 2024-08-29 13:06:00.
# Idle added for Omloop 11 from 2024-08-29 14:00:00 to 2024-08-29 14:06:00.
# Idle added for Omloop 11 from 2024-08-29 14:27:00 to 2024-08-29 14:36:00.
# Idle added for Omloop 11 from 2024-08-29 14:57:00 to 2024-08-29 14:59:00.
# Idle added for Omloop 11 from 2024-08-29 15:20:00 to 2024-08-29 15:36:00.
# Idle added for Omloop 11 from 2024-08-29 15:57:00 to 2024-08-29 15:59:00.
# Idle added for Omloop 11 from 2024-08-29 16:20:00 to 2024-08-29 16:27:00.
# Idle added for Omloop 11 from 2024-08-29 16:48:00 to 2024-08-29 16:59:00.
# Idle added for Omloop 11 from 2024-08-29 17:20:00 to 2024-08-29 17:27:00.
# Idle added for Omloop 11 from 2024-08-29 17:48:00 to 2024-08-29 17:51:00.
# Idle added for Omloop 11 from 2024-08-29 18:12:00 to 2024-08-29 18:27:00.
# Idle added for Omloop 12 from 2024-08-29 09:18:00 to 2024-08-29 10:36:00.
# Idle added for Omloop 12 from 2024-08-29 10:57:00 to 2024-08-29 11:06:00.
# Idle added for Omloop 12 from 2024-08-29 11:27:00 to 2024-08-29 11:36:00.
# Idle added for Omloop 12 from 2024-08-29 11:57:00 to 2024-08-29 12:09:00.
# Idle added for Omloop 12 from 2024-08-29 12:30:00 to 2024-08-29 12:34:00.
# Idle added for Omloop 12 from 2024-08-29 12:55:00 to 2024-08-29 13:06:00.
# Idle added for Omloop 12 from 2024-08-29 13:27:00 to 2024-08-29 13:36:00.
# Idle added for Omloop 12 from 2024-08-29 14:30:00 to 2024-08-29 14:36:00.
# Idle added for Omloop 12 from 2024-08-29 14:57:00 to 2024-08-29 15:06:00.
# Idle added for Omloop 12 from 2024-08-29 16:00:00 to 2024-08-29 16:06:00.
# Idle added for Omloop 12 from 2024-08-29 16:27:00 to 2024-08-29 16:36:00.
# Idle added for Omloop 12 from 2024-08-29 16:57:00 to 2024-08-29 17:06:00.
# Idle added for Omloop 12 from 2024-08-29 17:27:00 to 2024-08-29 17:36:00.
# Idle added for Omloop 12 from 2024-08-29 18:30:00 to 2024-08-29 19:14:00.
# Idle added for Omloop 13 from 2024-08-29 10:48:00 to 2024-08-29 12:06:00.
# Idle added for Omloop 13 from 2024-08-29 13:00:00 to 2024-08-29 15:39:00.
# Idle added for Omloop 13 from 2024-08-29 16:00:00 to 2024-08-29 16:06:00.
# Idle added for Omloop 13 from 2024-08-29 17:00:00 to 2024-08-29 17:24:00.
# Idle added for Omloop 13 from 2024-08-29 17:45:00 to 2024-08-29 18:06:00.
# Idle added for Omloop 14 from 2024-08-29 12:18:00 to 2024-08-29 12:36:00.
#    startlocatie eindlocatie vertrektijd buslijn    vertrek_datetime  \
# 0        ehvbst      ehvapt       05:07     401 2024-08-29 05:07:00
# 1        ehvapt   ehvgarage        None    None 2024-08-29 05:28:00
# 2     ehvgarage   ehvgarage        None    None 2024-08-29 05:32:00
# 3     ehvgarage      ehvapt        None    None 2024-08-29 05:57:00
# 4        ehvapt      ehvapt         NaN         2024-08-29 06:01:00
# ..          ...         ...         ...     ...                 ...
# 85       ehvapt      ehvbst       23:35     401 2024-08-29 23:35:00
# 86       ehvbst      ehvbst         NaN         2024-08-29 23:56:00
# 87       ehvbst      ehvapt       00:09     401 2024-08-30 00:09:00
# 88       ehvapt      ehvapt         NaN         2024-08-30 00:30:00
# 89       ehvapt      ehvbst       00:31     401 2024-08-30 00:31:00
#
#      aankomst_datetime  Omloop         code_omloop    activiteit  \
# 0  2024-08-29 05:28:00       1   ehvbst_ehvapt_401     dienstrit
# 1  2024-08-29 05:32:00       1                None  materiaalrit
# 2  2024-08-29 05:57:00       1                None       opladen
# 3  2024-08-29 06:01:00       1                None  materiaalrit
# 4  2024-08-29 06:04:00       1  ehvapt_ehvapt_Idle          idle
# ..                 ...     ...                 ...           ...
# 85 2024-08-29 23:56:00       1   ehvapt_ehvbst_401     dienstrit
# 86 2024-08-30 00:09:00       1  ehvbst_ehvbst_Idle          idle
# 87 2024-08-30 00:30:00       1   ehvbst_ehvapt_401     dienstrit
# 88 2024-08-30 00:31:00       1  ehvapt_ehvapt_Idle          idle
# 89 2024-08-30 00:52:00       1   ehvapt_ehvbst_401     dienstrit
#
#     afstand in km  Batterijgebruik       code_afstand  afstand in meters  \
# 0           9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 1             NaN           0.2000               None                NaN
# 2             NaN         -11.0036               None                NaN
# 3             NaN           0.2000               None                NaN
# 4           0.000           0.0100                NaN                0.0
# ..            ...              ...                ...                ...
# 85          9.050          10.8600  ehvapt_ehvbst_401             9050.0
# 86          0.000           0.0100                NaN                0.0
# 87          9.003          10.8036  ehvbst_ehvapt_401             9003.0
# 88          0.000           0.0100                NaN                0.0
# 89          9.050          10.8600  ehvapt_ehvbst_401             9050.0
#
#     SOC_start  SOC_eind
# 0    243.0000  232.1964
# 1    232.1964  231.9964
# 2    231.9964  243.0000
# 3    243.0000  242.8000
# 4         NaN       NaN
# ..        ...       ...
# 85   167.0056  156.1456
# 86        NaN       NaN
# 87   156.1456  145.3420
# 88        NaN       NaN
# 89   145.3420  134.4820
#
# [90 rows x 15 columns]

# %%
df_adjusted = df_adjusted.rename(columns={'vertrek_datetime': 'starttijd'})
df_adjusted = df_adjusted.rename(columns={'aankomst_datetime': 'eindtijd'})
df_adjusted = df_adjusted.rename(columns={'Batterijgebruik': 'energieverbruik'})
df_adjusted = df_adjusted.rename(columns={'Omloop': 'omloop nummer'})
df_adjusted['starttijd datum'] = df_adjusted['starttijd']
df_adjusted['eindtijd datum'] = df_adjusted['eindtijd']

df_adjusted_controle = df_adjusted[['startlocatie','eindlocatie','starttijd','eindtijd','activiteit','buslijn','energieverbruik','starttijd datum','eindtijd datum','omloop nummer']]

# %%
# Sorteer de DataFrame op 'vertrektijd'
df_dienstregeling_sorted = df_dienstregeling.sort_values(by='vertrektijd')

from datetime import datetime
df_dienstregeling_sorted['vertrektijd'] = df_dienstregeling_sorted['vertrektijd'].apply(
    lambda x: datetime.strptime(x, '%H:%M').time() if isinstance(x, str) else pd.NaT
)

# %%
import pandas as pd

# Zorg ervoor dat jouw dataframes zijn ingeladen
df_omloopplanning = df_adjusted_controle.copy()
df_dienstregeling = df_dienstregeling_sorted.copy()

# Controleer en converteer naar tijdformaat indien nodig
def ensure_time_format(column):
    # Alleen converteren als het van het type 'object' is
    if column.dtype == 'object':
        try:
            return pd.to_datetime(column).dt.time
        except Exception as e:
            print("Error converting column:", e)
            return column
    else:
        # Neem aan dat het al een timestamp is of van het juiste type
        try:
            return column.dt.time
        except AttributeError:
            # Als het al een datetime.time is, doe er niets mee
            return column

df_omloopplanning['starttijd'] = ensure_time_format(df_omloopplanning['starttijd'])
df_dienstregeling['vertrektijd'] = ensure_time_format(df_dienstregeling['vertrektijd'])

# Functie om rijen te vergelijken
def check_match(row):
    matches = df_dienstregeling[
        (df_dienstregeling['startlocatie'] == row['startlocatie']) &
        (df_dienstregeling['eindlocatie'] == row['eindlocatie']) &
        (df_dienstregeling['vertrektijd'] == row['starttijd'])
    ]
    return not matches.empty

# Nieuwe kolom creëren met True/False
df_omloopplanning['match'] = df_omloopplanning.apply(check_match, axis=1)

#display(df_omloopplanning)
# Out:
# Error converting column: <class 'datetime.time'> is not convertible to datetime, at position 0

# %%
# Tel aantal rijen waarbij activiteit == dienstrit en tel aantal rijen waarbij match == True in df_omloopplanning. Als dat verschil 0 is dan klopt het

dienstrit_count = df_omloopplanning[df_omloopplanning['activiteit'] == 'dienstrit'].shape[0]
match_true_count = df_omloopplanning[df_omloopplanning['match'] == True].shape[0]

if dienstrit_count == match_true_count:
  print("Het klopt: Aantal rijen met activiteit 'dienstrit' is gelijk aan aantal rijen met match 'True'")
else:
  print("Het klopt niet: Aantal rijen met activiteit 'dienstrit' is niet gelijk aan aantal rijen met match 'True'")
  print(f"Aantal dienstrit: {dienstrit_count}")
  print(f"Aantal match True: {match_true_count}")
# Out:
# Het klopt: Aantal rijen met activiteit 'dienstrit' is gelijk aan aantal rijen met match 'True'

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.patches import Patch
import pandas as pd
import numpy as np

df = df_omloopplanning
# Convert starttijd and eindtijd to datetime for proper plotting
df['starttijd datum'] = pd.to_datetime(df['starttijd datum'])
df['eindtijd datum'] = pd.to_datetime(df['eindtijd datum'])

# Assign a color to each unique activity
df['actieviteitBuslijn'] = df['activiteit'] + ' ' + df['buslijn'].fillna(' ').astype(str)
activities = df['actieviteitBuslijn'].unique()

# Use the updated method to get the colormap
cmap = plt.colormaps.get_cmap('turbo')
colors = [cmap(i / len(activities)) for i in range(len(activities))]

color_dict = {activity: colors[i] for i, activity in enumerate(activities)}

# Create the Gantt chart
fig, ax = plt.subplots(figsize=(18, 9))

for idx, row in df.iterrows():
    ax.barh(row['omloop nummer'], 
            row['eindtijd datum'] - row['starttijd datum'], 
            left=row['starttijd datum'], 
            color=color_dict[row['actieviteitBuslijn']],
            edgecolor='black')

# Format x-axis for time
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))


# Format Y-axis for jumps of one
ax.set_yticks(np.arange(0, 21, 1))

# Create legend
legend_elements = [Patch(facecolor=color_dict[activity], label=activity) for activity in activities]
ax.legend(handles=legend_elements, title="Activiteit", bbox_to_anchor=(1.05, 1), loc='upper left')

# Set labels and title
ax.set_xlabel('Tijd')
ax.set_ylabel('Omloop nummer')
ax.set_title('Omloopplanning Gantt Chart')

plt.tight_layout()
plt.savefig('Omloopplanning_Gantt.png')

# %%
df_omloopplanning['eindtijd'] = df_omloopplanning['eindtijd'].dt.strftime('%H:%M:%S')
df_omloopplanning = df_omloopplanning[['startlocatie','eindlocatie','starttijd', 'eindtijd', 'activiteit', 'buslijn', 'energieverbruik', 'starttijd datum', 'eindtijd datum', 'omloop nummer']]
df_omloopplanning.to_excel('5. Verbeterde omloopplanning.xlsx')
